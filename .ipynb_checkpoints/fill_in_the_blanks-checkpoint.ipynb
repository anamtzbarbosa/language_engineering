# %%
import math
import torch
import random
import numpy as np
from torch import nn, optim

from datetime import datetime
from dataclasses import dataclass, asdict
from tokenizer import TinyStoriesTokenizer
from self_attention import MultiHeadSelfAttention

# %% [markdown]
# ## Transformer block
# To obtain a complete transformer block, we add a __position-wise feed-forward layer__ after the self-attention computation. The vectors are first projected to be 4 times wider, a non-linear ``relu'' function is applied, and the vectors are projected down to their original size.
#
# Before and after the self-attention computation, we add a __layer norm__ which normalizes each vector to have mean 0 and variance 1. This contributes to "numerical stability" in the forward pass, i.e. that the numbers within the vectors stay within the bounds representable by a computer.
#
# We also add __residual connections__ to each layer. In general, this means that we compute $x+f(x)$ rather than just $f(x)$ (the "$x+$" is sometimes called the "identity shortcut"). The gradient of $x+f(x)$ is $1+f'(x)$, which is close to 1 if $f'(x)$ is tiny. Without the identity shortcut, the overall gradient in the backward pass could be come extremely small, in particular in a deep network where many layers are stacked. The residual connection thus acts as a prevention for the "vanishing gradient" problem.

# %%
class PositionwiseFFN(nn.Module):
    """
    The position-wise FFN that follows after the self-attention computation.
    Vectors are projected to 4x the dimensionality and then projected down
    again after relu application.
    """

    def __init__(self, vector_dim, dropout_prob) :
        super().__init__()
        self.fc1 = nn.Linear(vector_dim, 4*vector_dim, bias=True)
        self.fc2 = nn.Linear(4*vector_dim, vector_dim, bias=True)
        self.dropout = nn.Dropout(dropout_prob)

    def forward(self, x):
        return self.fc2(self.dropout(torch.relu(self.fc1(x))))

class Block(nn.Module):
    """
    Transformer encoder block.

    This version differs from the original version in  [Vaswani et al. NeurIPS 2017],
    and applies the LayerNorm before the self-attention, and before the FFN, as this
    has proved to be beneficial (see [Nguyen and Salazar 2019]).
    """

    def __init__(self, vector_dim, n_heads, block_size, dropout_prob):
        super().__init__()
        att_dim = vector_dim // n_heads
        self.attn = MultiHeadSelfAttention(vector_dim, n_heads, block_size, is_causal=False) #MODIFY IMPO
        self.ffn = PositionwiseFFN(vector_dim, dropout_prob)
        self.dropout = nn.Dropout(dropout_prob)
        self.ln1 = nn.LayerNorm(vector_dim)
        self.ln2 = nn.LayerNorm(vector_dim)

    def forward(self, x):
        x1 = self.ln1(x) # pre layer norm
        x2 = x + self.dropout(self.attn(x1)) # attention + residual
        x3 = self.ln2(x2)
        x4 = x2 + self.dropout(self.ffn(x3)) # ffn + residual
        return x4

# %% [markdown]
# ## Fill in the blanks

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000 + 1  # This number should agree with the tokenizer
    mask_token_id: int = 5000  # new token forn unmasking
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 4
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1


class TinyStoriesLM(nn.Module):

    def __init__(self, config):
        super(TinyStoriesLM, self).__init__()
        self.config = config
        self.embed =  nn.Embedding(config.vocab_size, config.vector_dim)
        self.positional = nn.Parameter(torch.randn(1, config.block_size, config.vector_dim)) # learns during trianing, beginning random
        modules = [Block(config.vector_dim,\
                         config.number_of_attention_heads,\
                         config.block_size,\
                         config.dropout_prob) for _ in range(config.number_of_transformer_blocks)]
        self.transformers = nn.ModuleList(modules)
        self.final = nn.Linear(config.vector_dim, config.vocab_size)

    def forward(self, x):
        # x size (B, S)
        # each element is a token-word -> transf it to vector
        B, S = x.shape

        # Embedding (B, S, vector_dim)
        token_embeddings = self.embed(x) # each num.token is now a 256 len vector

        # Position Embedding - size ( 1, blocksize, vector_dim) -> S increasing as model generates more words
        pos_embeddings = self.positional[:, :S, :] # (1, S, vector_dim)

        x = token_embeddings + pos_embeddings # (B, S, vector_dim)

        # TRANSFORMERS BLOCK
        for block in self.transformers:
            x = block(x)
        # output - same len but with more context

        # Project to 5_001 words. For each pos - how probable for next word to be ... from 0-4999
        logits = self.final(x) # (B, S, vector_dim) to (B, S, vocab_size)

        # YOUR CODE HERE

        return logits

    @classmethod
    def load(cls, checkpoint_path, device='cpu'):
        """
        Loads a model from a checkpoint file.
        Automatically reconstructs the config and model architecture.
        """
        checkpoint = torch.load(checkpoint_path, map_location=device)
        config = Config(**checkpoint['config'])
        model = cls(config)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(device)

        print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']}, iteration {checkpoint['iteration']})")
        return model

# %%
from torch.utils.data import Sampler, SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from tokenizer import TinyStoriesTokenizer

class MaskedTinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size, vocab_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size
        self.mask_token_id = vocab_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):

        """
        For each input sentence, randomly select 15% of the tokens.
        We call these “selected tokens”. Of the selected tokens, and replace 80% with “[MASK]”, 10% with a random word, and leave 10% unchanged.
        Train the model to predict the original identity of all selected tokens.
        Note that your loss function should only be calculated over the selected tokens
        """
        # Pull a chunk of length block_size 
        chunk = self.data[idx : idx + self.block_size]
        chunk = torch.from_numpy(chunk.astype(np.int64))
        original = chunk.clone()     # original
        masked_input = chunk.clone() # modified

        # randomly select 15%
        probs = torch.full(original.shape, 0.15)
        selected_idx = torch.bernoulli(probs).bool()

        # 15% si what we want to predict
        # From 15%:

        for idx in selected_idx.nonzero(as_tuple=True)[0]: # give me the idx of the rows where true in selected_idx
          r = random.random()
          if r < 0.80:
              masked_input[idx] = self.mask_token_id # 80% time we replace with mask [MASK]
          elif r < 0.90:
              masked_input[idx] = random.randint(0, self.mask_token_id-1)  # 10% replace with random word, exlcuidng mask
          # else: 10% remains the same
        # masked input = The [MASK] sat on the [RANDOM: airplane]

        return masked_input, original, selected_idx


# This class facilitates re-starting training without repeating any past training examples
class ResumableRandomSampler(Sampler):
    def __init__(self, data_source, start_index=0, seed=42):
        self.data_source = data_source
        self.start_index = start_index
        self.seed = seed
        self.generator = torch.Generator()
        self.generator.manual_seed(self.seed)

        # 1. Generate the full shuffled list of indices once
        self.indices = torch.randperm(len(self.data_source), generator=self.generator).tolist()

    def __iter__(self):
        # 2. Slice the indices to only include those from start_index onwards
        return iter(self.indices[self.start_index:])

    def __len__(self):
        return len(self.indices) - self.start_index

# %%
import os

# ======================= Training ======================= #

# Remove the checkpoint file if you want to train from scratch
checkpoint_path = 'last_checkpoint_unmasking.pt'
RESUME_TRAINING = os.path.exists(checkpoint_path)

seed = 42
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print( "Running on", device )

tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')

# IMPO Add [MASK] to tokens
mask_token = "[MASK]"
if mask_token not in tokenizer.vocab:
    tokenizer.vocab.append(mask_token)
    tokenizer.vocab_size += 1
mask_id = len(tokenizer.vocab) - 1 

if RESUME_TRAINING:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']+1}, iteration {checkpoint['iteration']})")
    config = Config(**checkpoint['config'])
    lm = TinyStoriesLM(config)
    # Sanity check
    if tokenizer.vocab_size != lm.config.vocab_size:
        print("WARNING: The tokenizer's and the model's vocab_size are different!")
    lm.load_state_dict(checkpoint['model_state_dict'])
    lm.to(device)
else :
    config = Config()
    config.vocab_size = tokenizer.vocab_size  # 5001
    config.mask_token_id = tokenizer.vocab_size - 1  # 5000
    print('len tokenizer: ', len(tokenizer.vocab))
    lm = TinyStoriesLM(config).to(device)

lm_optimizer = torch.optim.AdamW(lm.parameters(), lr=lm.config.learning_rate, weight_decay=config.weight_decay)

if RESUME_TRAINING:
    lm_optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

training_dataset = MaskedTinyStoriesDataset('/datasets/dd2417/train.bin', config.block_size, config.mask_token_id)

# Development set
dev_dataset = MaskedTinyStoriesDataset('/datasets/dd2417/dev.bin', config.block_size, config.mask_token_id)
# Create indices that jump by the block size. This ensures we only see each
# chunk of text once when computing validation loss.
dev_indices = list(range(0, len(dev_dataset), config.block_size))
dev_subset = torch.utils.data.Subset(dev_dataset, dev_indices)
dev_loader = DataLoader(dev_subset, config.batch_size, pin_memory=True)

print( "There are", len(training_dataset), "datapoints and", tokenizer.vocab_size, "token classes in the dataset" )

criterion = nn.CrossEntropyLoss()

lm.train()
running_loss = 0
print( datetime.now().strftime("%X"), "Training starts" )
# Can we pick up where we left off?
start_epoch = checkpoint['epoch'] if RESUME_TRAINING else 0
start_iter = checkpoint['iteration'] if RESUME_TRAINING else 0

# CHANGE
for epoch in range(start_epoch, config.no_of_epochs) :
    iteration = start_iter if epoch == start_epoch else 0
    # Random sampling of datapoints. Note that we use a new seed for each epoch
    # -- this will guarantee that we can resume the training anywhere without
    # repeating any datapoints within an epoch.
    sampler = ResumableRandomSampler(training_dataset,
                                     start_index=iteration * config.batch_size,
                                     seed=seed+epoch)
    training_loader = DataLoader(training_dataset,
                                 batch_size=config.batch_size,
                                 sampler=sampler,
                                 num_workers=4)
    for masked_input, original, selected in training_loader:
        masked_input, original, selected = masked_input.to(device), original.to(device), selected.to(device)
        lm_optimizer.zero_grad() # erase previous error

        # Prediction forward
        logits = lm(masked_input) 
        # masked input (15% - 80-10-10)-> what model sees | original -> what to predict | selected -> boolean, where calculate loss (random 15%)
        loss = criterion(logits[selected],  original[selected] )
        loss.backward() # gradients
        lm_optimizer.step() # update weights


        running_loss += loss.detach().item()
        iteration += 1
        if iteration%100 == 0:
            # Compute validation loss every 100 iterations
            # CHANGE
            lm.eval()
            with torch.no_grad():
                total_loss = 0
                for vx, vy, v_selected in dev_loader:
                  vx, vy, v_selected = vx.to(device), vy.to(device), v_selected.to(device)
                  logits = lm(vx)
                  val_loss = criterion(logits[v_selected], vy[v_selected])
                  total_loss += val_loss.item()
                print(f'{datetime.now().strftime("%X")} Epoch {epoch+1}, iteration {iteration}: loss={running_loss/100:.4f}, dev loss={total_loss/len(dev_loader):.4f}')
            lm.train()
            running_loss = 0
        if iteration%10000 == 0:
            checkpoint = {
                'model_state_dict': lm.state_dict(),
                'optimizer_state_dict': lm_optimizer.state_dict(),
                'epoch': epoch,
                'iteration': iteration,
                'config': config.__dict__, # Useful so you know the architecture later
            }

            # Overwrites the same file every time to save space
            torch.save(checkpoint, checkpoint_path)
            print(f"Checkpoint saved to {checkpoint_path}")

            # Show progress
            lm.eval()
            with torch.no_grad():
              sample_input, sample_original, sample_selected = next(iter(dev_loader))
              sample_input = sample_input.to(device)
              sample_original = sample_original.to(device)
              sample_selected = sample_selected.to(device)
              
              logits = lm(sample_input)
              predictions = logits.argmax(dim=-1)  # token max probability
              
              # Get the indx for selected -> jsut print the first 5 tokens first example from batch
              selected_positions = sample_selected[0].nonzero(as_tuple=True)[0][:5]
              print("-" * 30)
              for pos in selected_positions:
                  predicted = tokenizer.vocab[predictions[0][pos].item()]
                  original  = tokenizer.vocab[sample_original[0][pos].item()]
                  masked    = sample_input[0][pos].item()
                  print(f"original: {original:15} | prediction: {predicted:15} | is [MASK]?: {masked == config.mask_token_id}")
              print("-" * 30)
            lm.train()
# Out:
# Running on cuda
# len tokenizer:  5001
# There are 18507842 datapoints and 5001 token classes in the dataset
# 12:31:25 Training starts
# 12:31:30 Epoch 1, iteration 100: loss=6.1317, dev loss=5.7972
# 12:31:33 Epoch 1, iteration 200: loss=5.7455, dev loss=5.6817
# 12:31:37 Epoch 1, iteration 300: loss=5.6656, dev loss=5.6024
# 12:31:40 Epoch 1, iteration 400: loss=5.6024, dev loss=5.5577
# 12:31:43 Epoch 1, iteration 500: loss=5.5552, dev loss=5.4915
# 12:31:47 Epoch 1, iteration 600: loss=5.5223, dev loss=5.4866
# 12:31:50 Epoch 1, iteration 700: loss=5.4920, dev loss=5.4674
# 12:31:53 Epoch 1, iteration 800: loss=5.4996, dev loss=5.4675
# 12:31:56 Epoch 1, iteration 900: loss=5.4863, dev loss=5.4454
# 12:32:00 Epoch 1, iteration 1000: loss=5.4742, dev loss=5.4312
# 12:32:03 Epoch 1, iteration 1100: loss=5.4730, dev loss=5.3911
# 12:32:06 Epoch 1, iteration 1200: loss=5.4491, dev loss=5.4209
# 12:32:09 Epoch 1, iteration 1300: loss=5.4291, dev loss=5.4351
# 12:32:13 Epoch 1, iteration 1400: loss=5.4172, dev loss=5.3703
# 12:32:16 Epoch 1, iteration 1500: loss=5.4332, dev loss=5.4143
# 12:32:19 Epoch 1, iteration 1600: loss=5.4059, dev loss=5.4246
# 12:32:22 Epoch 1, iteration 1700: loss=5.4153, dev loss=5.3821
# 12:32:26 Epoch 1, iteration 1800: loss=5.3931, dev loss=5.4204
# 12:32:29 Epoch 1, iteration 1900: loss=5.3964, dev loss=5.3604
# 12:32:32 Epoch 1, iteration 2000: loss=5.3796, dev loss=5.3723
# 12:32:36 Epoch 1, iteration 2100: loss=5.3929, dev loss=5.3574
# 12:32:39 Epoch 1, iteration 2200: loss=5.3988, dev loss=5.3906
# 12:32:42 Epoch 1, iteration 2300: loss=5.3926, dev loss=5.3414
# 12:32:45 Epoch 1, iteration 2400: loss=5.3903, dev loss=5.3536
# 12:32:49 Epoch 1, iteration 2500: loss=5.3655, dev loss=5.3274
# 12:32:52 Epoch 1, iteration 2600: loss=5.3547, dev loss=5.3313
# 12:32:55 Epoch 1, iteration 2700: loss=5.3635, dev loss=5.3491
# 12:32:59 Epoch 1, iteration 2800: loss=5.3912, dev loss=5.3364
# 12:33:02 Epoch 1, iteration 2900: loss=5.3486, dev loss=5.3487
# 12:33:05 Epoch 1, iteration 3000: loss=5.3312, dev loss=5.3433
# 12:33:08 Epoch 1, iteration 3100: loss=5.3569, dev loss=5.3372
# 12:33:12 Epoch 1, iteration 3200: loss=5.3476, dev loss=5.3337
# 12:33:15 Epoch 1, iteration 3300: loss=5.3479, dev loss=5.3100
# 12:33:18 Epoch 1, iteration 3400: loss=5.3472, dev loss=5.3125
# 12:33:22 Epoch 1, iteration 3500: loss=5.3232, dev loss=5.3152
# 12:33:25 Epoch 1, iteration 3600: loss=5.3356, dev loss=5.3055
# 12:33:28 Epoch 1, iteration 3700: loss=5.3085, dev loss=5.3267
# 12:33:31 Epoch 1, iteration 3800: loss=5.3401, dev loss=5.3295
# 12:33:35 Epoch 1, iteration 3900: loss=5.3264, dev loss=5.3234
# 12:33:38 Epoch 1, iteration 4000: loss=5.3429, dev loss=5.3013
# 12:33:41 Epoch 1, iteration 4100: loss=5.3032, dev loss=5.3235
# 12:33:45 Epoch 1, iteration 4200: loss=5.3033, dev loss=5.2889
# 12:33:48 Epoch 1, iteration 4300: loss=5.3253, dev loss=5.2696
# 12:33:51 Epoch 1, iteration 4400: loss=5.3144, dev loss=5.2839
# 12:33:54 Epoch 1, iteration 4500: loss=5.3292, dev loss=5.2809
# 12:33:58 Epoch 1, iteration 4600: loss=5.2774, dev loss=5.2827
# 12:34:01 Epoch 1, iteration 4700: loss=5.2880, dev loss=5.2504
# 12:34:04 Epoch 1, iteration 4800: loss=5.2712, dev loss=5.2453
# 12:34:07 Epoch 1, iteration 4900: loss=5.2761, dev loss=5.2588
# 12:34:11 Epoch 1, iteration 5000: loss=5.2784, dev loss=5.2773
# 12:34:14 Epoch 1, iteration 5100: loss=5.2641, dev loss=5.2435
# 12:34:17 Epoch 1, iteration 5200: loss=5.2497, dev loss=5.2113
# 12:34:21 Epoch 1, iteration 5300: loss=5.2420, dev loss=5.2227
# 12:34:24 Epoch 1, iteration 5400: loss=5.2257, dev loss=5.1927
# 12:34:27 Epoch 1, iteration 5500: loss=5.2003, dev loss=5.1909
# 12:34:30 Epoch 1, iteration 5600: loss=5.2097, dev loss=5.1799
# 12:34:34 Epoch 1, iteration 5700: loss=5.1609, dev loss=5.1884
# 12:34:37 Epoch 1, iteration 5800: loss=5.2035, dev loss=5.1714
# 12:34:40 Epoch 1, iteration 5900: loss=5.1720, dev loss=5.1446
# 12:34:44 Epoch 1, iteration 6000: loss=5.1771, dev loss=5.1304
# 12:34:47 Epoch 1, iteration 6100: loss=5.1338, dev loss=5.1052
# 12:34:50 Epoch 1, iteration 6200: loss=5.1310, dev loss=5.0786
# 12:34:53 Epoch 1, iteration 6300: loss=5.0993, dev loss=5.0444
# 12:34:57 Epoch 1, iteration 6400: loss=5.0395, dev loss=4.9976
# 12:35:00 Epoch 1, iteration 6500: loss=5.0011, dev loss=4.9611
# 12:35:03 Epoch 1, iteration 6600: loss=4.9119, dev loss=4.8546
# 12:35:06 Epoch 1, iteration 6700: loss=4.8750, dev loss=4.7732
# 12:35:10 Epoch 1, iteration 6800: loss=4.7926, dev loss=4.7196
# 12:35:13 Epoch 1, iteration 6900: loss=4.7027, dev loss=4.5937
# 12:35:16 Epoch 1, iteration 7000: loss=4.6538, dev loss=4.5357
# 12:35:20 Epoch 1, iteration 7100: loss=4.5368, dev loss=4.4815
# 12:35:23 Epoch 1, iteration 7200: loss=4.4796, dev loss=4.3720
# 12:35:26 Epoch 1, iteration 7300: loss=4.3562, dev loss=4.2893
# 12:35:29 Epoch 1, iteration 7400: loss=4.2830, dev loss=4.2272
# 12:35:33 Epoch 1, iteration 7500: loss=4.2058, dev loss=4.0923
# 12:35:36 Epoch 1, iteration 7600: loss=4.1226, dev loss=4.0298
# 12:35:39 Epoch 1, iteration 7700: loss=4.0374, dev loss=3.9617
# 12:35:43 Epoch 1, iteration 7800: loss=3.9504, dev loss=3.9291
# 12:35:46 Epoch 1, iteration 7900: loss=3.9016, dev loss=3.7967
# 12:35:49 Epoch 1, iteration 8000: loss=3.8275, dev loss=3.7621
# 12:35:53 Epoch 1, iteration 8100: loss=3.7588, dev loss=3.6489
# 12:35:56 Epoch 1, iteration 8200: loss=3.7201, dev loss=3.6057
# 12:35:59 Epoch 1, iteration 8300: loss=3.6580, dev loss=3.5585
# 12:36:02 Epoch 1, iteration 8400: loss=3.5643, dev loss=3.4727
# 12:36:06 Epoch 1, iteration 8500: loss=3.5087, dev loss=3.4232
# 12:36:09 Epoch 1, iteration 8600: loss=3.4405, dev loss=3.3739
# 12:36:12 Epoch 1, iteration 8700: loss=3.4225, dev loss=3.3166
# 12:36:16 Epoch 1, iteration 8800: loss=3.3450, dev loss=3.2570
# 12:36:19 Epoch 1, iteration 8900: loss=3.3332, dev loss=3.2315
# 12:36:22 Epoch 1, iteration 9000: loss=3.2787, dev loss=3.1793
# 12:36:25 Epoch 1, iteration 9100: loss=3.2534, dev loss=3.1375
# 12:36:29 Epoch 1, iteration 9200: loss=3.2141, dev loss=3.0932
# 12:36:32 Epoch 1, iteration 9300: loss=3.1417, dev loss=3.0834
# 12:36:35 Epoch 1, iteration 9400: loss=3.1396, dev loss=3.0318
# 12:36:38 Epoch 1, iteration 9500: loss=3.0881, dev loss=3.0183
# 12:36:42 Epoch 1, iteration 9600: loss=3.0595, dev loss=2.9734
# 12:36:45 Epoch 1, iteration 9700: loss=3.0399, dev loss=2.9353
# 12:36:48 Epoch 1, iteration 9800: loss=3.0034, dev loss=2.9246
# 12:36:52 Epoch 1, iteration 9900: loss=2.9815, dev loss=2.9061
# 12:36:55 Epoch 1, iteration 10000: loss=2.9634, dev loss=2.8742
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  a              | prediction:  a              | is [MASK]?: True
# original:  time           | prediction:  time           | is [MASK]?: True
# original:  they           | prediction:  Timmy          | is [MASK]?: True
# original:  was            | prediction:  was            | is [MASK]?: True
# original:  excited        | prediction:  excited        | is [MASK]?: True
# ------------------------------
# 12:36:58 Epoch 1, iteration 10100: loss=2.9363, dev loss=2.8834
# 12:37:02 Epoch 1, iteration 10200: loss=2.9145, dev loss=2.8148
# 12:37:05 Epoch 1, iteration 10300: loss=2.8912, dev loss=2.8036
# 12:37:08 Epoch 1, iteration 10400: loss=2.8723, dev loss=2.7970
# 12:37:11 Epoch 1, iteration 10500: loss=2.8346, dev loss=2.7358
# 12:37:15 Epoch 1, iteration 10600: loss=2.8340, dev loss=2.7417
# 12:37:18 Epoch 1, iteration 10700: loss=2.8303, dev loss=2.7189
# 12:37:21 Epoch 1, iteration 10800: loss=2.8114, dev loss=2.6863
# 12:37:24 Epoch 1, iteration 10900: loss=2.7722, dev loss=2.6808
# 12:37:28 Epoch 1, iteration 11000: loss=2.7819, dev loss=2.6628
# 12:37:31 Epoch 1, iteration 11100: loss=2.7450, dev loss=2.6763
# 12:37:34 Epoch 1, iteration 11200: loss=2.7663, dev loss=2.6495
# 12:37:38 Epoch 1, iteration 11300: loss=2.7248, dev loss=2.6291
# 12:37:41 Epoch 1, iteration 11400: loss=2.7174, dev loss=2.6101
# 12:37:44 Epoch 1, iteration 11500: loss=2.6959, dev loss=2.6107
# 12:37:47 Epoch 1, iteration 11600: loss=2.7119, dev loss=2.6003
# 12:37:51 Epoch 1, iteration 11700: loss=2.6804, dev loss=2.6157
# 12:37:54 Epoch 1, iteration 11800: loss=2.6603, dev loss=2.5796
# 12:37:57 Epoch 1, iteration 11900: loss=2.6635, dev loss=2.5724
# 12:38:00 Epoch 1, iteration 12000: loss=2.6428, dev loss=2.5350
# 12:38:04 Epoch 1, iteration 12100: loss=2.6343, dev loss=2.5521
# 12:38:07 Epoch 1, iteration 12200: loss=2.5903, dev loss=2.5289
# 12:38:10 Epoch 1, iteration 12300: loss=2.5872, dev loss=2.4982
# 12:38:13 Epoch 1, iteration 12400: loss=2.5852, dev loss=2.4900
# 12:38:17 Epoch 1, iteration 12500: loss=2.5717, dev loss=2.4677
# 12:38:20 Epoch 1, iteration 12600: loss=2.5541, dev loss=2.4560
# 12:38:23 Epoch 1, iteration 12700: loss=2.5476, dev loss=2.4708
# 12:38:26 Epoch 1, iteration 12800: loss=2.5225, dev loss=2.4743
# 12:38:30 Epoch 1, iteration 12900: loss=2.5365, dev loss=2.4517
# 12:38:33 Epoch 1, iteration 13000: loss=2.5169, dev loss=2.4104
# 12:38:36 Epoch 1, iteration 13100: loss=2.5258, dev loss=2.4165
# 12:38:39 Epoch 1, iteration 13200: loss=2.4977, dev loss=2.3999
# 12:38:43 Epoch 1, iteration 13300: loss=2.4864, dev loss=2.3972
# 12:38:46 Epoch 1, iteration 13400: loss=2.4684, dev loss=2.3726
# 12:38:49 Epoch 1, iteration 13500: loss=2.4716, dev loss=2.3770
# 12:38:52 Epoch 1, iteration 13600: loss=2.4553, dev loss=2.3832
# 12:38:56 Epoch 1, iteration 13700: loss=2.4466, dev loss=2.3520
# 12:38:59 Epoch 1, iteration 13800: loss=2.4511, dev loss=2.3505
# 12:39:02 Epoch 1, iteration 13900: loss=2.4281, dev loss=2.3029
# 12:39:05 Epoch 1, iteration 14000: loss=2.4049, dev loss=2.3281
# 12:39:09 Epoch 1, iteration 14100: loss=2.4033, dev loss=2.3381
# 12:39:12 Epoch 1, iteration 14200: loss=2.4205, dev loss=2.3127
# 12:39:15 Epoch 1, iteration 14300: loss=2.4060, dev loss=2.3020
# 12:39:18 Epoch 1, iteration 14400: loss=2.3970, dev loss=2.2910
# 12:39:22 Epoch 1, iteration 14500: loss=2.3741, dev loss=2.2896
# 12:39:25 Epoch 1, iteration 14600: loss=2.3675, dev loss=2.2607
# 12:39:28 Epoch 1, iteration 14700: loss=2.3454, dev loss=2.2730
# 12:39:31 Epoch 1, iteration 14800: loss=2.3579, dev loss=2.2579
# 12:39:34 Epoch 1, iteration 14900: loss=2.3364, dev loss=2.2972
# 12:39:38 Epoch 1, iteration 15000: loss=2.2930, dev loss=2.2463
# 12:39:41 Epoch 1, iteration 15100: loss=2.2588, dev loss=2.2354
# 12:39:44 Epoch 1, iteration 15200: loss=2.3171, dev loss=2.2492
# 12:39:47 Epoch 1, iteration 15300: loss=2.2978, dev loss=2.2182
# 12:39:51 Epoch 1, iteration 15400: loss=2.2717, dev loss=2.2202
# 12:39:54 Epoch 1, iteration 15500: loss=2.2962, dev loss=2.2178
# 12:39:57 Epoch 1, iteration 15600: loss=2.2830, dev loss=2.1887
# 12:40:00 Epoch 1, iteration 15700: loss=2.2775, dev loss=2.1855
# 12:40:04 Epoch 1, iteration 15800: loss=2.2727, dev loss=2.2093
# 12:40:07 Epoch 1, iteration 15900: loss=2.2579, dev loss=2.1603
# 12:40:10 Epoch 1, iteration 16000: loss=2.2520, dev loss=2.1611
# 12:40:13 Epoch 1, iteration 16100: loss=2.2299, dev loss=2.1730
# 12:40:17 Epoch 1, iteration 16200: loss=2.2156, dev loss=2.1535
# 12:40:20 Epoch 1, iteration 16300: loss=2.2187, dev loss=2.1290
# 12:40:23 Epoch 1, iteration 16400: loss=2.1966, dev loss=2.1112
# 12:40:26 Epoch 1, iteration 16500: loss=2.2333, dev loss=2.1268
# 12:40:29 Epoch 1, iteration 16600: loss=2.2098, dev loss=2.0946
# 12:40:33 Epoch 1, iteration 16700: loss=2.2007, dev loss=2.1003
# 12:40:36 Epoch 1, iteration 16800: loss=2.1936, dev loss=2.0922
# 12:40:39 Epoch 1, iteration 16900: loss=2.1824, dev loss=2.0771
# 12:40:42 Epoch 1, iteration 17000: loss=2.1615, dev loss=2.0814
# 12:40:45 Epoch 1, iteration 17100: loss=2.1686, dev loss=2.0979
# 12:40:49 Epoch 1, iteration 17200: loss=2.1633, dev loss=2.0798
# 12:40:52 Epoch 1, iteration 17300: loss=2.1589, dev loss=2.0514
# 12:40:55 Epoch 1, iteration 17400: loss=2.1398, dev loss=2.0595
# 12:40:58 Epoch 1, iteration 17500: loss=2.1405, dev loss=2.0422
# 12:41:01 Epoch 1, iteration 17600: loss=2.1065, dev loss=2.0395
# 12:41:05 Epoch 1, iteration 17700: loss=2.1161, dev loss=2.0341
# 12:41:08 Epoch 1, iteration 17800: loss=2.1027, dev loss=2.0212
# 12:41:11 Epoch 1, iteration 17900: loss=2.1119, dev loss=2.0269
# 12:41:14 Epoch 1, iteration 18000: loss=2.0990, dev loss=2.0107
# 12:41:17 Epoch 1, iteration 18100: loss=2.0852, dev loss=2.0345
# 12:41:20 Epoch 1, iteration 18200: loss=2.0836, dev loss=1.9710
# 12:41:23 Epoch 1, iteration 18300: loss=2.0819, dev loss=1.9881
# 12:41:27 Epoch 1, iteration 18400: loss=2.0543, dev loss=1.9454
# 12:41:30 Epoch 1, iteration 18500: loss=2.0776, dev loss=1.9580
# 12:41:33 Epoch 1, iteration 18600: loss=2.0539, dev loss=1.9590
# 12:41:36 Epoch 1, iteration 18700: loss=2.0527, dev loss=1.9461
# 12:41:39 Epoch 1, iteration 18800: loss=2.0461, dev loss=1.9629
# 12:41:42 Epoch 1, iteration 18900: loss=2.0569, dev loss=1.9308
# 12:41:45 Epoch 1, iteration 19000: loss=2.0460, dev loss=1.9390
# 12:41:49 Epoch 1, iteration 19100: loss=2.0124, dev loss=1.9388
# 12:41:52 Epoch 1, iteration 19200: loss=2.0077, dev loss=1.9247
# 12:41:55 Epoch 1, iteration 19300: loss=2.0088, dev loss=1.9072
# 12:41:58 Epoch 1, iteration 19400: loss=2.0127, dev loss=1.9071
# 12:42:01 Epoch 1, iteration 19500: loss=2.0182, dev loss=1.9181
# 12:42:04 Epoch 1, iteration 19600: loss=2.0110, dev loss=1.9043
# 12:42:07 Epoch 1, iteration 19700: loss=2.0155, dev loss=1.8994
# 12:42:11 Epoch 1, iteration 19800: loss=2.0144, dev loss=1.8950
# 12:42:14 Epoch 1, iteration 19900: loss=1.9943, dev loss=1.8640
# 12:42:17 Epoch 1, iteration 20000: loss=1.9940, dev loss=1.8907
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  little         | prediction:  little         | is [MASK]?: True
# original:  Timmy          | prediction:  Timmy          | is [MASK]?: True
# original:  to             | prediction:  to             | is [MASK]?: True
# original:  go             | prediction:  play           | is [MASK]?: True
# original:  with           | prediction:  with           | is [MASK]?: True
# ------------------------------
# 12:42:20 Epoch 1, iteration 20100: loss=1.9827, dev loss=1.8988
# 12:42:23 Epoch 1, iteration 20200: loss=1.9705, dev loss=1.8974
# 12:42:26 Epoch 1, iteration 20300: loss=1.9774, dev loss=1.8588
# 12:42:30 Epoch 1, iteration 20400: loss=1.9543, dev loss=1.8874
# 12:42:33 Epoch 1, iteration 20500: loss=1.9762, dev loss=1.8313
# 12:42:36 Epoch 1, iteration 20600: loss=1.9638, dev loss=1.8456
# 12:42:39 Epoch 1, iteration 20700: loss=1.9545, dev loss=1.8249
# 12:42:42 Epoch 1, iteration 20800: loss=1.9339, dev loss=1.8511
# 12:42:45 Epoch 1, iteration 20900: loss=1.9465, dev loss=1.8661
# 12:42:48 Epoch 1, iteration 21000: loss=1.9408, dev loss=1.8227
# 12:42:52 Epoch 1, iteration 21100: loss=1.9364, dev loss=1.8130
# 12:42:55 Epoch 1, iteration 21200: loss=1.9121, dev loss=1.8054
# 12:42:58 Epoch 1, iteration 21300: loss=1.9026, dev loss=1.8283
# 12:43:01 Epoch 1, iteration 21400: loss=1.9170, dev loss=1.8120
# 12:43:04 Epoch 1, iteration 21500: loss=1.9033, dev loss=1.8041
# 12:43:07 Epoch 1, iteration 21600: loss=1.9046, dev loss=1.8161
# 12:43:10 Epoch 1, iteration 21700: loss=1.8894, dev loss=1.8087
# 12:43:14 Epoch 1, iteration 21800: loss=1.8957, dev loss=1.7869
# 12:43:17 Epoch 1, iteration 21900: loss=1.8843, dev loss=1.7920
# 12:43:20 Epoch 1, iteration 22000: loss=1.8727, dev loss=1.7757
# 12:43:23 Epoch 1, iteration 22100: loss=1.8726, dev loss=1.7752
# 12:43:26 Epoch 1, iteration 22200: loss=1.8599, dev loss=1.7814
# 12:43:29 Epoch 1, iteration 22300: loss=1.8648, dev loss=1.7657
# 12:43:33 Epoch 1, iteration 22400: loss=1.8831, dev loss=1.7689
# 12:43:36 Epoch 1, iteration 22500: loss=1.8664, dev loss=1.7665
# 12:43:39 Epoch 1, iteration 22600: loss=1.8788, dev loss=1.7444
# 12:43:42 Epoch 1, iteration 22700: loss=1.8646, dev loss=1.7619
# 12:43:45 Epoch 1, iteration 22800: loss=1.8543, dev loss=1.7335
# 12:43:49 Epoch 1, iteration 22900: loss=1.8463, dev loss=1.7508
# 12:43:52 Epoch 1, iteration 23000: loss=1.8176, dev loss=1.7877
# 12:43:55 Epoch 1, iteration 23100: loss=1.8282, dev loss=1.7349
# 12:43:58 Epoch 1, iteration 23200: loss=1.8257, dev loss=1.7225
# 12:44:02 Epoch 1, iteration 23300: loss=1.8211, dev loss=1.6850
# 12:44:05 Epoch 1, iteration 23400: loss=1.7880, dev loss=1.7260
# 12:44:08 Epoch 1, iteration 23500: loss=1.7871, dev loss=1.7039
# 12:44:11 Epoch 1, iteration 23600: loss=1.8198, dev loss=1.6849
# 12:44:15 Epoch 1, iteration 23700: loss=1.8078, dev loss=1.7125
# 12:44:18 Epoch 1, iteration 23800: loss=1.8133, dev loss=1.6953
# 12:44:21 Epoch 1, iteration 23900: loss=1.7884, dev loss=1.6938
# 12:44:25 Epoch 1, iteration 24000: loss=1.7917, dev loss=1.7017
# 12:44:28 Epoch 1, iteration 24100: loss=1.8158, dev loss=1.6994
# 12:44:31 Epoch 1, iteration 24200: loss=1.7682, dev loss=1.7255
# 12:44:34 Epoch 1, iteration 24300: loss=1.8041, dev loss=1.6736
# 12:44:38 Epoch 1, iteration 24400: loss=1.7950, dev loss=1.6951
# 12:44:41 Epoch 1, iteration 24500: loss=1.7448, dev loss=1.6946
# 12:44:44 Epoch 1, iteration 24600: loss=1.7693, dev loss=1.6702
# 12:44:48 Epoch 1, iteration 24700: loss=1.7824, dev loss=1.6888
# 12:44:51 Epoch 1, iteration 24800: loss=1.7544, dev loss=1.6301
# 12:44:54 Epoch 1, iteration 24900: loss=1.7704, dev loss=1.6561
# 12:44:58 Epoch 1, iteration 25000: loss=1.7419, dev loss=1.6392
# 12:45:01 Epoch 1, iteration 25100: loss=1.7421, dev loss=1.6408
# 12:45:04 Epoch 1, iteration 25200: loss=1.7593, dev loss=1.6525
# 12:45:07 Epoch 1, iteration 25300: loss=1.7349, dev loss=1.6578
# 12:45:11 Epoch 1, iteration 25400: loss=1.7438, dev loss=1.6252
# 12:45:14 Epoch 1, iteration 25500: loss=1.7575, dev loss=1.6440
# 12:45:17 Epoch 1, iteration 25600: loss=1.7346, dev loss=1.6522
# 12:45:21 Epoch 1, iteration 25700: loss=1.7344, dev loss=1.6483
# 12:45:24 Epoch 1, iteration 25800: loss=1.7274, dev loss=1.6238
# 12:45:27 Epoch 1, iteration 25900: loss=1.7281, dev loss=1.6239
# 12:45:30 Epoch 1, iteration 26000: loss=1.7153, dev loss=1.6458
# 12:45:34 Epoch 1, iteration 26100: loss=1.7271, dev loss=1.6420
# 12:45:37 Epoch 1, iteration 26200: loss=1.7222, dev loss=1.6240
# 12:45:40 Epoch 1, iteration 26300: loss=1.6865, dev loss=1.6238
# 12:45:44 Epoch 1, iteration 26400: loss=1.7097, dev loss=1.6202
# 12:45:47 Epoch 1, iteration 26500: loss=1.7137, dev loss=1.6031
# 12:45:50 Epoch 1, iteration 26600: loss=1.7265, dev loss=1.5960
# 12:45:53 Epoch 1, iteration 26700: loss=1.7180, dev loss=1.5757
# 12:45:57 Epoch 1, iteration 26800: loss=1.7028, dev loss=1.5954
# 12:46:00 Epoch 1, iteration 26900: loss=1.6764, dev loss=1.5894
# 12:46:03 Epoch 1, iteration 27000: loss=1.6876, dev loss=1.6090
# 12:46:07 Epoch 1, iteration 27100: loss=1.6841, dev loss=1.5934
# 12:46:10 Epoch 1, iteration 27200: loss=1.6812, dev loss=1.5929
# 12:46:13 Epoch 1, iteration 27300: loss=1.6935, dev loss=1.5969
# 12:46:16 Epoch 1, iteration 27400: loss=1.6753, dev loss=1.6084
# 12:46:20 Epoch 1, iteration 27500: loss=1.6926, dev loss=1.5838
# 12:46:23 Epoch 1, iteration 27600: loss=1.6801, dev loss=1.5887
# 12:46:26 Epoch 1, iteration 27700: loss=1.6816, dev loss=1.5969
# 12:46:30 Epoch 1, iteration 27800: loss=1.6830, dev loss=1.5758
# 12:46:33 Epoch 1, iteration 27900: loss=1.6644, dev loss=1.5607
# 12:46:36 Epoch 1, iteration 28000: loss=1.6802, dev loss=1.5742
# 12:46:39 Epoch 1, iteration 28100: loss=1.6700, dev loss=1.5685
# 12:46:43 Epoch 1, iteration 28200: loss=1.6718, dev loss=1.5712
# 12:46:46 Epoch 1, iteration 28300: loss=1.6891, dev loss=1.5402
# 12:46:49 Epoch 1, iteration 28400: loss=1.6478, dev loss=1.5608
# 12:46:52 Epoch 1, iteration 28500: loss=1.6647, dev loss=1.5500
# 12:46:56 Epoch 1, iteration 28600: loss=1.6550, dev loss=1.5435
# 12:46:59 Epoch 1, iteration 28700: loss=1.6585, dev loss=1.5738
# 12:47:02 Epoch 1, iteration 28800: loss=1.6611, dev loss=1.5409
# 12:47:06 Epoch 1, iteration 28900: loss=1.6564, dev loss=1.5512
# 12:47:09 Epoch 1, iteration 29000: loss=1.6285, dev loss=1.5447
# 12:47:12 Epoch 1, iteration 29100: loss=1.6406, dev loss=1.5239
# 12:47:15 Epoch 1, iteration 29200: loss=1.6245, dev loss=1.5223
# 12:47:19 Epoch 1, iteration 29300: loss=1.6302, dev loss=1.5318
# 12:47:22 Epoch 1, iteration 29400: loss=1.6405, dev loss=1.5313
# 12:47:25 Epoch 1, iteration 29500: loss=1.6178, dev loss=1.5499
# 12:47:29 Epoch 1, iteration 29600: loss=1.6353, dev loss=1.5009
# 12:47:32 Epoch 1, iteration 29700: loss=1.6400, dev loss=1.5382
# 12:47:35 Epoch 1, iteration 29800: loss=1.6044, dev loss=1.5308
# 12:47:38 Epoch 1, iteration 29900: loss=1.6216, dev loss=1.4974
# 12:47:42 Epoch 1, iteration 30000: loss=1.6143, dev loss=1.5297
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  fishing        | prediction:  fishing        | is [MASK]?: True
# original:  to             | prediction:  to             | is [MASK]?: True
# original:  some           | prediction:  the            | is [MASK]?: True
# original: .               | prediction: .               | is [MASK]?: True
# original:  Timmy          | prediction:  he             | is [MASK]?: True
# ------------------------------
# 12:47:45 Epoch 1, iteration 30100: loss=1.6169, dev loss=1.5167
# 12:47:49 Epoch 1, iteration 30200: loss=1.6259, dev loss=1.5262
# 12:47:52 Epoch 1, iteration 30300: loss=1.6347, dev loss=1.5282
# 12:47:55 Epoch 1, iteration 30400: loss=1.6144, dev loss=1.5302
# 12:47:58 Epoch 1, iteration 30500: loss=1.6218, dev loss=1.5136
# 12:48:02 Epoch 1, iteration 30600: loss=1.6244, dev loss=1.5096
# 12:48:05 Epoch 1, iteration 30700: loss=1.6045, dev loss=1.4833
# 12:48:08 Epoch 1, iteration 30800: loss=1.6248, dev loss=1.4873
# 12:48:12 Epoch 1, iteration 30900: loss=1.5963, dev loss=1.4982
# 12:48:15 Epoch 1, iteration 31000: loss=1.5896, dev loss=1.4963
# 12:48:18 Epoch 1, iteration 31100: loss=1.6078, dev loss=1.4911
# 12:48:22 Epoch 1, iteration 31200: loss=1.6074, dev loss=1.4794
# 12:48:25 Epoch 1, iteration 31300: loss=1.5767, dev loss=1.4820
# 12:48:28 Epoch 1, iteration 31400: loss=1.5755, dev loss=1.4755
# 12:48:31 Epoch 1, iteration 31500: loss=1.5719, dev loss=1.4881
# 12:48:35 Epoch 1, iteration 31600: loss=1.5953, dev loss=1.4821
# 12:48:38 Epoch 1, iteration 31700: loss=1.5833, dev loss=1.4907
# 12:48:41 Epoch 1, iteration 31800: loss=1.5699, dev loss=1.4763
# 12:48:45 Epoch 1, iteration 31900: loss=1.5717, dev loss=1.4640
# 12:48:48 Epoch 1, iteration 32000: loss=1.5469, dev loss=1.4688
# 12:48:51 Epoch 1, iteration 32100: loss=1.5724, dev loss=1.4581
# 12:48:54 Epoch 1, iteration 32200: loss=1.5659, dev loss=1.4664
# 12:48:58 Epoch 1, iteration 32300: loss=1.5736, dev loss=1.4742
# 12:49:01 Epoch 1, iteration 32400: loss=1.5778, dev loss=1.4385
# 12:49:04 Epoch 1, iteration 32500: loss=1.5480, dev loss=1.4662
# 12:49:08 Epoch 1, iteration 32600: loss=1.5444, dev loss=1.4666
# 12:49:11 Epoch 1, iteration 32700: loss=1.5515, dev loss=1.4512
# 12:49:14 Epoch 1, iteration 32800: loss=1.5490, dev loss=1.4710
# 12:49:18 Epoch 1, iteration 32900: loss=1.5458, dev loss=1.4461
# 12:49:21 Epoch 1, iteration 33000: loss=1.5392, dev loss=1.4353
# 12:49:24 Epoch 1, iteration 33100: loss=1.5495, dev loss=1.4583
# 12:49:28 Epoch 1, iteration 33200: loss=1.5409, dev loss=1.4500
# 12:49:31 Epoch 1, iteration 33300: loss=1.5616, dev loss=1.4545
# 12:49:34 Epoch 1, iteration 33400: loss=1.5570, dev loss=1.4390
# 12:49:38 Epoch 1, iteration 33500: loss=1.5456, dev loss=1.4537
# 12:49:41 Epoch 1, iteration 33600: loss=1.5327, dev loss=1.4336
# 12:49:44 Epoch 1, iteration 33700: loss=1.5261, dev loss=1.4232
# 12:49:47 Epoch 1, iteration 33800: loss=1.5523, dev loss=1.4611
# 12:49:51 Epoch 1, iteration 33900: loss=1.5516, dev loss=1.4480
# 12:49:54 Epoch 1, iteration 34000: loss=1.5192, dev loss=1.4343
# 12:49:57 Epoch 1, iteration 34100: loss=1.5342, dev loss=1.4307
# 12:50:01 Epoch 1, iteration 34200: loss=1.5330, dev loss=1.4429
# 12:50:04 Epoch 1, iteration 34300: loss=1.5244, dev loss=1.4158
# 12:50:07 Epoch 1, iteration 34400: loss=1.5269, dev loss=1.4456
# 12:50:11 Epoch 1, iteration 34500: loss=1.5053, dev loss=1.4280
# 12:50:14 Epoch 1, iteration 34600: loss=1.5203, dev loss=1.4118
# 12:50:17 Epoch 1, iteration 34700: loss=1.4978, dev loss=1.4154
# 12:50:21 Epoch 1, iteration 34800: loss=1.4975, dev loss=1.4134
# 12:50:24 Epoch 1, iteration 34900: loss=1.5377, dev loss=1.4240
# 12:50:27 Epoch 1, iteration 35000: loss=1.4969, dev loss=1.4142
# 12:50:31 Epoch 1, iteration 35100: loss=1.5298, dev loss=1.4292
# 12:50:34 Epoch 1, iteration 35200: loss=1.5245, dev loss=1.4217
# 12:50:37 Epoch 1, iteration 35300: loss=1.5266, dev loss=1.4117
# 12:50:40 Epoch 1, iteration 35400: loss=1.5241, dev loss=1.3906
# 12:50:44 Epoch 1, iteration 35500: loss=1.5084, dev loss=1.4091
# 12:50:47 Epoch 1, iteration 35600: loss=1.5113, dev loss=1.3770
# 12:50:50 Epoch 1, iteration 35700: loss=1.5100, dev loss=1.4051
# 12:50:54 Epoch 1, iteration 35800: loss=1.4957, dev loss=1.4141
# 12:50:57 Epoch 1, iteration 35900: loss=1.4982, dev loss=1.3916
# 12:51:00 Epoch 1, iteration 36000: loss=1.4950, dev loss=1.3925
# 12:51:04 Epoch 1, iteration 36100: loss=1.4851, dev loss=1.4169
# 12:51:07 Epoch 1, iteration 36200: loss=1.4854, dev loss=1.3887
# 12:51:10 Epoch 1, iteration 36300: loss=1.4936, dev loss=1.3995
# 12:51:13 Epoch 1, iteration 36400: loss=1.4881, dev loss=1.4004
# 12:51:17 Epoch 1, iteration 36500: loss=1.5064, dev loss=1.3832
# 12:51:20 Epoch 1, iteration 36600: loss=1.4960, dev loss=1.4178
# 12:51:23 Epoch 1, iteration 36700: loss=1.4704, dev loss=1.4069
# 12:51:27 Epoch 1, iteration 36800: loss=1.4702, dev loss=1.3872
# 12:51:30 Epoch 1, iteration 36900: loss=1.4864, dev loss=1.3630
# 12:51:33 Epoch 1, iteration 37000: loss=1.4961, dev loss=1.3772
# 12:51:37 Epoch 1, iteration 37100: loss=1.4778, dev loss=1.4054
# 12:51:40 Epoch 1, iteration 37200: loss=1.4699, dev loss=1.3743
# 12:51:43 Epoch 1, iteration 37300: loss=1.4852, dev loss=1.3989
# 12:51:46 Epoch 1, iteration 37400: loss=1.4645, dev loss=1.3858
# 12:51:50 Epoch 1, iteration 37500: loss=1.4671, dev loss=1.3714
# 12:51:53 Epoch 1, iteration 37600: loss=1.4781, dev loss=1.3642
# 12:51:56 Epoch 1, iteration 37700: loss=1.4614, dev loss=1.3655
# 12:51:59 Epoch 1, iteration 37800: loss=1.4424, dev loss=1.3750
# 12:52:03 Epoch 1, iteration 37900: loss=1.4554, dev loss=1.3951
# 12:52:06 Epoch 1, iteration 38000: loss=1.4682, dev loss=1.3680
# 12:52:09 Epoch 1, iteration 38100: loss=1.4634, dev loss=1.3436
# 12:52:13 Epoch 1, iteration 38200: loss=1.4792, dev loss=1.3732
# 12:52:16 Epoch 1, iteration 38300: loss=1.4652, dev loss=1.3899
# 12:52:19 Epoch 1, iteration 38400: loss=1.4663, dev loss=1.3290
# 12:52:22 Epoch 1, iteration 38500: loss=1.4598, dev loss=1.3621
# 12:52:26 Epoch 1, iteration 38600: loss=1.4620, dev loss=1.3641
# 12:52:29 Epoch 1, iteration 38700: loss=1.4548, dev loss=1.3158
# 12:52:32 Epoch 1, iteration 38800: loss=1.4708, dev loss=1.3768
# 12:52:36 Epoch 1, iteration 38900: loss=1.4676, dev loss=1.3624
# 12:52:39 Epoch 1, iteration 39000: loss=1.4447, dev loss=1.3605
# 12:52:42 Epoch 1, iteration 39100: loss=1.4333, dev loss=1.3638
# 12:52:46 Epoch 1, iteration 39200: loss=1.4320, dev loss=1.3088
# 12:52:49 Epoch 1, iteration 39300: loss=1.4590, dev loss=1.3455
# 12:52:52 Epoch 1, iteration 39400: loss=1.4329, dev loss=1.3419
# 12:52:55 Epoch 1, iteration 39500: loss=1.4470, dev loss=1.3599
# 12:52:59 Epoch 1, iteration 39600: loss=1.4319, dev loss=1.3376
# 12:53:02 Epoch 1, iteration 39700: loss=1.4325, dev loss=1.3548
# 12:53:05 Epoch 1, iteration 39800: loss=1.4448, dev loss=1.3451
# 12:53:08 Epoch 1, iteration 39900: loss=1.4378, dev loss=1.3313
# 12:53:12 Epoch 1, iteration 40000: loss=1.4465, dev loss=1.3278
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  catch          | prediction:  get            | is [MASK]?: True
# original:  excited        | prediction:  happy          | is [MASK]?: False
# original:  a              | prediction:  a              | is [MASK]?: True
# original:  and            | prediction:  and            | is [MASK]?: True
# original:  to             | prediction:  to             | is [MASK]?: True
# ------------------------------
# 12:53:15 Epoch 1, iteration 40100: loss=1.4369, dev loss=1.3233
# 12:53:18 Epoch 1, iteration 40200: loss=1.4396, dev loss=1.3353
# 12:53:22 Epoch 1, iteration 40300: loss=1.4350, dev loss=1.3249
# 12:53:25 Epoch 1, iteration 40400: loss=1.4375, dev loss=1.3415
# 12:53:28 Epoch 1, iteration 40500: loss=1.4347, dev loss=1.3292
# 12:53:32 Epoch 1, iteration 40600: loss=1.4350, dev loss=1.3353
# 12:53:35 Epoch 1, iteration 40700: loss=1.4114, dev loss=1.3390
# 12:53:38 Epoch 1, iteration 40800: loss=1.4303, dev loss=1.3143
# 12:53:41 Epoch 1, iteration 40900: loss=1.4524, dev loss=1.3250
# 12:53:45 Epoch 1, iteration 41000: loss=1.4143, dev loss=1.3240
# 12:53:48 Epoch 1, iteration 41100: loss=1.4210, dev loss=1.3540
# 12:53:51 Epoch 1, iteration 41200: loss=1.4169, dev loss=1.3290
# 12:53:55 Epoch 1, iteration 41300: loss=1.4360, dev loss=1.3138
# 12:53:58 Epoch 1, iteration 41400: loss=1.4466, dev loss=1.3248
# 12:54:01 Epoch 1, iteration 41500: loss=1.4368, dev loss=1.3287
# 12:54:04 Epoch 1, iteration 41600: loss=1.4203, dev loss=1.3406
# 12:54:08 Epoch 1, iteration 41700: loss=1.4230, dev loss=1.3457
# 12:54:11 Epoch 1, iteration 41800: loss=1.4108, dev loss=1.3093
# 12:54:14 Epoch 1, iteration 41900: loss=1.4146, dev loss=1.3264
# 12:54:17 Epoch 1, iteration 42000: loss=1.4008, dev loss=1.3359
# 12:54:21 Epoch 1, iteration 42100: loss=1.4248, dev loss=1.3195
# 12:54:24 Epoch 1, iteration 42200: loss=1.3957, dev loss=1.3217
# 12:54:27 Epoch 1, iteration 42300: loss=1.4125, dev loss=1.2992
# 12:54:31 Epoch 1, iteration 42400: loss=1.4015, dev loss=1.3151
# 12:54:34 Epoch 1, iteration 42500: loss=1.4182, dev loss=1.3158
# 12:54:37 Epoch 1, iteration 42600: loss=1.4219, dev loss=1.3159
# 12:54:40 Epoch 1, iteration 42700: loss=1.4068, dev loss=1.3439
# 12:54:44 Epoch 1, iteration 42800: loss=1.4149, dev loss=1.3212
# 12:54:47 Epoch 1, iteration 42900: loss=1.4220, dev loss=1.3234
# 12:54:50 Epoch 1, iteration 43000: loss=1.3766, dev loss=1.3008
# 12:54:53 Epoch 1, iteration 43100: loss=1.4018, dev loss=1.3085
# 12:54:57 Epoch 1, iteration 43200: loss=1.4103, dev loss=1.2733
# 12:55:00 Epoch 1, iteration 43300: loss=1.4062, dev loss=1.3083
# 12:55:03 Epoch 1, iteration 43400: loss=1.4023, dev loss=1.3132
# 12:55:06 Epoch 1, iteration 43500: loss=1.4116, dev loss=1.3189
# 12:55:10 Epoch 1, iteration 43600: loss=1.3928, dev loss=1.2999
# 12:55:13 Epoch 1, iteration 43700: loss=1.4208, dev loss=1.2852
# 12:55:16 Epoch 1, iteration 43800: loss=1.3995, dev loss=1.3051
# 12:55:20 Epoch 1, iteration 43900: loss=1.4075, dev loss=1.2819
# 12:55:23 Epoch 1, iteration 44000: loss=1.3910, dev loss=1.3070
# 12:55:26 Epoch 1, iteration 44100: loss=1.3970, dev loss=1.3098
# 12:55:29 Epoch 1, iteration 44200: loss=1.3844, dev loss=1.2909
# 12:55:33 Epoch 1, iteration 44300: loss=1.3970, dev loss=1.3035
# 12:55:36 Epoch 1, iteration 44400: loss=1.3862, dev loss=1.2830
# 12:55:39 Epoch 1, iteration 44500: loss=1.3820, dev loss=1.3195
# 12:55:42 Epoch 1, iteration 44600: loss=1.3741, dev loss=1.2962
# 12:55:46 Epoch 1, iteration 44700: loss=1.4007, dev loss=1.2650
# 12:55:49 Epoch 1, iteration 44800: loss=1.3807, dev loss=1.3034
# 12:55:52 Epoch 1, iteration 44900: loss=1.3839, dev loss=1.2586
# 12:55:56 Epoch 1, iteration 45000: loss=1.3714, dev loss=1.2736
# 12:55:59 Epoch 1, iteration 45100: loss=1.3701, dev loss=1.3007
# 12:56:02 Epoch 1, iteration 45200: loss=1.3844, dev loss=1.2775
# 12:56:05 Epoch 1, iteration 45300: loss=1.3886, dev loss=1.2804
# 12:56:09 Epoch 1, iteration 45400: loss=1.3761, dev loss=1.2658
# 12:56:12 Epoch 1, iteration 45500: loss=1.3652, dev loss=1.3137
# 12:56:15 Epoch 1, iteration 45600: loss=1.3857, dev loss=1.2891
# 12:56:18 Epoch 1, iteration 45700: loss=1.3802, dev loss=1.2873
# 12:56:22 Epoch 1, iteration 45800: loss=1.3814, dev loss=1.2995
# 12:56:25 Epoch 1, iteration 45900: loss=1.3780, dev loss=1.2706
# 12:56:28 Epoch 1, iteration 46000: loss=1.3980, dev loss=1.2675
# 12:56:32 Epoch 1, iteration 46100: loss=1.3933, dev loss=1.2960
# 12:56:35 Epoch 1, iteration 46200: loss=1.3604, dev loss=1.2583
# 12:56:38 Epoch 1, iteration 46300: loss=1.3811, dev loss=1.2841
# 12:56:41 Epoch 1, iteration 46400: loss=1.3894, dev loss=1.2921
# 12:56:45 Epoch 1, iteration 46500: loss=1.3736, dev loss=1.2514
# 12:56:48 Epoch 1, iteration 46600: loss=1.3741, dev loss=1.2506
# 12:56:51 Epoch 1, iteration 46700: loss=1.3774, dev loss=1.2850
# 12:56:54 Epoch 1, iteration 46800: loss=1.3460, dev loss=1.2815
# 12:56:58 Epoch 1, iteration 46900: loss=1.3688, dev loss=1.2871
# 12:57:01 Epoch 1, iteration 47000: loss=1.3582, dev loss=1.2669
# 12:57:04 Epoch 1, iteration 47100: loss=1.3497, dev loss=1.2536
# 12:57:07 Epoch 1, iteration 47200: loss=1.3615, dev loss=1.2844
# 12:57:11 Epoch 1, iteration 47300: loss=1.3503, dev loss=1.2716
# 12:57:14 Epoch 1, iteration 47400: loss=1.3775, dev loss=1.2502
# 12:57:17 Epoch 1, iteration 47500: loss=1.3722, dev loss=1.2647
# 12:57:21 Epoch 1, iteration 47600: loss=1.3689, dev loss=1.2544
# 12:57:24 Epoch 1, iteration 47700: loss=1.3456, dev loss=1.2718
# 12:57:27 Epoch 1, iteration 47800: loss=1.3660, dev loss=1.2798
# 12:57:30 Epoch 1, iteration 47900: loss=1.3593, dev loss=1.2292
# 12:57:34 Epoch 1, iteration 48000: loss=1.3630, dev loss=1.2430
# 12:57:37 Epoch 1, iteration 48100: loss=1.3712, dev loss=1.2464
# 12:57:40 Epoch 1, iteration 48200: loss=1.3510, dev loss=1.2490
# 12:57:43 Epoch 1, iteration 48300: loss=1.3268, dev loss=1.2410
# 12:57:47 Epoch 1, iteration 48400: loss=1.3545, dev loss=1.2476
# 12:57:50 Epoch 1, iteration 48500: loss=1.3434, dev loss=1.2933
# 12:57:53 Epoch 1, iteration 48600: loss=1.3701, dev loss=1.2808
# 12:57:56 Epoch 1, iteration 48700: loss=1.3532, dev loss=1.2361
# 12:58:00 Epoch 1, iteration 48800: loss=1.3407, dev loss=1.2378
# 12:58:03 Epoch 1, iteration 48900: loss=1.3483, dev loss=1.2599
# 12:58:06 Epoch 1, iteration 49000: loss=1.3497, dev loss=1.2458
# 12:58:10 Epoch 1, iteration 49100: loss=1.3452, dev loss=1.2432
# 12:58:13 Epoch 1, iteration 49200: loss=1.3503, dev loss=1.2721
# 12:58:16 Epoch 1, iteration 49300: loss=1.3473, dev loss=1.2436
# 12:58:19 Epoch 1, iteration 49400: loss=1.3056, dev loss=1.2265
# 12:58:23 Epoch 1, iteration 49500: loss=1.3190, dev loss=1.2539
# 12:58:26 Epoch 1, iteration 49600: loss=1.3461, dev loss=1.2156
# 12:58:29 Epoch 1, iteration 49700: loss=1.3576, dev loss=1.2453
# 12:58:32 Epoch 1, iteration 49800: loss=1.3171, dev loss=1.2382
# 12:58:36 Epoch 1, iteration 49900: loss=1.3413, dev loss=1.2500
# 12:58:39 Epoch 1, iteration 50000: loss=1.3430, dev loss=1.2734
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original: Once            | prediction: Once            | is [MASK]?: True
# original:  was            | prediction:  was            | is [MASK]?: True
# original:  to             | prediction:  to             | is [MASK]?: True
# original:  grandpa        | prediction:  grandpa        | is [MASK]?: True
# original: ,               | prediction: ,               | is [MASK]?: True
# ------------------------------
# 12:58:42 Epoch 1, iteration 50100: loss=1.3210, dev loss=1.2431
# 12:58:45 Epoch 1, iteration 50200: loss=1.3329, dev loss=1.2586
# 12:58:49 Epoch 1, iteration 50300: loss=1.3473, dev loss=1.2159
# 12:58:52 Epoch 1, iteration 50400: loss=1.3390, dev loss=1.2326
# 12:58:55 Epoch 1, iteration 50500: loss=1.3166, dev loss=1.2352
# 12:58:59 Epoch 1, iteration 50600: loss=1.3270, dev loss=1.2550
# 12:59:02 Epoch 1, iteration 50700: loss=1.3271, dev loss=1.2326
# 12:59:05 Epoch 1, iteration 50800: loss=1.3129, dev loss=1.2415
# 12:59:08 Epoch 1, iteration 50900: loss=1.3474, dev loss=1.2158
# 12:59:12 Epoch 1, iteration 51000: loss=1.3043, dev loss=1.2102
# 12:59:15 Epoch 1, iteration 51100: loss=1.3285, dev loss=1.2443
# 12:59:18 Epoch 1, iteration 51200: loss=1.3256, dev loss=1.2251
# 12:59:21 Epoch 1, iteration 51300: loss=1.3208, dev loss=1.2434
# 12:59:25 Epoch 1, iteration 51400: loss=1.3255, dev loss=1.2389
# 12:59:28 Epoch 1, iteration 51500: loss=1.3357, dev loss=1.2073
# 12:59:31 Epoch 1, iteration 51600: loss=1.3276, dev loss=1.2234
# 12:59:34 Epoch 1, iteration 51700: loss=1.3372, dev loss=1.2007
# 12:59:38 Epoch 1, iteration 51800: loss=1.3164, dev loss=1.2197
# 12:59:41 Epoch 1, iteration 51900: loss=1.3253, dev loss=1.1960
# 12:59:44 Epoch 1, iteration 52000: loss=1.3183, dev loss=1.2155
# 12:59:48 Epoch 1, iteration 52100: loss=1.3131, dev loss=1.1974
# 12:59:51 Epoch 1, iteration 52200: loss=1.3192, dev loss=1.2315
# 12:59:54 Epoch 1, iteration 52300: loss=1.3142, dev loss=1.2263
# 12:59:57 Epoch 1, iteration 52400: loss=1.3219, dev loss=1.2117
# 13:00:01 Epoch 1, iteration 52500: loss=1.3078, dev loss=1.2031
# 13:00:04 Epoch 1, iteration 52600: loss=1.3151, dev loss=1.2222
# 13:00:07 Epoch 1, iteration 52700: loss=1.3190, dev loss=1.2177
# 13:00:10 Epoch 1, iteration 52800: loss=1.2952, dev loss=1.2338
# 13:00:14 Epoch 1, iteration 52900: loss=1.3246, dev loss=1.1984
# 13:00:17 Epoch 1, iteration 53000: loss=1.3023, dev loss=1.2008
# 13:00:20 Epoch 1, iteration 53100: loss=1.3016, dev loss=1.1868
# 13:00:24 Epoch 1, iteration 53200: loss=1.2973, dev loss=1.2011
# 13:00:27 Epoch 1, iteration 53300: loss=1.3010, dev loss=1.2323
# 13:00:30 Epoch 1, iteration 53400: loss=1.3091, dev loss=1.2394
# 13:00:33 Epoch 1, iteration 53500: loss=1.3084, dev loss=1.2203
# 13:00:37 Epoch 1, iteration 53600: loss=1.2979, dev loss=1.2311
# 13:00:40 Epoch 1, iteration 53700: loss=1.3292, dev loss=1.2222
# 13:00:43 Epoch 1, iteration 53800: loss=1.3200, dev loss=1.2023
# 13:00:46 Epoch 1, iteration 53900: loss=1.2916, dev loss=1.2037
# 13:00:50 Epoch 1, iteration 54000: loss=1.2928, dev loss=1.1902
# 13:00:53 Epoch 1, iteration 54100: loss=1.3114, dev loss=1.2139
# 13:00:56 Epoch 1, iteration 54200: loss=1.2974, dev loss=1.2004
# 13:01:00 Epoch 1, iteration 54300: loss=1.3154, dev loss=1.1984
# 13:01:03 Epoch 1, iteration 54400: loss=1.2877, dev loss=1.2234
# 13:01:06 Epoch 1, iteration 54500: loss=1.3071, dev loss=1.2039
# 13:01:09 Epoch 1, iteration 54600: loss=1.2852, dev loss=1.1976
# 13:01:13 Epoch 1, iteration 54700: loss=1.3023, dev loss=1.2016
# 13:01:16 Epoch 1, iteration 54800: loss=1.3003, dev loss=1.2131
# 13:01:19 Epoch 1, iteration 54900: loss=1.3035, dev loss=1.2129
# 13:01:22 Epoch 1, iteration 55000: loss=1.3154, dev loss=1.1899
# 13:01:26 Epoch 1, iteration 55100: loss=1.3086, dev loss=1.1988
# 13:01:29 Epoch 1, iteration 55200: loss=1.3045, dev loss=1.1954
# 13:01:32 Epoch 1, iteration 55300: loss=1.2760, dev loss=1.2148
# 13:01:36 Epoch 1, iteration 55400: loss=1.2870, dev loss=1.2050
# 13:01:39 Epoch 1, iteration 55500: loss=1.2886, dev loss=1.1930
# 13:01:42 Epoch 1, iteration 55600: loss=1.2895, dev loss=1.2153
# 13:01:45 Epoch 1, iteration 55700: loss=1.2782, dev loss=1.1908
# 13:01:49 Epoch 1, iteration 55800: loss=1.2898, dev loss=1.2038
# 13:01:52 Epoch 1, iteration 55900: loss=1.2880, dev loss=1.1914
# 13:01:55 Epoch 1, iteration 56000: loss=1.3008, dev loss=1.1998
# 13:01:59 Epoch 1, iteration 56100: loss=1.2938, dev loss=1.1834
# 13:02:02 Epoch 1, iteration 56200: loss=1.3010, dev loss=1.1937
# 13:02:05 Epoch 1, iteration 56300: loss=1.2850, dev loss=1.2098
# 13:02:08 Epoch 1, iteration 56400: loss=1.2871, dev loss=1.1980
# 13:02:12 Epoch 1, iteration 56500: loss=1.2809, dev loss=1.1892
# 13:02:15 Epoch 1, iteration 56600: loss=1.2857, dev loss=1.1751
# 13:02:18 Epoch 1, iteration 56700: loss=1.2836, dev loss=1.1883
# 13:02:22 Epoch 1, iteration 56800: loss=1.2906, dev loss=1.1853
# 13:02:25 Epoch 1, iteration 56900: loss=1.2815, dev loss=1.1705
# 13:02:28 Epoch 1, iteration 57000: loss=1.2722, dev loss=1.1860
# 13:02:31 Epoch 1, iteration 57100: loss=1.2825, dev loss=1.1609
# 13:02:35 Epoch 1, iteration 57200: loss=1.2903, dev loss=1.1870
# 13:02:38 Epoch 1, iteration 57300: loss=1.2770, dev loss=1.1906
# 13:02:41 Epoch 1, iteration 57400: loss=1.2999, dev loss=1.1854
# 13:02:44 Epoch 1, iteration 57500: loss=1.2718, dev loss=1.1895
# 13:02:48 Epoch 1, iteration 57600: loss=1.2842, dev loss=1.1966
# 13:02:51 Epoch 1, iteration 57700: loss=1.2802, dev loss=1.1645
# 13:02:54 Epoch 1, iteration 57800: loss=1.2665, dev loss=1.1713
# 13:02:58 Epoch 1, iteration 57900: loss=1.2662, dev loss=1.1616
# 13:03:01 Epoch 1, iteration 58000: loss=1.2780, dev loss=1.1869
# 13:03:04 Epoch 1, iteration 58100: loss=1.2804, dev loss=1.1868
# 13:03:07 Epoch 1, iteration 58200: loss=1.2530, dev loss=1.1737
# 13:03:11 Epoch 1, iteration 58300: loss=1.2826, dev loss=1.1785
# 13:03:14 Epoch 1, iteration 58400: loss=1.2878, dev loss=1.1777
# 13:03:17 Epoch 1, iteration 58500: loss=1.2703, dev loss=1.1646
# 13:03:21 Epoch 1, iteration 58600: loss=1.2500, dev loss=1.1939
# 13:03:24 Epoch 1, iteration 58700: loss=1.2707, dev loss=1.2064
# 13:03:27 Epoch 1, iteration 58800: loss=1.2797, dev loss=1.1938
# 13:03:30 Epoch 1, iteration 58900: loss=1.2553, dev loss=1.1695
# 13:03:34 Epoch 1, iteration 59000: loss=1.2596, dev loss=1.1903
# 13:03:37 Epoch 1, iteration 59100: loss=1.2733, dev loss=1.2062
# 13:03:40 Epoch 1, iteration 59200: loss=1.2564, dev loss=1.1765
# 13:03:44 Epoch 1, iteration 59300: loss=1.2663, dev loss=1.1690
# 13:03:47 Epoch 1, iteration 59400: loss=1.2839, dev loss=1.1590
# 13:03:50 Epoch 1, iteration 59500: loss=1.2734, dev loss=1.1509
# 13:03:53 Epoch 1, iteration 59600: loss=1.2582, dev loss=1.1772
# 13:03:57 Epoch 1, iteration 59700: loss=1.2583, dev loss=1.1887
# 13:04:00 Epoch 1, iteration 59800: loss=1.2804, dev loss=1.1810
# 13:04:03 Epoch 1, iteration 59900: loss=1.2784, dev loss=1.1454
# 13:04:07 Epoch 1, iteration 60000: loss=1.2703, dev loss=1.1798
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  go             | prediction:  play           | is [MASK]?: True
# original:  with           | prediction:  with           | is [MASK]?: True
# original:  the            | prediction:  the            | is [MASK]?: False
# original:  the            | prediction:  the            | is [MASK]?: True
# original:  and            | prediction:  and            | is [MASK]?: False
# ------------------------------
# 13:04:10 Epoch 1, iteration 60100: loss=1.2697, dev loss=1.1594
# 13:04:13 Epoch 1, iteration 60200: loss=1.2433, dev loss=1.1667
# 13:04:17 Epoch 1, iteration 60300: loss=1.2615, dev loss=1.1513
# 13:04:20 Epoch 1, iteration 60400: loss=1.2554, dev loss=1.1880
# 13:04:23 Epoch 1, iteration 60500: loss=1.2730, dev loss=1.1688
# 13:04:26 Epoch 1, iteration 60600: loss=1.2585, dev loss=1.1505
# 13:04:30 Epoch 1, iteration 60700: loss=1.2587, dev loss=1.1779
# 13:04:33 Epoch 1, iteration 60800: loss=1.2464, dev loss=1.1549
# 13:04:36 Epoch 1, iteration 60900: loss=1.2512, dev loss=1.1774
# 13:04:39 Epoch 1, iteration 61000: loss=1.2523, dev loss=1.1694
# 13:04:43 Epoch 1, iteration 61100: loss=1.2587, dev loss=1.1550
# 13:04:46 Epoch 1, iteration 61200: loss=1.2422, dev loss=1.1793
# 13:04:49 Epoch 1, iteration 61300: loss=1.2643, dev loss=1.1588
# 13:04:53 Epoch 1, iteration 61400: loss=1.2499, dev loss=1.1467
# 13:04:56 Epoch 1, iteration 61500: loss=1.2560, dev loss=1.1553
# 13:04:59 Epoch 1, iteration 61600: loss=1.2603, dev loss=1.1584
# 13:05:03 Epoch 1, iteration 61700: loss=1.2461, dev loss=1.1505
# 13:05:06 Epoch 1, iteration 61800: loss=1.2572, dev loss=1.1730
# 13:05:09 Epoch 1, iteration 61900: loss=1.2579, dev loss=1.1601
# 13:05:12 Epoch 1, iteration 62000: loss=1.2460, dev loss=1.1540
# 13:05:16 Epoch 1, iteration 62100: loss=1.2439, dev loss=1.1292
# 13:05:19 Epoch 1, iteration 62200: loss=1.2666, dev loss=1.1370
# 13:05:22 Epoch 1, iteration 62300: loss=1.2553, dev loss=1.1762
# 13:05:25 Epoch 1, iteration 62400: loss=1.2292, dev loss=1.1660
# 13:05:29 Epoch 1, iteration 62500: loss=1.2281, dev loss=1.1363
# 13:05:32 Epoch 1, iteration 62600: loss=1.2428, dev loss=1.1481
# 13:05:35 Epoch 1, iteration 62700: loss=1.2532, dev loss=1.1690
# 13:05:39 Epoch 1, iteration 62800: loss=1.2495, dev loss=1.1587
# 13:05:42 Epoch 1, iteration 62900: loss=1.2501, dev loss=1.1427
# 13:05:45 Epoch 1, iteration 63000: loss=1.2572, dev loss=1.1428
# 13:05:48 Epoch 1, iteration 63100: loss=1.2560, dev loss=1.1219
# 13:05:52 Epoch 1, iteration 63200: loss=1.2412, dev loss=1.1858
# 13:05:55 Epoch 1, iteration 63300: loss=1.2396, dev loss=1.1460
# 13:05:58 Epoch 1, iteration 63400: loss=1.2509, dev loss=1.1448
# 13:06:02 Epoch 1, iteration 63500: loss=1.2400, dev loss=1.1393
# 13:06:05 Epoch 1, iteration 63600: loss=1.2446, dev loss=1.1441
# 13:06:08 Epoch 1, iteration 63700: loss=1.2400, dev loss=1.1656
# 13:06:11 Epoch 1, iteration 63800: loss=1.2379, dev loss=1.1516
# 13:06:15 Epoch 1, iteration 63900: loss=1.2565, dev loss=1.1381
# 13:06:18 Epoch 1, iteration 64000: loss=1.2179, dev loss=1.1070
# 13:06:21 Epoch 1, iteration 64100: loss=1.2366, dev loss=1.1400
# 13:06:24 Epoch 1, iteration 64200: loss=1.2325, dev loss=1.1527
# 13:06:28 Epoch 1, iteration 64300: loss=1.2482, dev loss=1.1381
# 13:06:31 Epoch 1, iteration 64400: loss=1.2438, dev loss=1.1357
# 13:06:34 Epoch 1, iteration 64500: loss=1.2319, dev loss=1.1489
# 13:06:38 Epoch 1, iteration 64600: loss=1.2228, dev loss=1.1500
# 13:06:41 Epoch 1, iteration 64700: loss=1.2292, dev loss=1.1459
# 13:06:44 Epoch 1, iteration 64800: loss=1.2423, dev loss=1.1199
# 13:06:47 Epoch 1, iteration 64900: loss=1.2266, dev loss=1.1265
# 13:06:51 Epoch 1, iteration 65000: loss=1.2407, dev loss=1.1366
# 13:06:54 Epoch 1, iteration 65100: loss=1.2506, dev loss=1.1579
# 13:06:57 Epoch 1, iteration 65200: loss=1.2246, dev loss=1.1450
# 13:07:00 Epoch 1, iteration 65300: loss=1.2493, dev loss=1.1345
# 13:07:04 Epoch 1, iteration 65400: loss=1.2578, dev loss=1.1636
# 13:07:07 Epoch 1, iteration 65500: loss=1.2353, dev loss=1.1392
# 13:07:10 Epoch 1, iteration 65600: loss=1.2275, dev loss=1.1525
# 13:07:14 Epoch 1, iteration 65700: loss=1.2302, dev loss=1.1428
# 13:07:17 Epoch 1, iteration 65800: loss=1.2237, dev loss=1.1503
# 13:07:20 Epoch 1, iteration 65900: loss=1.2522, dev loss=1.1365
# 13:07:23 Epoch 1, iteration 66000: loss=1.2238, dev loss=1.1616
# 13:07:27 Epoch 1, iteration 66100: loss=1.2299, dev loss=1.1190
# 13:07:30 Epoch 1, iteration 66200: loss=1.2197, dev loss=1.1432
# 13:07:33 Epoch 1, iteration 66300: loss=1.2260, dev loss=1.1382
# 13:07:37 Epoch 1, iteration 66400: loss=1.2287, dev loss=1.1518
# 13:07:40 Epoch 1, iteration 66500: loss=1.2377, dev loss=1.1317
# 13:07:43 Epoch 1, iteration 66600: loss=1.2023, dev loss=1.1326
# 13:07:46 Epoch 1, iteration 66700: loss=1.2396, dev loss=1.1124
# 13:07:50 Epoch 1, iteration 66800: loss=1.2027, dev loss=1.1375
# 13:07:53 Epoch 1, iteration 66900: loss=1.2280, dev loss=1.1194
# 13:07:56 Epoch 1, iteration 67000: loss=1.2239, dev loss=1.1168
# 13:07:59 Epoch 1, iteration 67100: loss=1.2272, dev loss=1.1366
# 13:08:03 Epoch 1, iteration 67200: loss=1.2206, dev loss=1.1289
# 13:08:06 Epoch 1, iteration 67300: loss=1.2147, dev loss=1.1178
# 13:08:09 Epoch 1, iteration 67400: loss=1.2246, dev loss=1.1511
# 13:08:13 Epoch 1, iteration 67500: loss=1.2450, dev loss=1.1226
# 13:08:16 Epoch 1, iteration 67600: loss=1.2175, dev loss=1.1264
# 13:08:19 Epoch 1, iteration 67700: loss=1.2314, dev loss=1.1032
# 13:08:22 Epoch 1, iteration 67800: loss=1.2104, dev loss=1.1448
# 13:08:26 Epoch 1, iteration 67900: loss=1.2279, dev loss=1.1255
# 13:08:29 Epoch 1, iteration 68000: loss=1.1993, dev loss=1.1173
# 13:08:32 Epoch 1, iteration 68100: loss=1.2329, dev loss=1.1262
# 13:08:35 Epoch 1, iteration 68200: loss=1.2286, dev loss=1.1079
# 13:08:39 Epoch 1, iteration 68300: loss=1.1979, dev loss=1.1098
# 13:08:42 Epoch 1, iteration 68400: loss=1.2373, dev loss=1.1230
# 13:08:45 Epoch 1, iteration 68500: loss=1.2306, dev loss=1.1107
# 13:08:48 Epoch 1, iteration 68600: loss=1.2353, dev loss=1.1367
# 13:08:52 Epoch 1, iteration 68700: loss=1.2299, dev loss=1.1020
# 13:08:55 Epoch 1, iteration 68800: loss=1.1993, dev loss=1.1288
# 13:08:58 Epoch 1, iteration 68900: loss=1.2103, dev loss=1.1121
# 13:09:01 Epoch 1, iteration 69000: loss=1.2144, dev loss=1.1204
# 13:09:05 Epoch 1, iteration 69100: loss=1.2138, dev loss=1.1129
# 13:09:08 Epoch 1, iteration 69200: loss=1.2226, dev loss=1.1198
# 13:09:11 Epoch 1, iteration 69300: loss=1.2009, dev loss=1.1265
# 13:09:15 Epoch 1, iteration 69400: loss=1.2150, dev loss=1.1130
# 13:09:18 Epoch 1, iteration 69500: loss=1.2189, dev loss=1.1216
# 13:09:21 Epoch 1, iteration 69600: loss=1.2037, dev loss=1.1094
# 13:09:24 Epoch 1, iteration 69700: loss=1.1996, dev loss=1.0839
# 13:09:28 Epoch 1, iteration 69800: loss=1.2236, dev loss=1.1166
# 13:09:31 Epoch 1, iteration 69900: loss=1.2224, dev loss=1.1100
# 13:09:34 Epoch 1, iteration 70000: loss=1.2023, dev loss=1.1359
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  there          | prediction:  there          | is [MASK]?: True
# original:  boy            | prediction:  boy            | is [MASK]?: False
# ...
# 13:31:32 Epoch 1, iteration 110200: loss=1.0705, dev loss=1.0018
# 13:31:35 Epoch 1, iteration 110300: loss=1.0659, dev loss=0.9933
# 13:31:38 Epoch 1, iteration 110400: loss=1.0538, dev loss=0.9954
# 13:31:42 Epoch 1, iteration 110500: loss=1.0844, dev loss=0.9713
# 13:31:45 Epoch 1, iteration 110600: loss=1.0772, dev loss=0.9887
# 13:31:48 Epoch 1, iteration 110700: loss=1.0701, dev loss=0.9949
# 13:31:51 Epoch 1, iteration 110800: loss=1.0425, dev loss=0.9895
# 13:31:55 Epoch 1, iteration 110900: loss=1.0598, dev loss=0.9715
# 13:31:58 Epoch 1, iteration 111000: loss=1.0775, dev loss=0.9877
# 13:32:01 Epoch 1, iteration 111100: loss=1.0823, dev loss=0.9782
# 13:32:04 Epoch 1, iteration 111200: loss=1.0756, dev loss=0.9774
# 13:32:08 Epoch 1, iteration 111300: loss=1.0787, dev loss=0.9809
# 13:32:11 Epoch 1, iteration 111400: loss=1.0759, dev loss=0.9796
# 13:32:14 Epoch 1, iteration 111500: loss=1.0587, dev loss=0.9634
# 13:32:17 Epoch 1, iteration 111600: loss=1.0561, dev loss=0.9712
# 13:32:21 Epoch 1, iteration 111700: loss=1.0828, dev loss=0.9975
# 13:32:24 Epoch 1, iteration 111800: loss=1.0663, dev loss=0.9909
# 13:32:27 Epoch 1, iteration 111900: loss=1.0544, dev loss=0.9946
# 13:32:31 Epoch 1, iteration 112000: loss=1.0734, dev loss=0.9865
# 13:32:34 Epoch 1, iteration 112100: loss=1.0799, dev loss=0.9718
# 13:32:37 Epoch 1, iteration 112200: loss=1.0736, dev loss=0.9768
# 13:32:40 Epoch 1, iteration 112300: loss=1.0707, dev loss=0.9708
# 13:32:44 Epoch 1, iteration 112400: loss=1.0659, dev loss=0.9776
# 13:32:47 Epoch 1, iteration 112500: loss=1.0720, dev loss=1.0009
# 13:32:50 Epoch 1, iteration 112600: loss=1.0734, dev loss=0.9824
# 13:32:54 Epoch 1, iteration 112700: loss=1.0594, dev loss=0.9746
# 13:32:57 Epoch 1, iteration 112800: loss=1.0762, dev loss=0.9896
# 13:33:00 Epoch 1, iteration 112900: loss=1.0719, dev loss=0.9861
# 13:33:03 Epoch 1, iteration 113000: loss=1.0709, dev loss=0.9839
# 13:33:07 Epoch 1, iteration 113100: loss=1.0553, dev loss=0.9648
# 13:33:10 Epoch 1, iteration 113200: loss=1.0691, dev loss=0.9647
# 13:33:13 Epoch 1, iteration 113300: loss=1.0682, dev loss=0.9676
# 13:33:16 Epoch 1, iteration 113400: loss=1.0663, dev loss=0.9703
# 13:33:20 Epoch 1, iteration 113500: loss=1.0738, dev loss=0.9770
# 13:33:23 Epoch 1, iteration 113600: loss=1.0709, dev loss=0.9744
# 13:33:26 Epoch 1, iteration 113700: loss=1.0733, dev loss=0.9949
# 13:33:30 Epoch 1, iteration 113800: loss=1.0479, dev loss=0.9923
# 13:33:33 Epoch 1, iteration 113900: loss=1.0656, dev loss=0.9888
# 13:33:36 Epoch 1, iteration 114000: loss=1.0707, dev loss=0.9804
# 13:33:39 Epoch 1, iteration 114100: loss=1.0485, dev loss=0.9676
# 13:33:43 Epoch 1, iteration 114200: loss=1.0535, dev loss=0.9608
# 13:33:46 Epoch 1, iteration 114300: loss=1.0650, dev loss=1.0000
# 13:33:49 Epoch 1, iteration 114400: loss=1.0787, dev loss=0.9567
# 13:33:52 Epoch 1, iteration 114500: loss=1.0712, dev loss=1.0022
# 13:33:56 Epoch 1, iteration 114600: loss=1.0596, dev loss=0.9889
# 13:33:59 Epoch 1, iteration 114700: loss=1.0622, dev loss=0.9756
# 13:34:02 Epoch 1, iteration 114800: loss=1.0755, dev loss=0.9817
# 13:34:05 Epoch 1, iteration 114900: loss=1.0678, dev loss=0.9541
# 13:34:09 Epoch 1, iteration 115000: loss=1.0653, dev loss=0.9762
# 13:34:12 Epoch 1, iteration 115100: loss=1.0582, dev loss=0.9659
# 13:34:15 Epoch 1, iteration 115200: loss=1.0657, dev loss=0.9792
# 13:34:18 Epoch 1, iteration 115300: loss=1.0661, dev loss=0.9491
# 13:34:22 Epoch 1, iteration 115400: loss=1.0706, dev loss=0.9854
# 13:34:25 Epoch 1, iteration 115500: loss=1.0782, dev loss=0.9895
# 13:34:28 Epoch 1, iteration 115600: loss=1.0616, dev loss=0.9644
# 13:34:31 Epoch 1, iteration 115700: loss=1.0606, dev loss=0.9851
# 13:34:34 Epoch 1, iteration 115800: loss=1.0535, dev loss=0.9600
# 13:34:38 Epoch 1, iteration 115900: loss=1.0578, dev loss=0.9935
# 13:34:41 Epoch 1, iteration 116000: loss=1.0961, dev loss=0.9631
# 13:34:44 Epoch 1, iteration 116100: loss=1.0587, dev loss=0.9736
# 13:34:47 Epoch 1, iteration 116200: loss=1.0736, dev loss=0.9595
# 13:34:51 Epoch 1, iteration 116300: loss=1.0616, dev loss=0.9537
# 13:34:54 Epoch 1, iteration 116400: loss=1.0516, dev loss=0.9634
# 13:34:57 Epoch 1, iteration 116500: loss=1.0561, dev loss=0.9666
# 13:35:00 Epoch 1, iteration 116600: loss=1.0636, dev loss=0.9720
# 13:35:04 Epoch 1, iteration 116700: loss=1.0664, dev loss=0.9604
# 13:35:07 Epoch 1, iteration 116800: loss=1.0526, dev loss=0.9667
# 13:35:10 Epoch 1, iteration 116900: loss=1.0719, dev loss=0.9594
# 13:35:13 Epoch 1, iteration 117000: loss=1.0882, dev loss=0.9952
# 13:35:17 Epoch 1, iteration 117100: loss=1.0712, dev loss=0.9683
# 13:35:20 Epoch 1, iteration 117200: loss=1.0532, dev loss=0.9705
# 13:35:23 Epoch 1, iteration 117300: loss=1.0599, dev loss=0.9455
# 13:35:26 Epoch 1, iteration 117400: loss=1.0568, dev loss=0.9606
# 13:35:30 Epoch 1, iteration 117500: loss=1.0457, dev loss=0.9664
# 13:35:33 Epoch 1, iteration 117600: loss=1.0528, dev loss=0.9675
# 13:35:36 Epoch 1, iteration 117700: loss=1.0484, dev loss=0.9637
# 13:35:39 Epoch 1, iteration 117800: loss=1.0644, dev loss=0.9529
# 13:35:43 Epoch 1, iteration 117900: loss=1.0675, dev loss=0.9706
# 13:35:46 Epoch 1, iteration 118000: loss=1.0484, dev loss=0.9682
# 13:35:49 Epoch 1, iteration 118100: loss=1.0686, dev loss=0.9668
# 13:35:52 Epoch 1, iteration 118200: loss=1.0622, dev loss=0.9845
# 13:35:56 Epoch 1, iteration 118300: loss=1.0550, dev loss=0.9783
# 13:35:59 Epoch 1, iteration 118400: loss=1.0588, dev loss=0.9753
# 13:36:02 Epoch 1, iteration 118500: loss=1.0673, dev loss=0.9721
# 13:36:05 Epoch 1, iteration 118600: loss=1.0594, dev loss=0.9770
# 13:36:09 Epoch 1, iteration 118700: loss=1.0662, dev loss=0.9560
# 13:36:12 Epoch 1, iteration 118800: loss=1.0506, dev loss=0.9708
# 13:36:15 Epoch 1, iteration 118900: loss=1.0422, dev loss=0.9616
# 13:36:18 Epoch 1, iteration 119000: loss=1.0143, dev loss=0.9761
# 13:36:21 Epoch 1, iteration 119100: loss=1.0472, dev loss=0.9846
# 13:36:25 Epoch 1, iteration 119200: loss=1.0660, dev loss=0.9856
# 13:36:28 Epoch 1, iteration 119300: loss=1.0606, dev loss=0.9541
# 13:36:31 Epoch 1, iteration 119400: loss=1.0589, dev loss=0.9323
# 13:36:34 Epoch 1, iteration 119500: loss=1.0473, dev loss=0.9746
# 13:36:38 Epoch 1, iteration 119600: loss=1.0571, dev loss=0.9530
# 13:36:41 Epoch 1, iteration 119700: loss=1.0524, dev loss=0.9575
# 13:36:44 Epoch 1, iteration 119800: loss=1.0440, dev loss=0.9756
# 13:36:47 Epoch 1, iteration 119900: loss=1.0310, dev loss=0.9723
# 13:36:50 Epoch 1, iteration 120000: loss=1.0451, dev loss=0.9568
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  Timmy          | prediction:  Timmy          | is [MASK]?: True
# original: .               | prediction: .               | is [MASK]?: True
# original:  lake           | prediction:  lake           | is [MASK]?: True
# original:  excited        | prediction:  excited        | is [MASK]?: True
# original:  fishing        | prediction:  fishing        | is [MASK]?: True
# ------------------------------
# 13:36:54 Epoch 1, iteration 120100: loss=1.0483, dev loss=0.9667
# 13:36:57 Epoch 1, iteration 120200: loss=1.0603, dev loss=0.9541
# 13:37:00 Epoch 1, iteration 120300: loss=1.0495, dev loss=0.9571
# 13:37:03 Epoch 1, iteration 120400: loss=1.0432, dev loss=0.9621
# 13:37:07 Epoch 1, iteration 120500: loss=1.0540, dev loss=0.9501
# 13:37:10 Epoch 1, iteration 120600: loss=1.0599, dev loss=0.9585
# 13:37:13 Epoch 1, iteration 120700: loss=1.0403, dev loss=0.9738
# 13:37:16 Epoch 1, iteration 120800: loss=1.0303, dev loss=0.9573
# 13:37:19 Epoch 1, iteration 120900: loss=1.0525, dev loss=0.9589
# 13:37:23 Epoch 1, iteration 121000: loss=1.0343, dev loss=0.9501
# 13:37:26 Epoch 1, iteration 121100: loss=1.0516, dev loss=0.9689
# 13:37:29 Epoch 1, iteration 121200: loss=1.0439, dev loss=0.9541
# 13:37:32 Epoch 1, iteration 121300: loss=1.0574, dev loss=0.9796
# 13:37:35 Epoch 1, iteration 121400: loss=1.0527, dev loss=0.9443
# 13:37:39 Epoch 1, iteration 121500: loss=1.0494, dev loss=0.9431
# 13:37:42 Epoch 1, iteration 121600: loss=1.0410, dev loss=0.9571
# 13:37:45 Epoch 1, iteration 121700: loss=1.0410, dev loss=0.9660
# 13:37:48 Epoch 1, iteration 121800: loss=1.0475, dev loss=0.9409
# 13:37:51 Epoch 1, iteration 121900: loss=1.0488, dev loss=0.9604
# 13:37:54 Epoch 1, iteration 122000: loss=1.0499, dev loss=0.9439
# 13:37:57 Epoch 1, iteration 122100: loss=1.0526, dev loss=0.9829
# 13:38:01 Epoch 1, iteration 122200: loss=1.0363, dev loss=0.9554
# 13:38:04 Epoch 1, iteration 122300: loss=1.0483, dev loss=0.9445
# 13:38:07 Epoch 1, iteration 122400: loss=1.0372, dev loss=0.9646
# 13:38:10 Epoch 1, iteration 122500: loss=1.0708, dev loss=0.9429
# 13:38:13 Epoch 1, iteration 122600: loss=1.0322, dev loss=0.9562
# 13:38:16 Epoch 1, iteration 122700: loss=1.0357, dev loss=0.9569
# 13:38:20 Epoch 1, iteration 122800: loss=1.0492, dev loss=0.9653
# 13:38:23 Epoch 1, iteration 122900: loss=1.0601, dev loss=0.9564
# 13:38:26 Epoch 1, iteration 123000: loss=1.0605, dev loss=0.9739
# 13:38:29 Epoch 1, iteration 123100: loss=1.0489, dev loss=0.9615
# 13:38:32 Epoch 1, iteration 123200: loss=1.0423, dev loss=0.9440
# 13:38:35 Epoch 1, iteration 123300: loss=1.0434, dev loss=0.9464
# 13:38:39 Epoch 1, iteration 123400: loss=1.0546, dev loss=0.9522
# 13:38:42 Epoch 1, iteration 123500: loss=1.0540, dev loss=0.9640
# 13:38:45 Epoch 1, iteration 123600: loss=1.0536, dev loss=0.9662
# 13:38:48 Epoch 1, iteration 123700: loss=1.0553, dev loss=0.9550
# 13:38:51 Epoch 1, iteration 123800: loss=1.0534, dev loss=0.9704
# 13:38:54 Epoch 1, iteration 123900: loss=1.0416, dev loss=0.9746
# 13:38:58 Epoch 1, iteration 124000: loss=1.0282, dev loss=0.9648
# 13:39:01 Epoch 1, iteration 124100: loss=1.0342, dev loss=0.9611
# 13:39:04 Epoch 1, iteration 124200: loss=1.0474, dev loss=0.9314
# 13:39:07 Epoch 1, iteration 124300: loss=1.0312, dev loss=0.9500
# 13:39:10 Epoch 1, iteration 124400: loss=1.0453, dev loss=0.9569
# 13:39:13 Epoch 1, iteration 124500: loss=1.0279, dev loss=0.9337
# 13:39:17 Epoch 1, iteration 124600: loss=1.0504, dev loss=0.9428
# 13:39:20 Epoch 1, iteration 124700: loss=1.0504, dev loss=0.9364
# 13:39:23 Epoch 1, iteration 124800: loss=1.0530, dev loss=0.9661
# 13:39:26 Epoch 1, iteration 124900: loss=1.0540, dev loss=0.9467
# 13:39:29 Epoch 1, iteration 125000: loss=1.0357, dev loss=0.9711
# 13:39:32 Epoch 1, iteration 125100: loss=1.0504, dev loss=0.9588
# 13:39:35 Epoch 1, iteration 125200: loss=1.0368, dev loss=0.9292
# 13:39:39 Epoch 1, iteration 125300: loss=1.0340, dev loss=0.9627
# 13:39:42 Epoch 1, iteration 125400: loss=1.0399, dev loss=0.9567
# 13:39:45 Epoch 1, iteration 125500: loss=1.0298, dev loss=0.9717
# 13:39:48 Epoch 1, iteration 125600: loss=1.0651, dev loss=0.9332
# 13:39:51 Epoch 1, iteration 125700: loss=1.0192, dev loss=0.9570
# 13:39:55 Epoch 1, iteration 125800: loss=1.0540, dev loss=0.9408
# 13:39:58 Epoch 1, iteration 125900: loss=1.0595, dev loss=0.9619
# 13:40:01 Epoch 1, iteration 126000: loss=1.0491, dev loss=0.9718
# 13:40:04 Epoch 1, iteration 126100: loss=1.0374, dev loss=0.9168
# 13:40:08 Epoch 1, iteration 126200: loss=1.0507, dev loss=0.9354
# 13:40:11 Epoch 1, iteration 126300: loss=1.0337, dev loss=0.9497
# 13:40:14 Epoch 1, iteration 126400: loss=1.0485, dev loss=0.9451
# 13:40:17 Epoch 1, iteration 126500: loss=1.0470, dev loss=0.9523
# 13:40:21 Epoch 1, iteration 126600: loss=1.0403, dev loss=0.9386
# 13:40:24 Epoch 1, iteration 126700: loss=1.0298, dev loss=0.9396
# 13:40:27 Epoch 1, iteration 126800: loss=1.0334, dev loss=0.9486
# 13:40:30 Epoch 1, iteration 126900: loss=1.0483, dev loss=0.9696
# 13:40:34 Epoch 1, iteration 127000: loss=1.0390, dev loss=0.9521
# 13:40:37 Epoch 1, iteration 127100: loss=1.0325, dev loss=0.9624
# 13:40:40 Epoch 1, iteration 127200: loss=1.0473, dev loss=0.9556
# 13:40:43 Epoch 1, iteration 127300: loss=1.0480, dev loss=0.9543
# 13:40:47 Epoch 1, iteration 127400: loss=1.0339, dev loss=0.9300
# 13:40:50 Epoch 1, iteration 127500: loss=1.0331, dev loss=0.9291
# 13:40:53 Epoch 1, iteration 127600: loss=1.0441, dev loss=0.9382
# 13:40:56 Epoch 1, iteration 127700: loss=1.0389, dev loss=0.9508
# 13:41:00 Epoch 1, iteration 127800: loss=1.0393, dev loss=0.9293
# 13:41:03 Epoch 1, iteration 127900: loss=1.0213, dev loss=0.9217
# 13:41:06 Epoch 1, iteration 128000: loss=1.0330, dev loss=0.9384
# 13:41:10 Epoch 1, iteration 128100: loss=1.0603, dev loss=0.9786
# 13:41:13 Epoch 1, iteration 128200: loss=1.0286, dev loss=0.9490
# 13:41:16 Epoch 1, iteration 128300: loss=1.0226, dev loss=0.9482
# 13:41:19 Epoch 1, iteration 128400: loss=1.0399, dev loss=0.9513
# 13:41:23 Epoch 1, iteration 128500: loss=1.0360, dev loss=0.9585
# 13:41:26 Epoch 1, iteration 128600: loss=1.0256, dev loss=0.9552
# 13:41:29 Epoch 1, iteration 128700: loss=1.0449, dev loss=0.9454
# 13:41:32 Epoch 1, iteration 128800: loss=1.0432, dev loss=0.9517
# 13:41:36 Epoch 1, iteration 128900: loss=1.0540, dev loss=0.9453
# 13:41:39 Epoch 1, iteration 129000: loss=1.0388, dev loss=0.9328
# 13:41:42 Epoch 1, iteration 129100: loss=1.0331, dev loss=0.9557
# 13:41:45 Epoch 1, iteration 129200: loss=1.0438, dev loss=0.9504
# 13:41:49 Epoch 1, iteration 129300: loss=1.0336, dev loss=0.9525
# 13:41:52 Epoch 1, iteration 129400: loss=1.0115, dev loss=0.9507
# 13:41:55 Epoch 1, iteration 129500: loss=1.0524, dev loss=0.9217
# 13:41:58 Epoch 1, iteration 129600: loss=1.0364, dev loss=0.9337
# 13:42:02 Epoch 1, iteration 129700: loss=1.0408, dev loss=0.9484
# 13:42:05 Epoch 1, iteration 129800: loss=1.0343, dev loss=0.9562
# 13:42:08 Epoch 1, iteration 129900: loss=1.0370, dev loss=0.9625
# 13:42:11 Epoch 1, iteration 130000: loss=1.0205, dev loss=0.9394
# Checkpoint saved to last_checkpoint_unmasking_2.pt
# ------------------------------
# original:  a              | prediction:  a              | is [MASK]?: True
# original: ,               | prediction: ,               | is [MASK]?: True
# original:  boy            | prediction:  boy            | is [MASK]?: True
# original:  loved          | prediction:  loved          | is [MASK]?: True
# original:  go             | prediction:  go             | is [MASK]?: True
# ------------------------------
# 13:42:15 Epoch 1, iteration 130100: loss=1.0357, dev loss=0.9523
# 13:42:18 Epoch 1, iteration 130200: loss=1.0335, dev loss=0.9496
# 13:42:21 Epoch 1, iteration 130300: loss=1.0349, dev loss=0.9366
# 13:42:25 Epoch 1, iteration 130400: loss=1.0306, dev loss=0.9402
# 13:42:28 Epoch 1, iteration 130500: loss=1.0471, dev loss=0.9232
# 13:42:31 Epoch 1, iteration 130600: loss=1.0153, dev loss=0.9443
# 13:42:34 Epoch 1, iteration 130700: loss=1.0394, dev loss=0.9542
# 13:42:38 Epoch 1, iteration 130800: loss=1.0111, dev loss=0.9468
# 13:42:41 Epoch 1, iteration 130900: loss=1.0228, dev loss=0.9466
# 13:42:44 Epoch 1, iteration 131000: loss=1.0285, dev loss=0.9414
# 13:42:47 Epoch 1, iteration 131100: loss=1.0373, dev loss=0.9547
# 13:42:51 Epoch 1, iteration 131200: loss=1.0224, dev loss=0.9513
# 13:42:54 Epoch 1, iteration 131300: loss=1.0393, dev loss=0.9428
# 13:42:57 Epoch 1, iteration 131400: loss=1.0296, dev loss=0.9551
# 13:43:01 Epoch 1, iteration 131500: loss=1.0090, dev loss=0.9526
# 13:43:04 Epoch 1, iteration 131600: loss=1.0356, dev loss=0.9604
# 13:43:07 Epoch 1, iteration 131700: loss=1.0381, dev loss=0.9417
# 13:43:10 Epoch 1, iteration 131800: loss=1.0424, dev loss=0.9395
# 13:43:14 Epoch 1, iteration 131900: loss=1.0329, dev loss=0.9354
# 13:43:17 Epoch 1, iteration 132000: loss=1.0129, dev loss=0.9288
# 13:43:20 Epoch 1, iteration 132100: loss=1.0178, dev loss=0.9397
# 13:43:23 Epoch 1, iteration 132200: loss=1.0306, dev loss=0.9527
# 13:43:27 Epoch 1, iteration 132300: loss=1.0282, dev loss=0.9384
# 13:43:30 Epoch 1, iteration 132400: loss=1.0219, dev loss=0.9395
# 13:43:33 Epoch 1, iteration 132500: loss=1.0462, dev loss=0.9514
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 90
#      86 loss.backward() # gradients
#      87 lm_optimizer.step() # update weights
# ---> 90 running_loss += loss.detach().item()
#      91 iteration += 1
#      92 if iteration%100 == 0:
#      93     # Compute validation loss every 100 iterations
#      94     # CHANGE
#
# KeyboardInterrupt:

# %% [markdown]
# ### Use the model to generate stories
# Try varying the prompt, max tokens, temperature, and top-k sampling to study the effects.

# %%
### MODIFY ###

def predict_masked(model, tokenizer, prompt="The cat sat in the chair that was by the lake."):
    model.eval()
    device = next(model.parameters()).device
    mask_token_id = tokenizer.vocab_size - 1  
    
    _, token_ids = tokenizer.tokenize(prompt)
    token_ids = torch.tensor(token_ids, dtype=torch.long, device=device)
    
    # manual amsk
    masked_input = token_ids.clone()
    positions_to_mask = [7, 9] 
    for pos in positions_to_mask:
        masked_input[pos] = mask_token_id
    
    # forward pass
    with torch.no_grad():
        logits = model(masked_input.unsqueeze(0))  
        predictions = logits.argmax(dim=-1).squeeze(0) 
    
  
    print("-" * 40)
    print(f"Prompt: {prompt}")
    print("-" * 40)
    for pos in positions_to_mask:
            original_word  = tokenizer.vocab[token_ids[pos].item()]
            predicted_word = tokenizer.vocab[predictions[pos].item()]
            is_masked = (masked_input[pos].item() == mask_token_id)
            print(f" Position {pos}: original='{original_word}' | predicted='{predicted_word}' | is [MASK]?: {is_masked}")
    print("-" * 40)

checkpoint_path = "last_checkpoint_unmasking.pt"
tokenizer_path = "/content/tokenizer.json"
tokenizer_path = "/datasets/dd2417/tokenizer.json"

tokenizer = TinyStoriesTokenizer.load(tokenizer_path)
# Add [MASK] to tokens
mask_token = "[MASK]"
if mask_token not in tokenizer.vocab:
    tokenizer.vocab.append(mask_token)
    tokenizer.vocab_size += 1
mask_id = len(tokenizer.vocab) - 1  # new token for unmasking


model = TinyStoriesLM.load(checkpoint_path, device='cuda')
print(f"Tokenizer vocab_size: {tokenizer.vocab_size}")
print(f"Model vocab_size: {model.config.vocab_size}")

predict_masked(model, tokenizer)

# %%
print(mask_id)
