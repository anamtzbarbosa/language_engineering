# %% [markdown]
# ## SET is_causal = TRUE in Settings

# %%
import torch
import torch.nn as nn
from Settings import TinyStoriesLM
from datetime import datetime
import random
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

from tokenizer import TinyStoriesTokenizer
from torch.utils.data import Dataset, DataLoader
from dataclasses import dataclass, asdict
import numpy as np
import os
print("cell ran")
# Out:
# cell ran

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000  # This number should agree with the tokenizer
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 1
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1


class TinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        # Pull a chunk of length block_size + 1 (data and target)
        chunk = self.data[idx : idx + self.block_size + 1]

        # Convert to torch tensors
        x = torch.from_numpy(chunk[:-1].astype(np.int64)) # Input
        y = torch.from_numpy(chunk[1:].astype(np.int64))  # Target (shifted by 1)

        return x, y 


class ProbeDataset(Dataset):
    def __init__(self, data, tensor_tags, index_range, limit=512, ignore_index = -100):
        self.data = data
        self.limit = limit
        self.index_range = list(index_range)
        self.tensor_tags = tensor_tags
        self.ignore_index = ignore_index
        #self.pos_to_id = pos_to_id

    def __len__(self):
        return len(self.index_range)

    def __getitem__(self, idx):
        idx_true = self.index_range[idx]
    
        # when we built tensors, we bactch (0, 512, 1024, 1536...)
        # To get the real position
        dataset_index = idx_true * self.limit

        # Extract binary file
        item = self.data[dataset_index]
        input_ids = item[0][:self.limit] 
        
        # from tensor tags
        labels = self.tensor_tags[idx_true][:self.limit].clone()
        labels[labels < 3] = self.ignore_index
        
        return {
            'input_ids': input_ids,
            'labels': labels
        }

print("probedataset ready")
# Out:
# probedataset ready

# %%
# We load the aligned data
tensores_tags_dataset = torch.load('tags_probes_5k_first_subtoken.pt')
POS_TAGS_VOCAB = [
    'PAD', 'SUBWORD', 'X', 'ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 
    'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 
    'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB'
]
tag2id = {tag: idx for idx, tag in enumerate(POS_TAGS_VOCAB)}
id2tag = {idx: tag for tag, idx in tag2id.items()}
ignore_index = -100
print(f"{len(tensores_tags_dataset)} tensors for Probing.")
# Out:
# 5000 tensors for Probing.

# %%
import json

with open("multipos_dict.json", "r") as f:
    multipos_dict = json.load(f)

print("cell ran")
# Out:
# cell ran

# %%
#alto

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
checkpoint_path = 'last_checkpoint_next_word.pt'

model = TinyStoriesLM.load(checkpoint_path, device=device).to(device)
training_dataset = TinyStoriesDataset('/datasets/dd2417/train.bin', Config.block_size)
tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')

# We have to freeze all the model
for param in model.parameters():
    param.requires_grad = False

# We set our model i eval mode -> deactivate dropout  so the vectors are stable
# dropout turns off random neurons during training to avoid overfitting/memorizing 
model.eval() #same input = same output

activations = {}

def forward_hook(module, input, output): # hook function
    # 'output' - ouput from Transformer layer
    # module layer that was just executed
    # save in our dictionary
    # .detach() no gradient info / history - we just want numbers
    
    if isinstance(output, tuple):
        activations[module.name] = output[0].detach()
    else:
        activations[module.name] = output.detach()

hooks = []

# register each block (TransformerBlock)
for i, block in enumerate(model.transformers):
    block.name = f"layer_{i}" 
    handle = block.register_forward_hook(forward_hook)
    hooks.append(handle)


num_tags = len(tag2id)
input_dim = model.config.vector_dim
limit = model.config.block_size
num_layers = len(model.transformers)

# from 5,000 stories -> 4500 train and 500 validate
# data for training
train_subset_tags = tensores_tags_dataset[:4500]
val_subset_tags = tensores_tags_dataset[4500:]

# index_range to ensure aligment
train_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(0, 4500), limit=limit)
train_loader = DataLoader(train_ds, batch_size=model.config.batch_size, shuffle=True)

val_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(4500, 5000), limit=limit)
val_loader = DataLoader(val_ds, batch_size=model.config.batch_size, shuffle=False)
# Out:
# Model loaded from last_checkpoint_next_word.pt (Epoch 0, iteration 130000)

# %%
print(f"Subsets : training: {len(train_ds)} | validation: {len(val_ds)}")

output_dir = os.path.join("plts", "next_word")
os.makedirs(output_dir, exist_ok=True)
target_words = [' so', ' playing', ' back', ' it', ' he']
evolution_tracking = {word: {} for word in target_words}

# Global accumulation 
all_general_acc = []
all_ambiguous_acc = []
all_general_pres = []
all_ambiguous_pres = []
all_general_rec = []
all_ambiguous_rec = []
all_general_f1 = []
all_ambiguous_f1 = []

# loop through each layer representation
for layer_to_probe in range(num_layers):
    layer_name = f"layer_{layer_to_probe}"
    print(f"\nTraining probe of: {layer_name}")

    # Reset linear probing for current layer
    probe = nn.Linear(input_dim, num_tags).to(device)
    optimizer = torch.optim.Adam(probe.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=ignore_index)

    # Epochs
    for epoch in range(3):
        probe.train()
        for batch in train_loader:
            activations.clear()
            ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            with torch.no_grad():
                model(ids) 

            optimizer.zero_grad()
            logits = probe(activations[layer_name])
   
            loss = criterion(logits.view(-1, num_tags), labels.view(-1))
            loss.backward()
            optimizer.step()

        # Validation phase
        probe.eval()
        
        all_preds_general = []
        all_labels_general = []
        all_preds_ambiguous = []
        all_labels_ambiguous = []
        
        with torch.no_grad():
            for v_batch in val_loader:
                v_ids = v_batch['input_ids'].to(device)
                v_labels = v_batch['labels'].to(device)
                
                model(v_ids)
                v_logits = probe(activations[layer_name])
                predictions = v_logits.argmax(dim=-1)

                v_probs = torch.softmax(v_logits, dim=-1)
                top_3_probs, top_3_idx = torch.topk(v_probs, k=3, dim=-1)  

                # Only not ignored elements
                mask = (v_labels != ignore_index)
                all_preds_general.extend(predictions[mask].cpu().tolist())
                all_labels_general.extend(v_labels[mask].cpu().tolist())

                for b in range(v_ids.size(0)):
                    ids_list = v_ids[b].tolist()
                    tokens = tokenizer.decode_to_tokens(ids_list)
                    
                    for t in range(len(tokens)):
                        label_real = v_labels[b, t].item()
                        if label_real == ignore_index:
                            continue 
                        
                        current_word = tokens[t] 
    
                        # Qualitative log (final epoch only)
                        if epoch == 2 and current_word in target_words:
                            inicio_contexto = max(0, t - 5)
                            fin_contexto = min(len(ids_list), t + 5)
                            texto_antes = tokenizer.decode(ids_list[inicio_contexto: t])
                            frase_id = f"{texto_antes} *[{current_word.upper().strip()}]*"

                            if frase_id not in evolution_tracking[current_word]:
                                evolution_tracking[current_word][frase_id] = {}
                            
                            pred_label = predictions[b, t].item()
                            top_3_lista = top_3_idx[b, t].tolist()
                            top_3_tags = [id2tag[idx] for idx in top_3_lista]
                            top_3_probs_list = top_3_probs[b, t].tolist()
                            percentages = [p * 100 for p in top_3_probs_list]
                                
                            evolution_tracking[current_word][frase_id][layer_name] = {
                                "real_tag": id2tag[label_real],
                                "pred_tag": id2tag[pred_label],
                                "top_3_tags": top_3_tags,
                                "percentages": percentages
                            }
                                
                        # Collect ambiguous info
                        if current_word in multipos_dict:
                            pred_label = predictions[b, t].item()
                            all_preds_ambiguous.append(pred_label)
                            all_labels_ambiguous.append(label_real)

        # Filter to strip subwordsl tags (0, 1, 2)
        valid_indices = [i for i, lbl in enumerate(all_labels_general) if lbl >= 3]
        all_labels_general = [all_labels_general[i] for i in valid_indices]
        all_preds_general = [all_preds_general[i] for i in valid_indices]
        unique_valid_labels = sorted(list(set(all_labels_general + all_preds_general)))

        # General evaluations
        epoch_accuracy = accuracy_score(all_labels_general, all_preds_general) * 100
        gen_prec, gen_rec, gen_f1, _ = precision_recall_fscore_support(
            all_labels_general, all_preds_general, labels=unique_valid_labels, average='macro', zero_division=0
        )
        epoch_precision = gen_prec * 100
        epoch_recall = gen_rec * 100
        epoch_f1 = gen_f1 * 100
        
        # Ambiguous subset evaluations (also ignore 0,1,2)
        amb_valid_labels = sorted(list(set([l for l in all_labels_ambiguous + all_preds_ambiguous if l >= 3])))
        if len(all_labels_ambiguous) > 0 and len(amb_valid_labels) > 0:
            epoch_ambiguity_accuracy = accuracy_score(all_labels_ambiguous, all_preds_ambiguous) * 100
            amb_prec, amb_rec, amb_f1, _ = precision_recall_fscore_support(
                all_labels_ambiguous, all_preds_ambiguous, labels = amb_valid_labels, average='macro', zero_division=0
            )
            epoch_amb_precision = amb_prec * 100
            epoch_amb_recall = amb_rec * 100
            epoch_amb_f1 = amb_f1 * 100
        else:
            epoch_ambiguity_accuracy, epoch_amb_precision, epoch_amb_recall, epoch_amb_f1 = 0.0, 0.0, 0.0, 0.0
       
        print(f" Epoch {epoch + 1} [General]   accuracy: {epoch_accuracy:.2f}% | precision: {epoch_precision:.2f}% | recall: {epoch_recall:.2f}% | F1: {epoch_f1:.2f}%")
        print(f" Epoch {epoch + 1} [Ambiguous] accuracy: {epoch_ambiguity_accuracy:.2f}% | precision: {epoch_amb_precision:.2f}% | recall: {epoch_amb_recall:.2f}% | F1: {epoch_amb_f1:.2f}%")
        
        # confusion data to numpy arrays
        if epoch == 2:
            tag_names = [id2tag[idx] for idx in unique_valid_labels]
            cm = confusion_matrix(all_labels_general, all_preds_general, labels=unique_valid_labels, normalize='true')
            matrix_data = {
                "matrix": cm,
                "tag_names": tag_names,
                "tag_ids": unique_valid_labels
            }
            
            matrix_path = os.path.join(output_dir, f'matrix_data_{layer_name}.npy')
            np.save(matrix_path, matrix_data, allow_pickle=True)
            print(f" -- Saved matrix array data to: {matrix_path} --")

    # Log for line plot 
    all_general_acc.append(epoch_accuracy)
    all_ambiguous_acc.append(epoch_ambiguity_accuracy)
    all_general_pres.append(epoch_precision)
    all_ambiguous_pres.append(epoch_amb_precision)
    all_general_rec.append(epoch_recall)
    all_ambiguous_rec.append(epoch_amb_recall)
    all_general_f1.append(epoch_f1)
    all_ambiguous_f1.append(epoch_amb_f1)
    
    print(f"="*70) 

# Disconnect hooks
for handle in hooks:
    handle.remove()

# metrics to json
experiment_results = {
    "metadata": {
        "num_layers": num_layers,
        "target_words": target_words
    },
    "general_metrics": {
        "layers": [f"layer_{i}" for i in range(num_layers)],
        "accuracy": all_general_acc,
        "precision": all_general_pres,
        "recall": all_general_rec,
        "f1_score": all_general_f1
    },
    "ambiguous_metrics": {
        "accuracy": all_ambiguous_acc,
        "precision": all_ambiguous_pres,
        "recall": all_ambiguous_rec,
        "f1_score": all_ambiguous_f1
    },
    "evolution_tracking": evolution_tracking
}

json_path = os.path.join(output_dir, "probing_results.json")
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(experiment_results, f, ensure_ascii=False, indent=4)

print("cell ran")
# Out:
# Subsets : training: 4500 | validation: 500
#
# Training probe of: layer_0
#  Epoch 1 [General]   accuracy: 96.20% | precision: 94.72% | recall: 95.32% | F1: 94.99%
#  Epoch 1 [Ambiguous] accuracy: 94.76% | precision: 91.59% | recall: 93.35% | F1: 92.34%
#  Epoch 2 [General]   accuracy: 96.57% | precision: 95.48% | recall: 95.72% | F1: 95.58%
#  Epoch 2 [Ambiguous] accuracy: 95.24% | precision: 92.60% | recall: 93.72% | F1: 93.08%
#  Epoch 3 [General]   accuracy: 96.73% | precision: 95.80% | recall: 95.84% | F1: 95.81%
#  Epoch 3 [Ambiguous] accuracy: 95.45% | precision: 93.36% | recall: 93.60% | F1: 93.46%
#  -- Saved matrix array data to: plts/next_word/matrix_data_layer_0.npy --
# ======================================================================
#
# Training probe of: layer_1
#  Epoch 1 [General]   accuracy: 97.10% | precision: 96.23% | recall: 96.04% | F1: 96.13%
#  Epoch 1 [Ambiguous] accuracy: 96.07% | precision: 94.23% | recall: 94.07% | F1: 94.14%
#  Epoch 2 [General]   accuracy: 97.36% | precision: 96.66% | recall: 96.52% | F1: 96.59%
#  Epoch 2 [Ambiguous] accuracy: 96.39% | precision: 94.64% | recall: 94.71% | F1: 94.65%
#  Epoch 3 [General]   accuracy: 97.44% | precision: 96.79% | recall: 96.64% | F1: 96.71%
#  Epoch 3 [Ambiguous] accuracy: 96.49% | precision: 94.82% | recall: 94.85% | F1: 94.82%
#  -- Saved matrix array data to: plts/next_word/matrix_data_layer_1.npy --
# ======================================================================
#
# Training probe of: layer_2
#  Epoch 1 [General]   accuracy: 97.39% | precision: 96.84% | recall: 96.47% | F1: 96.65%
#  Epoch 1 [Ambiguous] accuracy: 96.60% | precision: 95.27% | recall: 94.67% | F1: 94.96%
#  Epoch 2 [General]   accuracy: 97.64% | precision: 97.14% | recall: 96.88% | F1: 97.01%
#  Epoch 2 [Ambiguous] accuracy: 96.88% | precision: 95.64% | recall: 95.20% | F1: 95.42%
#  Epoch 3 [General]   accuracy: 97.71% | precision: 97.25% | recall: 96.92% | F1: 97.08%
#  Epoch 3 [Ambiguous] accuracy: 96.94% | precision: 95.78% | recall: 95.22% | F1: 95.49%
#  -- Saved matrix array data to: plts/next_word/matrix_data_layer_2.npy --
# ======================================================================
#
# Training probe of: layer_3
#  Epoch 1 [General]   accuracy: 96.93% | precision: 96.19% | recall: 95.76% | F1: 95.97%
#  Epoch 1 [Ambiguous] accuracy: 96.21% | precision: 94.55% | recall: 93.95% | F1: 94.24%
#  Epoch 2 [General]   accuracy: 97.21% | precision: 96.46% | recall: 96.34% | F1: 96.40%
#  Epoch 2 [Ambiguous] accuracy: 96.49% | precision: 94.84% | recall: 94.64% | F1: 94.74%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 34
#      32 activations.clear()
#      33 ids = batch['input_ids'].to(device)
# ---> 34 labels = batch['labels'].to(device)
#      36 with torch.no_grad():
#      37     model(ids)
#
# KeyboardInterrupt:

# %%
fixed_rand_phrases = {}

for word, contexts in evolution_tracking.items():
    phrase_list = list(contexts.keys())
    phrase_list = sorted(phrase_list) # base order
    random.seed(103)
    num_elements = min(5, len(phrase_list)) # if any element has less than 5
    selected_phrases = random.sample(phrase_list, num_elements)
    fixed_rand_phrases[word] = selected_phrases

for word, phrases in fixed_rand_phrases.items():
    print("-"*50)
    print(f"Ambiguous Word: {repr(word)}")
    for phrase_id in phrases: # each dif phrase from that ambiguous word
       layers = evolution_tracking[word][phrase_id]
       print("-"*50)
       print(f"Sentence ... {phrase_id}") 
       for layer_name in sorted(layers.keys()):
           info = layers[layer_name]
           print(f"{layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']}")
           print(f" Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | Top 3: {info['top_3_tags'][2]} ({info['percentages'][2]:.1f}%)")
            
    print("")

# %%
for word, contexts in evolution_tracking.items():
    print("=" * 80)
    print(f"SEARCHING HIGH-UNCERTAINTY CASES FOR: {repr(word)}")
    print("=" * 80)
    
    match_count = 0
    
    for phrase_id, layers in contexts.items():
        # Verificamos si en AL MENOS una capa el Top 2 superó el 20%
        has_high_uncertainty = any(layers[layer]['percentages'][1] > 20.0 for layer in layers)
        
        if has_high_uncertainty:
            match_count += 1
            print(f"\n[Case #{match_count}] Sentence: {phrase_id}")
            print("-" * 60)
            
            # Mostramos cómo evolucionó la duda capa por capa en esta frase
            for layer_name in sorted(layers.keys()):
                info = layers[layer_name]
                
                # Alerta visual si esta capa específica es la que causó la duda
                alert = "⚠️" if info['percentages'][1] > 20.0 else "   "
                
                print(f"  {layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']} {alert}")
                print(f"    Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | "
                      f"Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | ")
            print("-" * 60)
            
    if match_count == 0:
        print(f"No rare cases found for {repr(word)} with Top 2 > 10% in this run.\n")
    else:
        print(f"✅ Found {match_count} interesting cases for {repr(word)}.\n")
# Out:
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' so'
# ================================================================================
#
# [Case #1] Sentence:  for it to breathe, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (80.0%) | Top 2: SCONJ (17.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.8%) | Top 2: SCONJ (36.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.4%) | Top 2: SCONJ (22.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (80.1%) | Top 2: SCONJ (14.3%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  was an ancient symbol, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.0%) | Top 2: SCONJ (9.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.2%) | Top 2: SCONJ (29.6%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.1%) | Top 2: SCONJ (5.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (93.3%) | Top 2: SCONJ (3.5%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  wanted to include everyone, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.9%) | Top 2: SCONJ (12.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (70.3%) | Top 2: SCONJ (26.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.9%) | Top 2: SCONJ (28.9%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (53.6%) | Top 2: SCONJ (43.6%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  mad but also sad, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.3%) | Top 2: SCONJ (11.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.7%) | Top 2: SCONJ (21.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (79.3%) | Top 2: NOUN (8.9%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.0%) | Top 2: NOUN (31.1%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  extra careful with his water *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (92.5%) | Top 2: SCONJ (3.8%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (66.0%) | Top 2: ADV (32.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (95.3%) | Top 2: ADV (4.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (93.1%) | Top 2: ADV (4.2%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  was excited to help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.5%) | Top 2: SCONJ (11.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.3%) | Top 2: SCONJ (24.6%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.5%) | Top 2: SCONJ (2.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (88.4%) | Top 2: SCONJ (8.0%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  Let me restore your leg *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (94.4%) | Top 2: SCONJ (2.9%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (59.3%) | Top 2: SCONJ (39.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.6%) | Top 2: ADV (8.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (79.9%) | Top 2: ADV (17.3%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  the tasty fruit behind, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (89.3%) | Top 2: SCONJ (8.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.9%) | Top 2: SCONJ (13.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.8%) | Top 2: SCONJ (25.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (43.7%) | Top 2: SCONJ (32.8%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  eat in their home, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (89.2%) | Top 2: SCONJ (9.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (83.3%) | Top 2: SCONJ (13.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.7%) | Top 2: SCONJ (34.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.2%) | Top 2: SCONJ (30.1%) |
# ------------------------------------------------------------
#
# [Case #10] Sentence:  should take care of it *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.5%) | Top 2: SCONJ (6.1%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (61.5%) | Top 2: SCONJ (37.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (94.9%) | Top 2: ADV (4.6%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.8%) | Top 2: ADV (13.6%) |
# ------------------------------------------------------------
#
# [Case #11] Sentence:  that belonged to her, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (89.0%) | Top 2: SCONJ (9.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.8%) | Top 2: SCONJ (21.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (89.2%) | Top 2: SCONJ (9.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (75.7%) | Top 2: SCONJ (18.2%) |
# ------------------------------------------------------------
#
# [Case #12] Sentence:  let me comb your hair *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.7%) | Top 2: SCONJ (4.0%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (70.5%) | Top 2: ADV (28.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.2%) | Top 2: ADV (8.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.0%) | Top 2: ADV (15.7%) |
# ------------------------------------------------------------
#
# [Case #13] Sentence:  Bobo loved melons, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (93.7%) | Top 2: SCONJ (5.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.6%) | Top 2: SCONJ (5.4%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.7%) | Top 2: SCONJ (2.8%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.0%) | Top 2: SCONJ (39.6%) |
# ------------------------------------------------------------
#
# [Case #14] Sentence: . Lily got thirsty, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (90.8%) | Top 2: SCONJ (7.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.8%) | Top 2: SCONJ (20.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.2%) | Top 2: SCONJ (43.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.3%) | Top 2: SCONJ (37.9%) |
# ------------------------------------------------------------
#
# [Case #15] Sentence:  be careful with her juice *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.4%) | Top 2: SCONJ (4.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (55.4%) | Top 2: ADV (43.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.1%) | Top 2: ADV (13.9%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (98.8%) | Top 2: ADV (0.9%) |
# ------------------------------------------------------------
#
# [Case #16] Sentence:  see in the fog, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.4%) | Top 2: SCONJ (14.1%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (59.2%) | Top 2: ADV (38.9%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (92.7%) | Top 2: ADV (5.2%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (87.3%) | Top 2: ADV (10.3%) |
# ------------------------------------------------------------
#
# [Case #17] Sentence:  her house to Tom's house *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.0%) | Top 2: SCONJ (7.1%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (53.3%) | Top 2: SCONJ (46.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.4%) | Top 2: ADV (24.7%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.7%) | Top 2: ADV (12.3%) |
# ------------------------------------------------------------
#
# [Case #18] Sentence:  to protect his family, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (81.2%) | Top 2: SCONJ (15.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (53.5%) | Top 2: SCONJ (44.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.5%) | Top 2: SCONJ (23.3%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (60.4%) | Top 2: ADV (37.2%) |
# ------------------------------------------------------------
#
# [Case #19] Sentence:  little duck, who was *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: VERB
#     Top 1: ADV (91.5%) | Top 2: SCONJ (6.9%) |
#   layer_1 | Pred: ADV | True: VERB
#     Top 1: ADV (93.8%) | Top 2: SCONJ (4.5%) |
#   layer_2 | Pred: ADV | True: VERB
#     Top 1: ADV (93.3%) | Top 2: VERB (3.9%) |
#   layer_3 | Pred: ADV | True: VERB ⚠️
#     Top 1: ADV (65.2%) | Top 2: VERB (25.3%) |
# ------------------------------------------------------------
#
# [Case #20] Sentence:  book with her friends, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.8%) | Top 2: SCONJ (9.4%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (67.0%) | Top 2: SCONJ (26.2%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.4%) | Top 2: SCONJ (4.4%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.5%) | Top 2: SCONJ (3.8%) |
# ------------------------------------------------------------
#
# [Case #21] Sentence:  in the warm ocean, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.1%) | Top 2: SCONJ (8.7%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.4%) | Top 2: SCONJ (38.8%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (59.2%) | Top 2: ADV (39.9%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (64.0%) | Top 2: ADV (35.5%) |
# ------------------------------------------------------------
#
# [Case #22] Sentence:  started to feel sleepy, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.3%) | Top 2: SCONJ (11.7%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (52.7%) | Top 2: ADV (40.4%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (48.7%) | Top 2: ADV (34.4%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (54.5%) | Top 2: SCONJ (39.4%) |
# ------------------------------------------------------------
#
# [Case #23] Sentence:  was feeling much better, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (85.5%) | Top 2: SCONJ (13.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (78.9%) | Top 2: SCONJ (16.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (47.7%) | Top 2: SCONJ (33.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.4%) | Top 2: SCONJ (44.0%) |
# ------------------------------------------------------------
#
# [Case #24] Sentence:  all day long. And *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (96.4%) | Top 2: SCONJ (2.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.5%) | Top 2: SCONJ (1.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (98.3%) | Top 2: NOUN (1.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.4%) | Top 2: NOUN (26.4%) |
# ------------------------------------------------------------
#
# [Case #25] Sentence: , *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (62.2%) | Top 2: SCONJ (31.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (83.8%) | Top 2: SCONJ (11.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.3%) | Top 2: SCONJ (6.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (92.7%) | Top 2: SCONJ (5.5%) |
# ------------------------------------------------------------
#
# [Case #26] Sentence:  to climb the tree, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (81.7%) | Top 2: SCONJ (15.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.2%) | Top 2: SCONJ (20.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (5.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.5%) | Top 2: SCONJ (5.4%) |
# ------------------------------------------------------------
#
# [Case #27] Sentence:  scared of spiders, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (86.8%) | Top 2: SCONJ (11.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.8%) | Top 2: SCONJ (24.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (94.3%) | Top 2: SCONJ (3.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (99.6%) | Top 2: SCONJ (0.2%) |
# ------------------------------------------------------------
#
# [Case #28] Sentence:  seek, and they had *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.6%) | Top 2: SCONJ (8.7%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.6%) | Top 2: SCONJ (20.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (97.7%) | Top 2: SCONJ (1.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: SCONJ (5.3%) |
# ------------------------------------------------------------
#
# [Case #29] Sentence:  was scaring the baby *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (95.5%) | Top 2: SCONJ (3.2%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.6%) | Top 2: SCONJ (7.4%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.7%) | Top 2: SCONJ (31.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (49.4%) | Top 2: ADV (47.6%) |
# ------------------------------------------------------------
#
# [Case #30] Sentence:  the things in the refrigerator *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.6%) | Top 2: SCONJ (6.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (61.7%) | Top 2: ADV (37.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (97.6%) | Top 2: ADV (2.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (93.6%) | Top 2: ADV (4.7%) |
# ------------------------------------------------------------
#
# [Case #31] Sentence:  to make something special, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (90.1%) | Top 2: SCONJ (7.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.0%) | Top 2: SCONJ (27.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (77.4%) | Top 2: SCONJ (17.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.6%) | Top 2: SCONJ (6.4%) |
# ------------------------------------------------------------
#
# [Case #32] Sentence:  was cold, they had *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (7.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (86.5%) | Top 2: SCONJ (10.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.1%) | Top 2: SCONJ (20.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (89.2%) | Top 2: SCONJ (6.8%) |
# ------------------------------------------------------------
#
# [Case #33] Sentence:  to chase the cat, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (93.1%) | Top 2: SCONJ (4.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (94.7%) | Top 2: SCONJ (3.6%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.6%) | Top 2: SCONJ (2.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (45.1%) | Top 2: CCONJ (37.9%) |
# ------------------------------------------------------------
#
# [Case #34] Sentence:  had to be careful, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (92.3%) | Top 2: SCONJ (6.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.0%) | Top 2: SCONJ (27.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (79.5%) | Top 2: SCONJ (11.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.6%) | Top 2: CCONJ (23.7%) |
# ------------------------------------------------------------
#
# [Case #35] Sentence:  to supply it with gas *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.2%) | Top 2: SCONJ (6.0%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (54.2%) | Top 2: SCONJ (43.7%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.7%) | Top 2: ADV (13.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.9%) | Top 2: ADV (8.3%) |
# ------------------------------------------------------------
#
# [Case #36] Sentence:  parents with his address *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.3%) | Top 2: SCONJ (7.5%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.0%) | Top 2: SCONJ (29.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (51.8%) | Top 2: SCONJ (47.5%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (65.3%) | Top 2: SCONJ (33.2%) |
# ------------------------------------------------------------
#
# [Case #37] Sentence: . Tim was worried, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.0%) | Top 2: SCONJ (22.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (77.6%) | Top 2: SCONJ (15.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (62.1%) | Top 2: SCONJ (26.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (79.4%) | Top 2: SCONJ (15.6%) |
# ------------------------------------------------------------
#
# [Case #38] Sentence:  was getting very upset, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.8%) | Top 2: SCONJ (24.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (80.2%) | Top 2: SCONJ (15.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (73.3%) | Top 2: SCONJ (9.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (50.6%) | Top 2: SCONJ (36.9%) |
# ------------------------------------------------------------
#
# [Case #39] Sentence:  to go to work, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.8%) | Top 2: SCONJ (22.8%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (66.6%) | Top 2: ADV (28.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.8%) | Top 2: SCONJ (23.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.7%) | Top 2: SCONJ (7.0%) |
# ------------------------------------------------------------
#
# [Case #40] Sentence:  in a safe place, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.5%) | Top 2: SCONJ (10.3%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.1%) | Top 2: SCONJ (24.1%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.3%) | Top 2: SCONJ (17.0%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (70.9%) | Top 2: SCONJ (22.2%) |
# ------------------------------------------------------------
#
# [Case #41] Sentence:  you back to your house *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.7%) | Top 2: SCONJ (3.8%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (65.8%) | Top 2: SCONJ (33.2%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.5%) | Top 2: ADV (10.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.7%) | Top 2: ADV (15.9%) |
# ------------------------------------------------------------
#
# [Case #42] Sentence:  The gloomy day was not *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.2%) | Top 2: SCONJ (0.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (99.5%) | Top 2: SCONJ (0.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (98.2%) | Top 2: VERB (0.9%) |
#   layer_3 | Pred: VERB | True: ADV ⚠️
#     Top 1: VERB (56.5%) | Top 2: ADV (40.0%) |
# ------------------------------------------------------------
#
# [Case #43] Sentence:  wanted to help her, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (85.6%) | Top 2: SCONJ (12.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (89.6%) | Top 2: SCONJ (8.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: SCONJ (7.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.6%) | Top 2: SCONJ (24.2%) |
# ------------------------------------------------------------
#
# [Case #44] Sentence:  help Tim feel better, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ
#     Top 1: ADV (87.9%) | Top 2: SCONJ (10.9%) |
#   layer_1 | Pred: ADV | True: CCONJ
#     Top 1: ADV (78.7%) | Top 2: SCONJ (14.9%) |
#   layer_2 | Pred: ADV | True: CCONJ
#     Top 1: ADV (67.0%) | Top 2: SCONJ (18.0%) |
#   layer_3 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (47.2%) | Top 2: SCONJ (27.6%) |
# ------------------------------------------------------------
#
# [Case #45] Sentence:  "I will release you *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (95.2%) | Top 2: SCONJ (2.9%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.5%) | Top 2: SCONJ (15.4%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (54.5%) | Top 2: SCONJ (45.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (77.9%) | Top 2: ADV (21.4%) |
# ------------------------------------------------------------
#
# [Case #46] Sentence:  was careful when she danced *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (97.2%) | Top 2: SCONJ (2.2%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (79.2%) | Top 2: SCONJ (20.5%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.1%) | Top 2: SCONJ (12.7%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.2%) | Top 2: SCONJ (8.5%) |
# ------------------------------------------------------------
#
# [Case #47] Sentence:  wanted to read it, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (79.8%) | Top 2: SCONJ (16.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.4%) | Top 2: SCONJ (30.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (80.1%) | Top 2: SCONJ (12.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.7%) | Top 2: SCONJ (2.0%) |
# ------------------------------------------------------------
#
# [Case #48] Sentence:  how strong he was, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (89.6%) | Top 2: SCONJ (9.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.0%) | Top 2: SCONJ (20.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.5%) | Top 2: CCONJ (3.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (70.8%) | Top 2: SCONJ (12.0%) |
# ------------------------------------------------------------
#
# [Case #49] Sentence:  feel a bit chilly *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (93.0%) | Top 2: SCONJ (5.7%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.5%) | Top 2: SCONJ (22.9%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.7%) | Top 2: SCONJ (22.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (86.6%) | Top 2: SCONJ (8.3%) |
# ------------------------------------------------------------
#
# [Case #50] Sentence:  bit chilly too, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (81.4%) | Top 2: SCONJ (16.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (77.5%) | Top 2: SCONJ (18.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (70.7%) | Top 2: CCONJ (9.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (53.8%) | Top 2: SCONJ (20.8%) |
# ------------------------------------------------------------
#
# [Case #51] Sentence: aved very well, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (81.1%) | Top 2: SCONJ (16.0%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.8%) | Top 2: SCONJ (25.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.6%) | Top 2: SCONJ (30.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.3%) | Top 2: SCONJ (26.0%) |
# ------------------------------------------------------------
#
# [Case #52] Sentence:  had to slow down, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (80.8%) | Top 2: SCONJ (15.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.2%) | Top 2: SCONJ (31.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (79.6%) | Top 2: SCONJ (16.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.4%) | Top 2: SCONJ (5.8%) |
# ------------------------------------------------------------
#
# [Case #53] Sentence:  see what was inside, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (86.2%) | Top 2: SCONJ (11.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.9%) | Top 2: SCONJ (22.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (84.9%) | Top 2: SCONJ (10.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (88.7%) | Top 2: SCONJ (8.4%) |
# ------------------------------------------------------------
#
# [Case #54] Sentence:  keep the rock. And *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.8%) | Top 2: SCONJ (2.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (95.2%) | Top 2: SCONJ (3.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.9%) | Top 2: NOUN (4.5%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.6%) | Top 2: NOUN (33.5%) |
# ------------------------------------------------------------
#
# [Case #55] Sentence:  the hanger was special, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.6%) | Top 2: SCONJ (9.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (84.8%) | Top 2: SCONJ (13.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (82.0%) | Top 2: SCONJ (14.0%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (68.7%) | Top 2: ADV (27.4%) |
# ------------------------------------------------------------
#
# [Case #56] Sentence:  to tie your hair back *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.4%) | Top 2: SCONJ (4.7%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (54.6%) | Top 2: ADV (44.8%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.9%) | Top 2: ADV (26.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (95.6%) | Top 2: ADV (4.2%) |
# ------------------------------------------------------------
#
# [Case #57] Sentence: ! But, after eating *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (77.3%) | Top 2: SCONJ (18.8%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.0%) | Top 2: SCONJ (27.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (81.1%) | Top 2: SCONJ (16.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (86.9%) | Top 2: NOUN (5.8%) |
# ------------------------------------------------------------
#
# [Case #58] Sentence:  to be tidy and organized *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (92.1%) | Top 2: SCONJ (7.0%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (84.2%) | Top 2: SCONJ (15.5%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (65.8%) | Top 2: SCONJ (33.9%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.2%) | Top 2: SCONJ (15.3%) |
# ------------------------------------------------------------
#
# [Case #59] Sentence:  and tied him up outside *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.3%) | Top 2: SCONJ (6.9%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (60.8%) | Top 2: SCONJ (38.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (80.5%) | Top 2: ADV (19.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.5%) | Top 2: ADV (9.8%) |
# ------------------------------------------------------------
#
# [Case #60] Sentence:  "You need to bathe *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.0%) | Top 2: SCONJ (6.7%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (78.1%) | Top 2: SCONJ (20.3%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (75.7%) | Top 2: SCONJ (23.5%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (86.8%) | Top 2: SCONJ (7.2%) |
# ------------------------------------------------------------
#
# [Case #61] Sentence:  him about snakes, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (79.3%) | Top 2: SCONJ (19.1%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.6%) | Top 2: ADV (39.8%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (45.8%) | Top 2: ADV (43.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (54.9%) | Top 2: SCONJ (30.2%) |
# ------------------------------------------------------------
#
# [Case #62] Sentence:  to learn new things, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.5%) | Top 2: SCONJ (9.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.8%) | Top 2: SCONJ (24.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.4%) | Top 2: SCONJ (36.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.4%) | Top 2: SCONJ (32.2%) |
# ------------------------------------------------------------
#
# [Case #63] Sentence:  know, but it's locked *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (94.0%) | Top 2: SCONJ (4.9%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (80.3%) | Top 2: SCONJ (19.1%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.0%) | Top 2: SCONJ (25.4%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (96.4%) | Top 2: SCONJ (3.1%) |
# ------------------------------------------------------------
#
# [Case #64] Sentence:  listen to her mom, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.4%) | Top 2: SCONJ (27.1%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (67.9%) | Top 2: ADV (30.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.8%) | Top 2: SCONJ (21.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.0%) | Top 2: SCONJ (24.9%) |
# ------------------------------------------------------------
#
# [Case #65] Sentence:  books back on the bookcase *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (95.3%) | Top 2: SCONJ (3.2%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (52.1%) | Top 2: SCONJ (47.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (92.3%) | Top 2: ADV (7.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (68.4%) | Top 2: ADV (27.4%) |
# ------------------------------------------------------------
#
# [Case #66] Sentence:  the mysterious box was not *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (98.9%) | Top 2: SCONJ (0.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (99.4%) | Top 2: SCONJ (0.4%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: VERB (3.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.2%) | Top 2: VERB (22.7%) |
# ------------------------------------------------------------
#
# [Case #67] Sentence:  and were very quiet, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.3%) | Top 2: SCONJ (8.7%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (73.2%) | Top 2: SCONJ (24.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (63.5%) | Top 2: ADV (34.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (62.6%) | Top 2: ADV (35.2%) |
# ------------------------------------------------------------
#
# [Case #68] Sentence:  glass to the kitchen, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (65.0%) | Top 2: SCONJ (28.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (72.3%) | Top 2: ADV (23.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (76.1%) | Top 2: ADV (18.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (73.5%) | Top 2: ADV (17.3%) |
# ------------------------------------------------------------
#
# [Case #69] Sentence: illed it had given him *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.5%) | Top 2: SCONJ (12.7%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.8%) | Top 2: SCONJ (25.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (94.0%) | Top 2: SCONJ (5.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (98.1%) | Top 2: SCONJ (1.6%) |
# ------------------------------------------------------------
#
# [Case #70] Sentence:  happy to see them, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (86.4%) | Top 2: SCONJ (12.5%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.3%) | Top 2: SCONJ (23.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (96.9%) | Top 2: SCONJ (1.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.2%) | Top 2: SCONJ (2.7%) |
# ------------------------------------------------------------
#
# [Case #71] Sentence:  his room clean and tidy *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.9%) | Top 2: SCONJ (4.7%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (54.2%) | Top 2: SCONJ (45.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (64.1%) | Top 2: ADV (32.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (48.2%) | Top 2: ADV (28.5%) |
# ------------------------------------------------------------
#
# [Case #72] Sentence:  to help the boy, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.0%) | Top 2: SCONJ (12.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.6%) | Top 2: SCONJ (21.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.4%) | Top 2: SCONJ (4.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: SCONJ (5.9%) |
# ------------------------------------------------------------
#
# [Case #73] Sentence:  her mom for help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (82.9%) | Top 2: SCONJ (14.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.1%) | Top 2: SCONJ (25.0%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.8%) | Top 2: SCONJ (23.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (61.1%) | Top 2: SCONJ (31.9%) |
# ------------------------------------------------------------
#
# [Case #74] Sentence:  what was hiding inside, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (91.8%) | Top 2: SCONJ (6.8%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.4%) | Top 2: SCONJ (20.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (82.5%) | Top 2: SCONJ (13.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (85.7%) | Top 2: SCONJ (8.0%) |
# ------------------------------------------------------------
#
# [Case #75] Sentence:  town was very modern, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.7%) | Top 2: SCONJ (14.4%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.9%) | Top 2: SCONJ (9.3%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (77.1%) | Top 2: SCONJ (21.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (49.1%) | Top 2: ADV (47.6%) |
# ------------------------------------------------------------
#
# [Case #76] Sentence:  But his mom insisted, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (90.1%) | Top 2: SCONJ (8.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.5%) | Top 2: SCONJ (10.3%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.6%) | Top 2: SCONJ (20.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.4%) | Top 2: SCONJ (1.7%) |
# ------------------------------------------------------------
#
# [Case #77] Sentence:  It started to rain, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.2%) | Top 2: SCONJ (9.5%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.6%) | Top 2: SCONJ (20.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.0%) | Top 2: SCONJ (39.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (94.0%) | Top 2: SCONJ (2.2%) |
# ------------------------------------------------------------
#
# [Case #78] Sentence:  that Timmy needed support, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (79.1%) | Top 2: SCONJ (18.8%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.4%) | Top 2: SCONJ (32.9%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.2%) | Top 2: SCONJ (29.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.1%) | Top 2: SCONJ (22.5%) |
# ------------------------------------------------------------
#
# [Case #79] Sentence:  decided to practice every day *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (96.0%) | Top 2: SCONJ (3.0%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (69.8%) | Top 2: SCONJ (29.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (55.1%) | Top 2: ADV (44.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (79.8%) | Top 2: ADV (19.7%) |
# ------------------------------------------------------------
#
# [Case #80] Sentence:  The ball was harmless, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (94.9%) | Top 2: SCONJ (4.2%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.7%) | Top 2: SCONJ (7.0%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.5%) | Top 2: SCONJ (16.7%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (47.1%) | Top 2: ADV (38.7%) |
# ------------------------------------------------------------
#
# [Case #81] Sentence:  to supply it with power *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.6%) | Top 2: SCONJ (5.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (64.0%) | Top 2: ADV (35.1%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (69.2%) | Top 2: SCONJ (30.6%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (72.7%) | Top 2: SCONJ (26.3%) |
# ------------------------------------------------------------
#
# [Case #82] Sentence:  Let's put it in there *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (96.1%) | Top 2: SCONJ (2.5%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (78.0%) | Top 2: ADV (21.5%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (96.2%) | Top 2: ADV (3.3%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (90.5%) | Top 2: VERB (4.3%) |
# ------------------------------------------------------------
#
# [Case #83] Sentence:  are too small to shine *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (96.4%) | Top 2: SCONJ (2.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (89.6%) | Top 2: SCONJ (9.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.7%) | Top 2: SCONJ (22.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (89.0%) | Top 2: SCONJ (10.6%) |
# ------------------------------------------------------------
#
# [Case #84] Sentence:  big and strong, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ
#     Top 1: ADV (82.9%) | Top 2: SCONJ (10.7%) |
#   layer_1 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (59.8%) | Top 2: SCONJ (37.5%) |
#   layer_2 | Pred: ADV | True: CCONJ
#     Top 1: ADV (84.1%) | Top 2: SCONJ (13.4%) |
#   layer_3 | Pred: ADV | True: CCONJ
#     Top 1: ADV (81.1%) | Top 2: SCONJ (16.6%) |
# ------------------------------------------------------------
#
# [Case #85] Sentence:  Ann asked for help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.9%) | Top 2: SCONJ (20.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.7%) | Top 2: SCONJ (9.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (97.4%) | Top 2: SCONJ (2.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (99.1%) | Top 2: SCONJ (0.5%) |
# ------------------------------------------------------------
#
# [Case #86] Sentence:  Ellie was very hungry, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (97.0%) | Top 2: SCONJ (2.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (5.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.0%) | Top 2: SCONJ (21.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.7%) | Top 2: SCONJ (44.5%) |
# ------------------------------------------------------------
#
# [Case #87] Sentence:  The toast and butter smelled *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.2%) | Top 2: SCONJ (3.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.1%) | Top 2: SCONJ (2.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: SCONJ (2.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.3%) | Top 2: ADP (21.6%) |
# ------------------------------------------------------------
#
# [Case #88] Sentence:  that he was sad, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.5%) | Top 2: SCONJ (21.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.3%) | Top 2: SCONJ (6.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.0%) | Top 2: SCONJ (3.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.0%) | Top 2: SCONJ (1.4%) |
# ------------------------------------------------------------
#
# [Case #89] Sentence:  take care of special things *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.6%) | Top 2: SCONJ (4.8%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (81.3%) | Top 2: SCONJ (18.1%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (56.4%) | Top 2: SCONJ (43.3%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (61.5%) | Top 2: SCONJ (22.8%) |
# ------------------------------------------------------------
#
# [Case #90] Sentence:  correctly, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (90.9%) | Top 2: SCONJ (7.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.4%) | Top 2: SCONJ (41.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.6%) | Top 2: SCONJ (29.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (48.1%) | Top 2: SCONJ (44.6%) |
# ------------------------------------------------------------
#
# [Case #91] Sentence: ! We can make it *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.3%) | Top 2: SCONJ (3.0%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.2%) | Top 2: SCONJ (21.7%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (50.3%) | Top 2: ADV (48.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (54.4%) | Top 2: SCONJ (38.0%) |
# ------------------------------------------------------------
#
# [Case #92] Sentence: " Mia's friends agreed, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.9%) | Top 2: SCONJ (14.8%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (81.3%) | Top 2: SCONJ (14.3%) |
# ...
#
# [Case #6] Sentence:  bottle had a number on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: NOUN (0.5%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.3%) | Top 2: NOUN (0.6%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.8%) | Top 2: NOUN (2.2%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (54.0%) | Top 2: PRON (45.9%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  and learned. She tried *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.0%) | Top 2: ADV (0.9%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (62.5%) | Top 2: VERB (27.5%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  of salt and sprinkled *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: NOUN (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: ADV (0.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (54.3%) | Top 2: VERB (22.8%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  stick with a cut on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (96.6%) | Top 2: NOUN (3.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (82.7%) | Top 2: NOUN (17.2%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (73.2%) | Top 2: PRON (26.5%) |
# ------------------------------------------------------------
#
# [Case #10] Sentence:  put her favorite dress on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: NOUN (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.3%) | Top 2: NOUN (0.6%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (96.2%) | Top 2: NOUN (3.7%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (59.2%) | Top 2: NOUN (39.8%) |
# ------------------------------------------------------------
#
# [Case #11] Sentence:  dress with big eyes on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: NOUN (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (98.8%) | Top 2: NOUN (1.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.9%) | Top 2: NOUN (1.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (68.1%) | Top 2: NOUN (31.4%) |
# ------------------------------------------------------------
#
# [Case #12] Sentence:  It has big eyes on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: NOUN (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.0%) | Top 2: NOUN (0.9%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.8%) | Top 2: NOUN (2.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (58.2%) | Top 2: NOUN (38.3%) |
# ------------------------------------------------------------
#
# [Case #13] Sentence:  know if she could do *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: NOUN (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: ADV (0.3%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (55.0%) | Top 2: VERB (38.3%) |
# ------------------------------------------------------------
#
# [Case #14] Sentence:  the lake had poison in *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: NOUN (0.4%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (94.4%) | Top 2: NOUN (5.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.6%) | Top 2: NOUN (25.4%) |
# ------------------------------------------------------------
#
# [Case #15] Sentence:  box with a lock on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: NOUN (0.5%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (98.2%) | Top 2: NOUN (1.6%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.6%) | Top 2: NOUN (1.4%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (76.6%) | Top 2: NOUN (23.3%) |
# ------------------------------------------------------------
#
# [Case #16] Sentence:  paper with a map on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: NOUN (2.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (85.2%) | Top 2: NOUN (14.6%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (78.5%) | Top 2: NOUN (21.2%) |
# ------------------------------------------------------------
#
# [Case #17] Sentence:  he sprayed some water on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: NOUN (0.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.0%) | Top 2: NOUN (0.9%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (60.3%) | Top 2: PRON (39.5%) |
# ------------------------------------------------------------
#
# [Case #18] Sentence:  had a little spider on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (91.5%) | Top 2: NOUN (8.3%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (52.1%) | Top 2: NOUN (47.6%) |
# ------------------------------------------------------------
#
# [Case #19] Sentence:  a name. They call *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: NOUN (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.1%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (74.6%) | Top 2: PUNCT (22.2%) |
# ------------------------------------------------------------
#
# [Case #20] Sentence:  train had a number on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: NOUN (0.5%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (98.8%) | Top 2: NOUN (1.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: NOUN (2.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (78.7%) | Top 2: NOUN (21.3%) |
# ------------------------------------------------------------
#
# [Case #21] Sentence:  had a big knob on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: NOUN (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.5%) | Top 2: NOUN (1.3%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (51.8%) | Top 2: PRON (47.7%) |
# ------------------------------------------------------------
#
# [Case #22] Sentence:  drum. He banged *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: ADV (0.1%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.2%) | Top 2: VERB (26.5%) |
# ------------------------------------------------------------
#
# [Case #23] Sentence:  broke. He banged *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (100.0%) | Top 2: ADV (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: PROPN (0.1%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (64.0%) | Top 2: VERB (32.3%) |
# ------------------------------------------------------------
#
# [Case #24] Sentence:  a big stain on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: NOUN (0.5%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (97.8%) | Top 2: NOUN (1.8%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (81.2%) | Top 2: NOUN (18.4%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (68.4%) | Top 2: PRON (30.8%) |
# ------------------------------------------------------------
#
# [Case #25] Sentence:  picture of her family in *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: NOUN (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (97.8%) | Top 2: NOUN (1.9%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (93.7%) | Top 2: NOUN (5.8%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (78.8%) | Top 2: NOUN (20.3%) |
# ------------------------------------------------------------
#
# [Case #26] Sentence: . They wanted to climb *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: ADV (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: ADV (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (94.3%) | Top 2: ADV (5.4%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (66.2%) | Top 2: ADV (33.8%) |
# ------------------------------------------------------------
#
# [Case #27] Sentence:  of big logs on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: NOUN (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.5%) | Top 2: NOUN (1.4%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (60.8%) | Top 2: PRON (39.1%) |
# ------------------------------------------------------------
#
# [Case #28] Sentence:  of a spicy pepper on *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.4%) | Top 2: NOUN (0.6%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (96.2%) | Top 2: NOUN (3.6%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.3%) | Top 2: NOUN (2.6%) |
#   layer_3 | Pred: NOUN | True: PRON ⚠️
#     Top 1: NOUN (60.5%) | Top 2: PRON (39.0%) |
# ------------------------------------------------------------
# ✅ Found 28 interesting cases for ' it'.
#
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' he'
# ================================================================================
#
# [Case #1] Sentence:  wife who is now in *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PROPN
#     Top 1: PRON (99.3%) | Top 2: ADJ (0.2%) |
#   layer_1 | Pred: PRON | True: PROPN
#     Top 1: PRON (86.7%) | Top 2: NOUN (6.2%) |
#   layer_2 | Pred: PRON | True: PROPN ⚠️
#     Top 1: PRON (71.6%) | Top 2: NOUN (24.6%) |
#   layer_3 | Pred: PRON | True: PROPN
#     Top 1: PRON (72.5%) | Top 2: NOUN (18.5%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  wrong, Mommy?" *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: ADJ (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: PUNCT (0.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (82.0%) | Top 2: PUNCT (8.3%) |
#   layer_3 | Pred: PUNCT | True: PRON ⚠️
#     Top 1: PUNCT (50.4%) | Top 2: PRON (32.5%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  them instead. Lily was *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (98.4%) | Top 2: AUX (0.6%) |
#   layer_1 | Pred: PRON | True: ADJ
#     Top 1: PRON (93.9%) | Top 2: ADJ (2.3%) |
#   layer_2 | Pred: PRON | True: ADJ
#     Top 1: PRON (82.7%) | Top 2: ADV (7.9%) |
#   layer_3 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (73.2%) | Top 2: ADV (20.6%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  things happen, but if *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: ADV (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.2%) | Top 2: NOUN (0.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.5%) | Top 2: ADV (1.4%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.3%) | Top 2: ADV (22.8%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  the dog. Lily was *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (95.9%) | Top 2: AUX (1.9%) |
#   layer_1 | Pred: PRON | True: ADJ
#     Top 1: PRON (89.8%) | Top 2: ADJ (2.3%) |
#   layer_2 | Pred: PRON | True: ADJ
#     Top 1: PRON (70.4%) | Top 2: ADV (11.4%) |
#   layer_3 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (51.9%) | Top 2: ADV (21.8%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence: . Max explained the noise *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.2%) | Top 2: ADV (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (98.5%) | Top 2: NOUN (1.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (95.6%) | Top 2: NOUN (4.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (76.0%) | Top 2: NOUN (23.6%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  dance with you?" *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: ADV (0.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: PUNCT (0.1%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.1%) | Top 2: NOUN (1.5%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (48.2%) | Top 2: AUX (42.3%) |
# ------------------------------------------------------------
# ✅ Found 7 interesting cases for ' he'.
