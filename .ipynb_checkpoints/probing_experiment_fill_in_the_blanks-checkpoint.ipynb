# %% [markdown]
# ## Remember to change is_causal = True to False in Settings

# %%
import torch
import torch.nn as nn
from Settings import TinyStoriesLM
from datetime import datetime
import random
import matplotlib.pyplot as plt

from tokenizer import TinyStoriesTokenizer
from torch.utils.data import Dataset, DataLoader
from dataclasses import dataclass, asdict
import numpy as np

print("cell ran")
# Out:
# cell ran

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000  # This number should agree with the tokenizer
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 1
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1


class TinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        # Pull a chunk of length block_size + 1 (data and target)
        chunk = self.data[idx : idx + self.block_size + 1]

        # Convert to torch tensors
        x = torch.from_numpy(chunk[:-1].astype(np.int64)) # Input
        y = torch.from_numpy(chunk[1:].astype(np.int64))  # Target (shifted by 1)

        return x, y 


class ProbeDataset(Dataset):
    def __init__(self, data, tensor_tags, index_range, limit=512, ignore_index = -100):
        self.data = data
        self.limit = limit
        self.index_range = list(index_range)
        self.tensor_tags = tensor_tags
        self.ignore_index = ignore_index
        #self.pos_to_id = pos_to_id

    def __len__(self):
        return len(self.index_range)

    def __getitem__(self, idx):
        idx_true = self.index_range[idx]
    
        # when we built tensors, we bactch (0, 512, 1024, 1536...)
        # To get the real position
        dataset_index = idx_true * self.limit

        # Extract binary file
        item = self.data[dataset_index]
        input_ids = item[0][:self.limit] 
        
        # from tensor tags
        labels = self.tensor_tags[idx_true][:self.limit].clone()
        labels[labels < 3] = self.ignore_index
        
        return {
            'input_ids': input_ids,
            'labels': labels
        }

print("probedataset ready")
# Out:
# probedataset ready

# %%
# We load the aligned data
tensores_tags_dataset = torch.load('tags_probes_5k_first_subtoken.pt')
POS_TAGS_VOCAB = [
    'PAD', 'SUBWORD', 'X', 'ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 
    'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 
    'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB'
]
tag2id = {tag: idx for idx, tag in enumerate(POS_TAGS_VOCAB)}
id2tag = {idx: tag for tag, idx in tag2id.items()}
ignore_index = -100
print(f"{len(tensores_tags_dataset)} tensors for Probing.")
# Out:
# 5000 tensors for Probing.

# %%
import json

with open("multipos_dict.json", "r") as f:
    multipos_dict = json.load(f)

print("cell ran")
# Out:
# cell ran

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
checkpoint_path = 'last_checkpoint_unmasking.pt'

model = TinyStoriesLM.load(checkpoint_path, device=device).to(device)
training_dataset = TinyStoriesDataset('/datasets/dd2417/train.bin', Config.block_size)
tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')

# Freeze model
for param in model.parameters():
    param.requires_grad = False

model.eval() 

activations = {}

def forward_hook(module, input, output):
    if isinstance(output, tuple):
        activations[module.name] = output[0].detach()
    else:
        activations[module.name] = output.detach()

hooks = []
for i, block in enumerate(model.transformers):
    block.name = f"layer_{i}" 
    handle = block.register_forward_hook(forward_hook)
    hooks.append(handle)

num_tags = len(tag2id)
input_dim = model.config.vector_dim
limit = model.config.block_size
num_layers = len(model.transformers)

train_subset_tags = tensores_tags_dataset[:4500]
val_subset_tags = tensores_tags_dataset[4500:]

train_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(0, 4500), limit=limit)
train_loader = DataLoader(train_ds, batch_size=model.config.batch_size, shuffle=True)

val_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(4500, 5000), limit=limit)
val_loader = DataLoader(val_ds, batch_size=model.config.batch_size, shuffle=False)

# %%
print(f"Subsets : training: {len(train_ds)} | validation: {len(val_ds)}")

target_words = [' so',' playing' ,' back', ' it', ' he']
evolution_tracking = {word: {} for word in target_words}


# FOR GRAPHS
all_general_acc = []
all_ambiguous_acc = []

# Layer for layer
for layer_to_probe in range(num_layers):
    layer_name = f"layer_{layer_to_probe}"
    print(f"\nTraining probe of: {layer_name}")

    probe = nn.Linear(input_dim, num_tags).to(device)
    optimizer = torch.optim.Adam(probe.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=ignore_index)

    # Training
    for epoch in range(3):
        probe.train()
        for batch in train_loader:
            activations.clear()
            ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            with torch.no_grad():
                model(ids) 

            optimizer.zero_grad()
            logits = probe(activations[layer_name])
   
            loss = criterion(logits.view(-1, num_tags), labels.view(-1))
            loss.backward()
            optimizer.step()

        # Evaluation
        probe.eval()
        correct_tokens = 0
        total_tokens = 0
        correct_ambiguous_tokens = 0
        total_ambiguous_tokens = 0
        
        with torch.no_grad():
            for v_batch in val_loader:
                v_ids = v_batch['input_ids'].to(device)
                v_labels = v_batch['labels'].to(device)
                
                model(v_ids)
                v_logits = probe(activations[layer_name])
                predictions = v_logits.argmax(dim=-1)

                v_probs = torch.softmax(v_logits, dim=-1)
                top_3_probs, top_3_idx = torch.topk(v_probs, k=3, dim=-1)  

                for b in range(v_ids.size(0)):
                    ids_list = v_ids[b].tolist()
                    tokens = tokenizer.decode_to_tokens(ids_list)
                    
                    for t in range(len(tokens)):
                        label_real = v_labels[b, t].item()
                        if label_real == ignore_index:
                            continue 
                        
                        current_word = tokens[t] 
    
                        # just last epoch
                        if epoch == 2 and current_word in target_words:
                            inicio_contexto = max(0, t - 5)
                            fin_contexto = min(len(ids_list), t + 5)
                            texto_antes = tokenizer.decode(ids_list[inicio_contexto: t])
                            texto_despues = tokenizer.decode(ids_list[t+1: fin_contexto])
                            frase_id = f"{texto_antes} *[{current_word.upper().strip()}]* {texto_despues}"

                            if frase_id not in evolution_tracking[current_word]:
                                evolution_tracking[current_word][frase_id] = {}
                            
                            pred_label = predictions[b, t].item()
                            top_3_lista = top_3_idx[b, t].tolist()
                            top_3_tags = [id2tag[idx] for idx in top_3_lista]
                            top_3_probs_list = top_3_probs[b, t].tolist()
                            percentages = [p * 100 for p in top_3_probs_list]
                                
                            evolution_tracking[current_word][frase_id][layer_name] = {
                                "real_tag": id2tag[label_real],
                                "pred_tag": id2tag[pred_label],
                                "top_3_tags": top_3_tags,
                                "percentages": percentages
                            }
                                
                        # general metrics for multipos, always
                        if current_word in multipos_dict:
                            pred_label = predictions[b, t].item()
                            total_ambiguous_tokens += 1
                            if pred_label == label_real:
                                correct_ambiguous_tokens += 1
                
                # global epoch
                mask = (v_labels != ignore_index)
                correct_tokens += (predictions[mask] == v_labels[mask]).sum().item()
                total_tokens += mask.sum().item()
                    
        epoch_accuracy = (correct_tokens / total_tokens) * 100 if total_tokens > 0 else 0.0
        epoch_ambiguity_accuracy = (correct_ambiguous_tokens / total_ambiguous_tokens) * 100 if total_ambiguous_tokens > 0 else 0.0        
        print(f"Epoch {epoch + 1} accuracy: {epoch_accuracy:.2f}% | Ambiguous Accuracy: {epoch_ambiguity_accuracy:.2f}%")
               
    all_general_acc.append(epoch_accuracy)
    all_ambiguous_acc.append(epoch_ambiguity_accuracy)
    print(f"="*70) 
for handle in hooks:
    handle.remove()

# when training (ignore_index=-100) impo
print("cell ran")
# Out:
# Model loaded from last_checkpoint_unmasking.pt (Epoch 0, iteration 130000)
# Subsets : training: 4500 | validation: 500
#
# Training probe of: layer_0
# Epoch 1 accuracy: 97.62% | Ambiguous Accuracy: 97.23%
# Epoch 2 accuracy: 97.95% | Ambiguous Accuracy: 97.51%
# Epoch 3 accuracy: 98.07% | Ambiguous Accuracy: 97.63%
# ======================================================================
#
# Training probe of: layer_1
# Epoch 1 accuracy: 97.59% | Ambiguous Accuracy: 97.21%
# Epoch 2 accuracy: 97.91% | Ambiguous Accuracy: 97.55%
# Epoch 3 accuracy: 98.05% | Ambiguous Accuracy: 97.67%
# ======================================================================
#
# Training probe of: layer_2
# Epoch 1 accuracy: 97.38% | Ambiguous Accuracy: 97.06%
# Epoch 2 accuracy: 97.71% | Ambiguous Accuracy: 97.36%
# Epoch 3 accuracy: 97.80% | Ambiguous Accuracy: 97.44%
# ======================================================================
#
# Training probe of: layer_3
# Epoch 1 accuracy: 97.19% | Ambiguous Accuracy: 96.88%
# Epoch 2 accuracy: 97.52% | Ambiguous Accuracy: 97.17%
# Epoch 3 accuracy: 97.63% | Ambiguous Accuracy: 97.28%
# ======================================================================
# cell ran

# %%
# evolution tracking -> 3 diciconaries
#1.1 word = ' so'
#1.2 'context'
#1.3 - ALL layers are a key (realtag, pred tag, top 3, percentages)

#lista_de_frases = list(evolution_tracking[' so'].keys())
# print(lista_de_frases)

# datos_capa_0 = evolution_tracking[' so'][frase]['layer_0']

# %%
#lista_de_frases = list(evolution_tracking[' so'].keys())
#print(lista_de_frases[:10])

# %%
fixed_rand_phrases = {}

for word, contexts in evolution_tracking.items():
    phrase_list = list(contexts.keys())
    phrase_list = sorted(phrase_list) # base order
    random.seed(103)
    num_elements = min(5, len(phrase_list)) # if any element has less than 5
    selected_phrases = random.sample(phrase_list, num_elements)
    fixed_rand_phrases[word] = selected_phrases

for word, phrases in fixed_rand_phrases.items():
    print("-"*50)
    print(f"Ambiguous Word: {repr(word)}")
    for phrase_id in phrases: # each dif phrase from that ambiguous word
       layers = evolution_tracking[word][phrase_id]
       print("-"*50)
       print(f"Sentence ... {phrase_id}") 
       for layer_name in sorted(layers.keys()):
           info = layers[layer_name]
           print(f"{layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']}")
           print(f" Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | Top 3: {info['top_3_tags'][2]} ({info['percentages'][2]:.1f}%)")
            
    print("")
# Out:
# --------------------------------------------------
# Ambiguous Word: ' so'
# --------------------------------------------------
# Sentence ... . "I don't think *[SO]* , Lily,"
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.9%) | Top 2: SCONJ (0.0%) | Top 3: INTJ (0.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.6%) | Top 2: SCONJ (0.4%) | Top 3: INTJ (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (98.7%) | Top 2: SCONJ (1.2%) | Top 3: ADJ (0.0%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.3%) | Top 2: SCONJ (0.5%) | Top 3: CCONJ (0.1%)
# --------------------------------------------------
# Sentence ...  loud, but it sounded *[SO]*  cheerful. Everyone was
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.1%) | Top 2: DET (0.4%) | Top 3: SCONJ (0.2%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.8%) | Top 2: ADP (0.1%) | Top 3: DET (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (99.7%) | Top 2: SCONJ (0.1%) | Top 3: ADP (0.1%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.3%) | Top 2: SCONJ (0.3%) | Top 3: ADP (0.3%)
# --------------------------------------------------
# Sentence ...  at him. Timmy was *[SO]*  embarrassed that he ran
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.5%) | Top 2: ADJ (0.3%) | Top 3: SCONJ (0.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.9%) | Top 2: ADJ (0.0%) | Top 3: PUNCT (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (99.7%) | Top 2: ADJ (0.2%) | Top 3: VERB (0.1%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.4%) | Top 2: ADJ (0.3%) | Top 3: VERB (0.1%)
# --------------------------------------------------
# Sentence ...  dark. The sky was *[SO]*  dark that the K
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (98.1%) | Top 2: ADJ (0.9%) | Top 3: SCONJ (0.4%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (98.9%) | Top 2: ADJ (0.6%) | Top 3: SCONJ (0.3%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (93.0%) | Top 2: ADJ (3.3%) | Top 3: VERB (2.3%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (92.6%) | Top 2: VERB (3.3%) | Top 3: SCONJ (2.5%)
# --------------------------------------------------
# Sentence ...  together all day and had *[SO]*  much fun. After
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.6%) | Top 2: DET (0.1%) | Top 3: SCONJ (0.1%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (98.9%) | Top 2: DET (0.4%) | Top 3: ADP (0.3%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (91.4%) | Top 2: ADJ (4.0%) | Top 3: DET (2.8%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (95.9%) | Top 2: ADJ (1.6%) | Top 3: DET (1.1%)
#
# --------------------------------------------------
# Ambiguous Word: ' playing'
# --------------------------------------------------
# Sentence ...  the peaceful day he had *[PLAYING]*  at Grandma's.
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (98.4%) | Top 2: NOUN (1.3%) | Top 3: DET (0.1%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (99.2%) | Top 2: NOUN (0.7%) | Top 3: DET (0.1%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (98.4%) | Top 2: NOUN (1.3%) | Top 3: ADJ (0.2%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (83.6%) | Top 2: NOUN (13.9%) | Top 3: ADJ (1.7%)
# --------------------------------------------------
# Sentence ...  day, she was *[PLAYING]*  in the woods when
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (99.8%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.0%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (99.2%) | Top 2: NOUN (0.5%) | Top 3: ADJ (0.1%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (96.5%) | Top 2: NOUN (1.4%) | Top 3: ADJ (1.2%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (94.5%) | Top 2: NOUN (3.6%) | Top 3: ADV (0.6%)
# --------------------------------------------------
# Sentence ...  One day, he was *[PLAYING]*  in his room when
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (99.1%) | Top 2: NOUN (0.8%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (99.7%) | Top 2: NOUN (0.2%) | Top 3: ADJ (0.0%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (96.5%) | Top 2: AUX (1.9%) | Top 3: ADJ (0.6%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (97.9%) | Top 2: NOUN (1.2%) | Top 3: AUX (0.4%)
# --------------------------------------------------
# Sentence ... , while the bear was *[PLAYING]*  with his friends,
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (99.7%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.1%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (97.5%) | Top 2: ADV (1.3%) | Top 3: NOUN (0.6%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (91.0%) | Top 2: ADV (4.9%) | Top 3: NOUN (1.4%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (93.8%) | Top 2: NOUN (2.2%) | Top 3: ADV (1.9%)
# --------------------------------------------------
# Sentence ...  They ignored him and kept *[PLAYING]*  with their toys.
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (100.0%) | Top 2: NOUN (0.0%) | Top 3: ADV (0.0%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (99.7%) | Top 2: ADV (0.1%) | Top 3: NOUN (0.1%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (99.1%) | Top 2: ADJ (0.5%) | Top 3: ADV (0.3%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (99.3%) | Top 2: ADJ (0.3%) | Top 3: PROPN (0.1%)
#
# --------------------------------------------------
# Ambiguous Word: ' back'
# --------------------------------------------------
# Sentence ...  worked sometimes. She went *[BACK]*  to singing with the
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (98.2%) | Top 2: ADP (0.7%) | Top 3: VERB (0.5%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (98.6%) | Top 2: ADP (1.1%) | Top 3: VERB (0.1%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (97.1%) | Top 2: ADP (1.9%) | Top 3: ADJ (0.7%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (87.8%) | Top 2: ADP (9.5%) | Top 3: ADJ (1.8%)
# --------------------------------------------------
# Sentence ...  on the stairs and come *[BACK]*  later with her mom
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (87.9%) | Top 2: ADP (10.3%) | Top 3: ADJ (1.2%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (85.6%) | Top 2: ADP (13.5%) | Top 3: ADJ (0.7%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (67.9%) | Top 2: ADP (28.4%) | Top 3: ADJ (3.5%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (49.2%) | Top 2: ADP (41.6%) | Top 3: ADJ (8.2%)
# --------------------------------------------------
# Sentence ...  wrong and gave the hammer *[BACK]*  to Tim. She
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (79.8%) | Top 2: ADJ (17.1%) | Top 3: NOUN (1.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (95.5%) | Top 2: ADJ (2.6%) | Top 3: ADP (0.8%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (98.4%) | Top 2: ADJ (0.9%) | Top 3: ADP (0.2%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (97.6%) | Top 2: ADJ (1.8%) | Top 3: ADP (0.3%)
# --------------------------------------------------
# Sentence ...  were both happy and went *[BACK]*  to play with the
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (94.9%) | Top 2: ADJ (3.2%) | Top 3: VERB (1.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.4%) | Top 2: ADJ (0.4%) | Top 3: ADP (0.2%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (91.2%) | Top 2: ADJ (6.2%) | Top 3: VERB (1.6%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (85.0%) | Top 2: ADP (7.9%) | Top 3: ADJ (6.0%)
# --------------------------------------------------
# Sentence ... " Sam and Lily went *[BACK]*  to the park.
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (95.6%) | Top 2: ADP (3.8%) | Top 3: ADJ (0.3%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.7%) | Top 2: ADP (0.3%) | Top 3: VERB (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (98.6%) | Top 2: ADP (1.0%) | Top 3: VERB (0.3%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (98.8%) | Top 2: ADP (0.7%) | Top 3: VERB (0.3%)
#
# --------------------------------------------------
# Ambiguous Word: ' it'
# --------------------------------------------------
# Sentence ...  the yummy cake and ate *[IT]*  all up.Once
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: DET (0.0%) | Top 3: NOUN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) | Top 3: DET (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: DET (0.0%)
# --------------------------------------------------
# Sentence ...  friends. They learned that *[IT]*  was more fun to
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.7%) | Top 2: NOUN (0.2%) | Top 3: AUX (0.1%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.5%) | Top 2: AUX (0.2%) | Top 3: ADV (0.2%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (98.6%) | Top 2: NOUN (1.1%) | Top 3: ADV (0.2%)
# --------------------------------------------------
# Sentence ...  accidentally kicked the castle and *[IT]*  fell down. Lily
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: DET (0.1%) | Top 3: ADV (0.1%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.5%) | Top 2: DET (0.4%) | Top 3: ADV (0.1%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.1%) | Top 3: NOUN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# --------------------------------------------------
# Sentence ... . Lily laughed and thought *[IT]*  was so funny!
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: ADV (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: DET (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# --------------------------------------------------
# Sentence ...  back, but she knew *[IT]*  was the right thing
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: VERB (0.0%)
#
# --------------------------------------------------
# Ambiguous Word: ' he'
# --------------------------------------------------
# Sentence ...  you happy again," *[HE]*  said. Lily wiped
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.6%) | Top 2: NOUN (0.2%) | Top 3: PROPN (0.2%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: PROPN (0.0%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: NOUN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: PROPN (0.1%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ...  playing in his garden when *[HE]*  heard a strange noise
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: AUX (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PUNCT (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PUNCT (0.0%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ... " Jack didn't understand and *[HE]*  felt even more scared
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: ADV (0.2%) | Top 3: PROPN (0.0%)
# --------------------------------------------------
# Sentence ...  with his boat and soon *[HE]*  saw a big island
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# --------------------------------------------------
# Sentence ... , but he was sad *[HE]*  couldn't play with the
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.1%) | Top 3: PART (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.0%) | Top 3: SCONJ (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.7%) | Top 2: ADV (0.2%) | Top 3: SCONJ (0.1%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (97.2%) | Top 2: ADV (2.1%) | Top 3: SCONJ (0.3%)

# %%
for word, contexts in evolution_tracking.items():
    print("=" * 80)
    print(f"SEARCHING HIGH-UNCERTAINTY CASES FOR: {repr(word)}")
    print("=" * 80)
    
    match_count = 0
    
    for phrase_id, layers in contexts.items():
        # Verificamos si en AL MENOS una capa el Top 2 superó el 20%
        has_high_uncertainty = any(layers[layer]['percentages'][1] > 20.0 for layer in layers)
        
        if has_high_uncertainty:
            match_count += 1
            print(f"\n[Case #{match_count}] Sentence: {phrase_id}")
            print("-" * 60)
            
            # Mostramos cómo evolucionó la duda capa por capa en esta frase
            for layer_name in sorted(layers.keys()):
                info = layers[layer_name]
                
                # Alerta visual si esta capa específica es la que causó la duda
                alert = "⚠️" if info['percentages'][1] > 20.0 else "   "
                
                print(f"  {layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']} {alert}")
                print(f"    Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | "
                      f"Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | ")
            print("-" * 60)
            
    if match_count == 0:
        print(f"No rare cases found for {repr(word)} with Top 2 > 10% in this run.\n")
    else:
        print(f"✅ Found {match_count} interesting cases for {repr(word)}.\n")
# Out:
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' so'
# ================================================================================
#
# [Case #1] Sentence:  for it to breathe, *[SO]*  it flew away quickly
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (68.8%) | Top 2: ADV (30.1%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (75.6%) | Top 2: ADV (20.9%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (77.8%) | Top 2: ADV (21.3%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.4%) | Top 2: ADV (34.7%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  Lily couldn't reach it, *[SO]*  her mom always helped
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.4%) | Top 2: SCONJ (7.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.4%) | Top 2: CCONJ (28.3%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (55.2%) | Top 2: CCONJ (24.2%) |
#   layer_3 | Pred: CCONJ | True: ADV ⚠️
#     Top 1: CCONJ (56.1%) | Top 2: SCONJ (31.4%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence: . "Ah, *[SO]*  you've found it
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (56.6%) | Top 2: SCONJ (41.5%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (73.0%) | Top 2: ADV (23.9%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (90.3%) | Top 2: ADV (6.2%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (49.5%) | Top 2: ADV (19.4%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  wanted to include everyone, *[SO]*  he invited the birds
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.4%) | Top 2: SCONJ (38.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.0%) | Top 2: SCONJ (9.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (94.9%) | Top 2: SCONJ (4.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: SCONJ (2.1%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  extra careful with his water *[SO]*  he wouldn't make a
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.0%) | Top 2: ADV (13.6%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (60.3%) | Top 2: ADV (38.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (60.6%) | Top 2: SCONJ (39.1%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.6%) | Top 2: SCONJ (21.9%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  was excited to help, *[SO]*  he went to the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.6%) | Top 2: SCONJ (38.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.8%) | Top 2: SCONJ (16.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (84.8%) | Top 2: SCONJ (14.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.7%) | Top 2: SCONJ (2.0%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  Let me restore your leg *[SO]*  you can dance again
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (75.1%) | Top 2: ADV (23.5%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.3%) | Top 2: ADV (24.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.0%) | Top 2: ADV (9.9%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (68.5%) | Top 2: ADV (30.0%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  eat in their home, *[SO]*  they decided to go
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.1%) | Top 2: SCONJ (45.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: SCONJ (7.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (82.8%) | Top 2: SCONJ (15.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (88.7%) | Top 2: SCONJ (8.8%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  should take care of it *[SO]*  it stays beautiful
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (58.2%) | Top 2: ADV (40.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (51.3%) | Top 2: ADV (47.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (80.4%) | Top 2: ADV (19.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.3%) | Top 2: ADV (13.2%) |
# ------------------------------------------------------------
#
# [Case #10] Sentence: ided them evenly, *[SO]*  everyone had the same
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (84.5%) | Top 2: ADV (13.8%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.3%) | Top 2: ADV (38.8%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (95.6%) | Top 2: ADV (4.3%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (95.7%) | Top 2: ADV (4.0%) |
# ------------------------------------------------------------
#
# [Case #11] Sentence:  play with the toys, *[SO]*  he climbed up the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.1%) | Top 2: SCONJ (32.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (86.9%) | Top 2: SCONJ (11.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: SCONJ (9.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.0%) | Top 2: SCONJ (2.8%) |
# ------------------------------------------------------------
#
# [Case #12] Sentence: , "Wow, that's *[SO]*  cool! Can you
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (94.9%) | Top 2: PRON (2.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (98.2%) | Top 2: PRON (0.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.1%) | Top 2: PRON (9.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (48.2%) | Top 2: PRON (33.0%) |
# ------------------------------------------------------------
#
# [Case #13] Sentence: . Lily got thirsty, *[SO]*  her mom gave her
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.2%) | Top 2: SCONJ (11.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.2%) | Top 2: SCONJ (39.0%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (53.7%) | Top 2: ADV (40.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (69.5%) | Top 2: SCONJ (19.1%) |
# ------------------------------------------------------------
#
# [Case #14] Sentence:  be careful with her juice *[SO]*  she wouldn't split it
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.6%) | Top 2: ADV (17.0%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (83.2%) | Top 2: ADV (16.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (61.5%) | Top 2: ADV (38.4%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.8%) | Top 2: SCONJ (32.3%) |
# ------------------------------------------------------------
#
# [Case #15] Sentence:  wanted to help Tom, *[SO]*  they went to the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.1%) | Top 2: SCONJ (32.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.3%) | Top 2: SCONJ (6.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (88.1%) | Top 2: SCONJ (9.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.0%) | Top 2: SCONJ (1.7%) |
# ------------------------------------------------------------
#
# [Case #16] Sentence:  her house to Tom's house *[SO]*  he could follow them
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.2%) | Top 2: ADV (10.2%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.7%) | Top 2: ADV (13.8%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.9%) | Top 2: ADV (10.0%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (68.6%) | Top 2: ADV (30.7%) |
# ------------------------------------------------------------
#
# [Case #17] Sentence:  to protect his family, *[SO]*  he always stayed close
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (58.2%) | Top 2: ADV (39.3%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (58.8%) | Top 2: ADV (35.5%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (70.7%) | Top 2: ADV (26.2%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (43.1%) | Top 2: ADV (36.1%) |
# ------------------------------------------------------------
#
# [Case #18] Sentence: . The duck was scared *[SO]*  Bob slowly made some
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (49.6%) | Top 2: SCONJ (49.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (53.3%) | Top 2: ADV (44.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (50.5%) | Top 2: ADV (48.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (52.7%) | Top 2: ADV (45.7%) |
# ------------------------------------------------------------
#
# [Case #19] Sentence:  said, "Please move *[SO]*  I can protect the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (64.5%) | Top 2: SCONJ (30.9%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (73.4%) | Top 2: SCONJ (24.7%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (54.2%) | Top 2: ADV (44.4%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (62.7%) | Top 2: SCONJ (35.0%) |
# ------------------------------------------------------------
#
# [Case #20] Sentence:  in the warm ocean, *[SO]*  he floated to
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (49.4%) | Top 2: ADV (47.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (83.3%) | Top 2: SCONJ (14.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.8%) | Top 2: SCONJ (12.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: SCONJ (8.8%) |
# ------------------------------------------------------------
#
# [Case #21] Sentence:  started to feel sleepy, *[SO]*  he yawned and yawned
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.9%) | Top 2: SCONJ (24.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.7%) | Top 2: SCONJ (9.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.2%) | Top 2: SCONJ (6.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.9%) | Top 2: SCONJ (1.9%) |
# ------------------------------------------------------------
#
# [Case #22] Sentence:  Lily trusted her mommy, *[SO]*  she didn't say anything
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (86.9%) | Top 2: SCONJ (8.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (76.6%) | Top 2: CCONJ (14.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (66.3%) | Top 2: SCONJ (18.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.4%) | Top 2: CCONJ (20.3%) |
# ------------------------------------------------------------
#
# [Case #23] Sentence:  was scaring the baby *[SO]*  the mommy touched the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.3%) | Top 2: SCONJ (10.4%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (71.3%) | Top 2: SCONJ (27.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.7%) | Top 2: ADV (12.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (70.9%) | Top 2: ADV (23.1%) |
# ------------------------------------------------------------
#
# [Case #24] Sentence:  the things in the refrigerator *[SO]*  we can find what
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (50.1%) | Top 2: ADV (48.4%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.0%) | Top 2: SCONJ (10.6%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (77.5%) | Top 2: SCONJ (22.1%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.9%) | Top 2: SCONJ (7.3%) |
# ------------------------------------------------------------
#
# [Case #25] Sentence:  had to be careful, *[SO]*  he swam away from
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.0%) | Top 2: SCONJ (20.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.8%) | Top 2: SCONJ (5.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.7%) | Top 2: SCONJ (11.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.6%) | Top 2: SCONJ (3.2%) |
# ------------------------------------------------------------
#
# [Case #26] Sentence:  parents with his address *[SO]*  they could thank him
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (67.8%) | Top 2: ADV (31.8%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.2%) | Top 2: SCONJ (8.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (63.2%) | Top 2: ADV (36.0%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (52.0%) | Top 2: SCONJ (46.5%) |
# ------------------------------------------------------------
#
# [Case #27] Sentence:  and forth. It was *[SO]*  much fun that he
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.0%) | Top 2: SCONJ (0.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (96.3%) | Top 2: DET (1.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.3%) | Top 2: ADJ (4.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.0%) | Top 2: ADJ (22.1%) |
# ------------------------------------------------------------
#
# [Case #28] Sentence:  more about the crane, *[SO]*  she kept trying to
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (80.3%) | Top 2: SCONJ (17.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.5%) | Top 2: SCONJ (6.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.8%) | Top 2: SCONJ (35.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (82.1%) | Top 2: SCONJ (15.8%) |
# ------------------------------------------------------------
#
# [Case #29] Sentence:  branch. "Wow, *[SO]*  pretty!" Mia
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (97.0%) | Top 2: DET (1.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (99.1%) | Top 2: AUX (0.6%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (96.9%) | Top 2: PRON (1.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.4%) | Top 2: PRON (22.9%) |
# ------------------------------------------------------------
#
# [Case #30] Sentence:  to go to work, *[SO]*  she asked her friend
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (56.7%) | Top 2: SCONJ (41.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (92.9%) | Top 2: SCONJ (5.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (88.0%) | Top 2: SCONJ (10.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.0%) | Top 2: SCONJ (2.6%) |
# ------------------------------------------------------------
#
# [Case #31] Sentence:  in a safe place, *[SO]*  the dog could not
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (77.5%) | Top 2: SCONJ (21.5%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (85.9%) | Top 2: SCONJ (12.4%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (67.4%) | Top 2: SCONJ (30.5%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (53.5%) | Top 2: SCONJ (39.9%) |
# ------------------------------------------------------------
#
# [Case #32] Sentence:  you back to your house *[SO]*  you don't get lost
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (75.1%) | Top 2: ADV (20.4%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (79.5%) | Top 2: ADV (17.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (94.2%) | Top 2: ADV (5.7%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (92.5%) | Top 2: ADV (6.2%) |
# ------------------------------------------------------------
#
# [Case #33] Sentence:  "I will release you *[SO]*  you can fly.
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (69.9%) | Top 2: ADV (26.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.5%) | Top 2: ADV (2.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (95.1%) | Top 2: ADV (4.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.4%) | Top 2: ADV (12.8%) |
# ------------------------------------------------------------
#
# [Case #34] Sentence:  was careful when she danced *[SO]*  she wouldn't fall down
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.3%) | Top 2: SCONJ (31.6%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (50.7%) | Top 2: ADV (49.2%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (67.9%) | Top 2: SCONJ (32.1%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.0%) | Top 2: SCONJ (31.7%) |
# ------------------------------------------------------------
#
# [Case #35] Sentence:  was a cold day, *[SO]*  they wore their warm
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (80.1%) | Top 2: SCONJ (18.9%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.8%) | Top 2: SCONJ (15.5%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.7%) | Top 2: SCONJ (22.8%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.3%) | Top 2: SCONJ (9.9%) |
# ------------------------------------------------------------
#
# [Case #36] Sentence:  truck, Timmy. It's *[SO]*  cool!" Timmy
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.2%) | Top 2: ADJ (0.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (98.7%) | Top 2: PRON (0.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.5%) | Top 2: PRON (3.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.4%) | Top 2: AUX (24.0%) |
# ------------------------------------------------------------
#
# [Case #37] Sentence:  feel a bit chilly *[SO]*  she wrapped her coat
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (53.0%) | Top 2: SCONJ (46.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.5%) | Top 2: SCONJ (8.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.1%) | Top 2: SCONJ (27.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (82.5%) | Top 2: SCONJ (15.0%) |
# ------------------------------------------------------------
#
# [Case #38] Sentence:  with the toys too, *[SO]*  it took the bag
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ
#     Top 1: ADV (78.2%) | Top 2: SCONJ (19.2%) |
#   layer_1 | Pred: ADV | True: CCONJ
#     Top 1: ADV (84.6%) | Top 2: SCONJ (8.6%) |
#   layer_2 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (70.2%) | Top 2: SCONJ (26.1%) |
#   layer_3 | Pred: ADV | True: CCONJ
#     Top 1: ADV (94.5%) | Top 2: CCONJ (2.9%) |
# ------------------------------------------------------------
#
# [Case #39] Sentence:  see what was inside, *[SO]*  it crawled in.
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ
#     Top 1: ADV (90.5%) | Top 2: SCONJ (4.5%) |
#   layer_1 | Pred: ADV | True: CCONJ
#     Top 1: ADV (81.5%) | Top 2: SCONJ (8.3%) |
#   layer_2 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (63.5%) | Top 2: SCONJ (22.1%) |
#   layer_3 | Pred: ADV | True: CCONJ
#     Top 1: ADV (78.9%) | Top 2: CCONJ (13.8%) |
# ------------------------------------------------------------
#
# [Case #40] Sentence:  to tie your hair back *[SO]*  it doesn't get in
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (61.1%) | Top 2: SCONJ (36.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.9%) | Top 2: ADV (25.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (94.3%) | Top 2: ADV (5.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (78.2%) | Top 2: ADV (21.3%) |
# ------------------------------------------------------------
#
# [Case #41] Sentence:  to be tidy and organized *[SO]*  that you can find
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (86.8%) | Top 2: SCONJ (12.8%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.2%) | Top 2: SCONJ (8.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (65.7%) | Top 2: SCONJ (33.8%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (83.2%) | Top 2: SCONJ (11.0%) |
# ------------------------------------------------------------
#
# [Case #42] Sentence:  and tied him up outside *[SO]*  he could wait for
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.9%) | Top 2: SCONJ (8.6%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.7%) | Top 2: SCONJ (8.9%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (77.4%) | Top 2: SCONJ (22.1%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.0%) | Top 2: SCONJ (23.1%) |
# ------------------------------------------------------------
#
# [Case #43] Sentence:  "You need to bathe *[SO]*  you can be clean
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (76.4%) | Top 2: ADV (22.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (94.6%) | Top 2: ADV (4.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (88.5%) | Top 2: ADV (11.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (75.4%) | Top 2: ADV (22.1%) |
# ------------------------------------------------------------
#
# [Case #44] Sentence:  to learn new things, *[SO]*  he asked his friend
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.4%) | Top 2: SCONJ (23.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (98.0%) | Top 2: SCONJ (1.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (97.3%) | Top 2: SCONJ (1.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (98.8%) | Top 2: ADJ (0.3%) |
# ------------------------------------------------------------
#
# [Case #45] Sentence:  to gather more strawberries, *[SO]*  she asked her mom
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.9%) | Top 2: SCONJ (29.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (84.9%) | Top 2: SCONJ (7.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.5%) | Top 2: SCONJ (5.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.1%) | Top 2: SCONJ (1.3%) |
# ------------------------------------------------------------
#
# [Case #46] Sentence:  know, but it's locked *[SO]*  we can't go in
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (54.8%) | Top 2: ADV (44.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (58.9%) | Top 2: ADV (40.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.5%) | Top 2: SCONJ (25.3%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.9%) | Top 2: SCONJ (11.9%) |
# ------------------------------------------------------------
#
# [Case #47] Sentence:  listen to her mom, *[SO]*  she started to clean
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.9%) | Top 2: SCONJ (21.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.2%) | Top 2: SCONJ (3.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (78.6%) | Top 2: SCONJ (19.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.1%) | Top 2: SCONJ (7.0%) |
# ------------------------------------------------------------
#
# [Case #48] Sentence:  books back on the bookcase *[SO]*  she wouldn't lose any
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.7%) | Top 2: SCONJ (19.9%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.4%) | Top 2: SCONJ (33.4%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.7%) | Top 2: SCONJ (12.2%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (92.2%) | Top 2: SCONJ (7.7%) |
# ------------------------------------------------------------
#
# [Case #49] Sentence:  in the sky. And *[SO]*  the two friends flew
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.4%) | Top 2: SCONJ (30.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.2%) | Top 2: SCONJ (5.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.0%) | Top 2: SCONJ (5.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: SCONJ (4.2%) |
# ------------------------------------------------------------
#
# [Case #50] Sentence:  and were very quiet, *[SO]*  they did not wake
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.0%) | Top 2: SCONJ (11.6%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (81.2%) | Top 2: SCONJ (13.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (60.7%) | Top 2: SCONJ (35.2%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (82.9%) | Top 2: SCONJ (14.7%) |
# ------------------------------------------------------------
#
# [Case #51] Sentence:  glass to the kitchen, *[SO]*  it won't break.
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (50.2%) | Top 2: ADV (48.5%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.0%) | Top 2: ADV (15.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.0%) | Top 2: ADV (7.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (66.8%) | Top 2: ADV (16.9%) |
# ------------------------------------------------------------
#
# [Case #52] Sentence: illed it had given him *[SO]*  much joy and allowed
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.8%) | Top 2: SCONJ (3.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (76.3%) | Top 2: ADP (15.9%) |
#   layer_2 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (39.6%) | Top 2: SCONJ (35.1%) |
#   layer_3 | Pred: ADP | True: ADV
#     Top 1: ADP (65.9%) | Top 2: ADV (12.8%) |
# ------------------------------------------------------------
#
# [Case #53] Sentence:  happy to see them, *[SO]*  he went outside to
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.3%) | Top 2: SCONJ (23.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.8%) | Top 2: SCONJ (15.3%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (78.0%) | Top 2: SCONJ (20.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.5%) | Top 2: SCONJ (1.7%) |
# ------------------------------------------------------------
#
# [Case #54] Sentence:  The lady looked cold, *[SO]*  Sue put her blanket
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (62.4%) | Top 2: SCONJ (26.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (82.5%) | Top 2: SCONJ (10.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (62.2%) | Top 2: SCONJ (36.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (86.7%) | Top 2: SCONJ (12.0%) |
# ------------------------------------------------------------
#
# [Case #55] Sentence:  his room clean and tidy *[SO]*  he could always feel
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.0%) | Top 2: ADV (13.0%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.4%) | Top 2: ADV (3.5%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.9%) | Top 2: ADV (8.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (65.0%) | Top 2: ADV (34.4%) |
# ------------------------------------------------------------
#
# [Case #56] Sentence:  wanted to catch the bee *[SO]*  she could keep it
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (57.7%) | Top 2: SCONJ (41.8%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (50.9%) | Top 2: SCONJ (48.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (83.6%) | Top 2: ADV (16.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.9%) | Top 2: ADV (11.5%) |
# ------------------------------------------------------------
#
# [Case #57] Sentence:  her mom for help, *[SO]*  her mom showed her
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (80.9%) | Top 2: SCONJ (15.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (78.6%) | Top 2: SCONJ (12.3%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (68.2%) | Top 2: ADV (22.0%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (52.1%) | Top 2: CCONJ (30.9%) |
# ------------------------------------------------------------
#
# [Case #58] Sentence:  town was very modern, *[SO]*  they played music that
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (70.1%) | Top 2: SCONJ (28.4%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (84.5%) | Top 2: SCONJ (13.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (58.4%) | Top 2: SCONJ (40.8%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.9%) | Top 2: SCONJ (7.9%) |
# ------------------------------------------------------------
#
# [Case #59] Sentence:  But his mom insisted, *[SO]*  Timmy went inside to
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (61.4%) | Top 2: SCONJ (36.8%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.8%) | Top 2: SCONJ (23.7%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.0%) | Top 2: SCONJ (28.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (83.3%) | Top 2: SCONJ (10.6%) |
# ------------------------------------------------------------
#
# [Case #60] Sentence:  her cube to Timmy, *[SO]*  she said,
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.7%) | Top 2: SCONJ (20.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (84.6%) | Top 2: SCONJ (8.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (79.1%) | Top 2: SCONJ (11.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (86.1%) | Top 2: PRON (6.1%) |
# ------------------------------------------------------------
#
# [Case #61] Sentence:  It started to rain, *[SO]*  she grabbed her umbrella
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (68.5%) | Top 2: ADV (30.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (60.4%) | Top 2: SCONJ (38.1%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (67.5%) | Top 2: ADV (32.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.9%) | Top 2: SCONJ (32.8%) |
# ------------------------------------------------------------
#
# [Case #62] Sentence:  that Timmy needed support, *[SO]*  she lifted
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.3%) | Top 2: SCONJ (29.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (80.7%) | Top 2: SCONJ (15.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.6%) | Top 2: SCONJ (29.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (94.4%) | Top 2: SCONJ (3.5%) |
# ------------------------------------------------------------
#
# [Case #63] Sentence:  decided to practice every day *[SO]*  she could be a
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (85.8%) | Top 2: SCONJ (13.9%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.6%) | Top 2: SCONJ (12.2%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (70.2%) | Top 2: SCONJ (29.5%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (85.0%) | Top 2: SCONJ (14.4%) |
# ------------------------------------------------------------
#
# [Case #64] Sentence:  to help the bird, *[SO]*  he sprayed some water
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.1%) | Top 2: SCONJ (40.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.6%) | Top 2: SCONJ (40.3%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.3%) | Top 2: ADV (42.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (82.9%) | Top 2: SCONJ (16.4%) |
# ------------------------------------------------------------
#
# [Case #65] Sentence: . I was hungry, *[SO]*  I took it.
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (75.2%) | Top 2: SCONJ (11.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (73.6%) | Top 2: CCONJ (18.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (67.3%) | Top 2: SCONJ (21.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (71.8%) | Top 2: CCONJ (16.2%) |
# ------------------------------------------------------------
#
# [Case #66] Sentence:  to supply it with power *[SO]*  it can work well
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.0%) | Top 2: ADV (26.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.1%) | Top 2: ADV (12.2%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (98.0%) | Top 2: ADV (1.7%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.8%) | Top 2: ADV (8.0%) |
# ------------------------------------------------------------
#
# [Case #67] Sentence:  Let's put it in there *[SO]*  it doesn't get more
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.7%) | Top 2: SCONJ (26.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.4%) | Top 2: SCONJ (26.0%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (89.0%) | Top 2: ADV (10.8%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (87.5%) | Top 2: ADV (11.8%) |
# ------------------------------------------------------------
#
# [Case #68] Sentence:  big and strong, *[SO]*  I will cover you
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ
#     Top 1: ADV (87.5%) | Top 2: SCONJ (11.9%) |
#   layer_1 | Pred: ADV | True: CCONJ
#     Top 1: ADV (94.0%) | Top 2: SCONJ (5.2%) |
#   layer_2 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (75.5%) | Top 2: SCONJ (23.5%) |
#   layer_3 | Pred: ADV | True: CCONJ
#     Top 1: ADV (78.8%) | Top 2: SCONJ (18.6%) |
# ------------------------------------------------------------
#
# [Case #69] Sentence: ometimes bugs are terrible, *[SO]*  you have to remember
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (77.1%) | Top 2: SCONJ (18.2%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (46.1%) | Top 2: ADV (43.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (48.9%) | Top 2: ADV (39.4%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (46.0%) | Top 2: CCONJ (28.3%) |
# ------------------------------------------------------------
#
# [Case #70] Sentence:  Ann asked for help, *[SO]*  Tom decided to write
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (47.7%) | Top 2: ADV (44.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (88.7%) | Top 2: SCONJ (6.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.9%) | Top 2: SCONJ (26.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (87.5%) | Top 2: SCONJ (9.3%) |
# ------------------------------------------------------------
#
# [Case #71] Sentence:  to help the boy, *[SO]*  he stopped the cars
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.6%) | Top 2: SCONJ (24.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.5%) | Top 2: SCONJ (7.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (84.7%) | Top 2: SCONJ (14.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (93.0%) | Top 2: SCONJ (5.6%) |
# ------------------------------------------------------------
#
# [Case #72] Sentence:  said. "It is *[SO]*  fat and fuzzy
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (98.9%) | Top 2: ADJ (0.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (92.4%) | Top 2: DET (3.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (80.1%) | Top 2: DET (9.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.1%) | Top 2: DET (30.8%) |
# ------------------------------------------------------------
#
# [Case #73] Sentence: Mommy, the comet is *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (96.9%) | Top 2: SCONJ (1.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.3%) | Top 2: SCONJ (0.7%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.4%) | Top 2: ADJ (28.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (62.8%) | Top 2: ADJ (30.7%) |
# ------------------------------------------------------------
#
# [Case #74] Sentence:  take care of special things *[SO]*  they don't get spoiled
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (83.6%) | Top 2: ADV (15.7%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (78.7%) | Top 2: ADV (20.7%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (95.5%) | Top 2: ADV (4.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.3%) | Top 2: ADV (3.4%) |
# ------------------------------------------------------------
#
# [Case #75] Sentence:  correctly, *[SO]*  they always worried about
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (79.2%) | Top 2: SCONJ (14.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (83.4%) | Top 2: SCONJ (11.3%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (50.1%) | Top 2: SCONJ (41.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (60.9%) | Top 2: SCONJ (28.8%) |
# ------------------------------------------------------------
#
# [Case #76] Sentence:  dishwasher in action, *[SO]*  she watched as her
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.4%) | Top 2: SCONJ (30.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.4%) | Top 2: SCONJ (6.0%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.8%) | Top 2: SCONJ (21.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.4%) | Top 2: SCONJ (9.2%) |
# ------------------------------------------------------------
#
# [Case #77] Sentence:  have to brush your teeth *[SO]*  they stay strong and
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.1%) | Top 2: ADV (12.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (77.0%) | Top 2: ADV (21.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.6%) | Top 2: ADV (3.1%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (94.0%) | Top 2: ADV (5.2%) |
# ------------------------------------------------------------
#
# [Case #78] Sentence:  Tim loved to draw, *[SO]*  he was very happy
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.9%) | Top 2: SCONJ (10.5%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.2%) | Top 2: SCONJ (24.9%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.5%) | Top 2: SCONJ (37.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (71.2%) | Top 2: SCONJ (17.3%) |
# ------------------------------------------------------------
#
# [Case #79] Sentence:  was behind the door, *[SO]*  he kept cleaning.
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (91.5%) | Top 2: SCONJ (5.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (70.7%) | Top 2: SCONJ (24.1%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (49.7%) | Top 2: ADV (48.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.3%) | Top 2: SCONJ (29.0%) |
# ------------------------------------------------------------
#
# [Case #80] Sentence:  crying. Daisy was curious *[SO]*  she kept walking towards
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.4%) | Top 2: SCONJ (48.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.4%) | Top 2: SCONJ (23.8%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (55.6%) | Top 2: ADV (44.2%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.3%) | Top 2: ADV (42.3%) |
# ------------------------------------------------------------
#
# [Case #81] Sentence: . Let's rush back home *[SO]*  you can take a
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (56.9%) | Top 2: SCONJ (42.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (66.6%) | Top 2: ADV (33.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (62.3%) | Top 2: SCONJ (37.6%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.5%) | Top 2: SCONJ (10.9%) |
# ------------------------------------------------------------
#
# [Case #82] Sentence:  to her and scared her *[SO]*  much that she ran
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.9%) | Top 2: SCONJ (9.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (94.9%) | Top 2: SCONJ (4.4%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (61.6%) | Top 2: ADV (37.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (81.5%) | Top 2: SCONJ (17.5%) |
# ------------------------------------------------------------
#
# [Case #83] Sentence: . "Wow, it's *[SO]*  cool! It makes
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (98.9%) | Top 2: DET (0.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (99.2%) | Top 2: PRON (0.4%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (97.0%) | Top 2: PRON (2.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.8%) | Top 2: PRON (23.5%) |
# ------------------------------------------------------------
#
# [Case #84] Sentence:  to help her grandma, *[SO]*  she went to the
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.3%) | Top 2: SCONJ (24.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.8%) | Top 2: SCONJ (5.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (83.9%) | Top 2: SCONJ (15.8%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.4%) | Top 2: SCONJ (4.1%) |
# ------------------------------------------------------------
#
# [Case #85] Sentence:  to play more quietly, *[SO]*  they tried their best
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (80.8%) | Top 2: SCONJ (13.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (76.1%) | Top 2: CCONJ (16.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.7%) | Top 2: SCONJ (26.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (78.5%) | Top 2: SCONJ (13.1%) |
# ------------------------------------------------------------
#
# [Case #86] Sentence:  wanted to buy something, *[SO]*  he walked into a
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.6%) | Top 2: SCONJ (27.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (88.4%) | Top 2: SCONJ (8.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.2%) | Top 2: SCONJ (11.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: SCONJ (3.5%) |
# ------------------------------------------------------------
#
# [Case #87] Sentence:  to play with it, *[SO]*  he ran fast to
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.9%) | Top 2: SCONJ (21.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.0%) | Top 2: SCONJ (15.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.1%) | Top 2: SCONJ (10.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.2%) | Top 2: SCONJ (3.0%) |
# ------------------------------------------------------------
#
# [Case #88] Sentence:  good care of his boat *[SO]*  that no part would
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (92.3%) | Top 2: SCONJ (6.9%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.1%) | Top 2: SCONJ (6.9%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (71.3%) | Top 2: SCONJ (27.5%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (75.8%) | Top 2: SCONJ (17.6%) |
# ------------------------------------------------------------
#
# ...
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: ADP (2.4%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (67.8%) | Top 2: ADP (27.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (84.3%) | Top 2: ADP (14.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (49.9%) | Top 2: ADP (49.1%) |
# ------------------------------------------------------------
#
# [Case #85] Sentence:  thanked Tim. They went *[BACK]*  home and played with
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.8%) | Top 2: ADP (21.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (99.7%) | Top 2: VERB (0.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (99.7%) | Top 2: ADJ (0.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (99.7%) | Top 2: ADJ (0.2%) |
# ------------------------------------------------------------
#
# [Case #86] Sentence:  and warm, they went *[BACK]*  home. Their mom
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.6%) | Top 2: VERB (21.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.8%) | Top 2: VERB (1.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (98.9%) | Top 2: VERB (0.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (88.4%) | Top 2: VERB (10.7%) |
# ------------------------------------------------------------
#
# [Case #87] Sentence:  help him get his notebook *[BACK]* . Max knew he
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.7%) | Top 2: NOUN (2.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (96.2%) | Top 2: ADJ (1.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.3%) | Top 2: ADP (3.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.8%) | Top 2: ADP (23.7%) |
# ------------------------------------------------------------
#
# [Case #88] Sentence:  nicely to give the notebook *[BACK]* . The big dog
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: ADP (4.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.2%) | Top 2: ADP (22.1%) |
#   layer_2 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (51.1%) | Top 2: ADV (46.9%) |
#   layer_3 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (75.0%) | Top 2: ADV (24.2%) |
# ------------------------------------------------------------
#
# [Case #89] Sentence:  was and gave the notebook *[BACK]* . Tim was happy
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (79.8%) | Top 2: NOUN (12.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.8%) | Top 2: ADP (7.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (70.8%) | Top 2: ADP (26.5%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (60.3%) | Top 2: ADP (37.7%) |
# ------------------------------------------------------------
#
# [Case #90] Sentence:  she was excited to go *[BACK]*  home and tell all
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.7%) | Top 2: VERB (29.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (96.8%) | Top 2: VERB (2.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (98.7%) | Top 2: VERB (1.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.2%) | Top 2: VERB (2.2%) |
# ------------------------------------------------------------
#
# [Case #91] Sentence:  the crane's *[BACK]* . They rode together
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.5%) | Top 2: NOUN (23.4%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (34.8%) | Top 2: NOUN (32.6%) |
#   layer_2 | Pred: NOUN | True: ADV ⚠️
#     Top 1: NOUN (46.1%) | Top 2: ADJ (25.5%) |
#   layer_3 | Pred: NOUN | True: ADV
#     Top 1: NOUN (59.3%) | Top 2: ADV (16.8%) |
# ------------------------------------------------------------
#
# [Case #92] Sentence:  not fair! Give me *[BACK]*  my tool."
# ------------------------------------------------------------
#   layer_0 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (51.9%) | Top 2: ADV (41.3%) |
#   layer_1 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (55.7%) | Top 2: ADV (40.0%) |
#   layer_2 | Pred: ADP | True: ADV
#     Top 1: ADP (81.1%) | Top 2: ADV (16.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.0%) | Top 2: ADP (47.4%) |
# ------------------------------------------------------------
#
# [Case #93] Sentence:  leash. When they came *[BACK]* , Max was happy
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (98.5%) | Top 2: ADP (0.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.3%) | Top 2: ADP (1.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.7%) | Top 2: ADP (23.5%) |
#   layer_3 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (48.3%) | Top 2: ADV (48.1%) |
# ------------------------------------------------------------
#
# [Case #94] Sentence:  don't know how to go *[BACK]* . "Tim,
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.5%) | Top 2: ADP (0.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (96.3%) | Top 2: ADP (2.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (81.1%) | Top 2: ADP (18.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.6%) | Top 2: ADP (24.4%) |
# ------------------------------------------------------------
# ✅ Found 94 interesting cases for ' back'.
#
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' it'
# ================================================================================
#
# [Case #1] Sentence:  my ball. I need *[IT]* ." Tim and
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.1%) | Top 2: NOUN (0.8%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (95.0%) | Top 2: NOUN (4.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.1%) | Top 2: NOUN (0.7%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.1%) | Top 2: NOUN (26.4%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  for the bird and gave *[IT]*  food and water every
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (69.4%) | Top 2: DET (28.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.7%) | Top 2: DET (0.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: DET (0.2%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: DET (0.1%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  they both realized how important *[IT]*  is to help and
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.3%) | Top 2: NOUN (0.7%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (96.5%) | Top 2: NOUN (3.4%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.8%) | Top 2: NOUN (1.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.3%) | Top 2: NOUN (27.5%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence: . She tried to pull *[IT]*  off, but it
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (89.1%) | Top 2: DET (6.8%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (98.0%) | Top 2: DET (1.6%) |
#   layer_2 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (77.4%) | Top 2: DET (20.1%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (89.1%) | Top 2: DET (7.5%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  she wanted to go down *[IT]* . Lily's mommy helped
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: ADV (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (86.1%) | Top 2: ADV (12.1%) |
#   layer_2 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (56.1%) | Top 2: ADV (43.4%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (75.0%) | Top 2: ADV (24.2%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  You need to pay for *[IT]* ." Lily felt
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (98.4%) | Top 2: NOUN (1.5%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.7%) | Top 2: NOUN (26.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.1%) | Top 2: NOUN (0.8%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (95.3%) | Top 2: NOUN (4.5%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  ball. He can bounce *[IT]* , throw it,
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (94.4%) | Top 2: ADV (4.9%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (93.7%) | Top 2: ADV (5.5%) |
#   layer_2 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.0%) | Top 2: ADV (26.4%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (71.4%) | Top 2: ADV (25.0%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence: , but he cannot catch *[IT]* . The ball goes
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (96.6%) | Top 2: NOUN (2.6%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (90.0%) | Top 2: NOUN (7.9%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (92.9%) | Top 2: ADV (4.3%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (60.1%) | Top 2: ADV (26.5%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  She wanted to slide down *[IT]* , but she was
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (97.1%) | Top 2: ADV (0.8%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (42.5%) | Top 2: ADV (40.6%) |
#   layer_2 | Pred: ADV | True: PRON ⚠️
#     Top 1: ADV (73.1%) | Top 2: PRON (21.8%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (46.7%) | Top 2: ADV (45.9%) |
# ------------------------------------------------------------
# ✅ Found 9 interesting cases for ' it'.
#
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' he'
# ================================================================================
#
# [Case #1] Sentence:  power wisely. Alice *[HE]* eded the bear
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: VERB
#     Top 1: PRON (90.0%) | Top 2: VERB (8.2%) |
#   layer_1 | Pred: PRON | True: VERB
#     Top 1: PRON (79.6%) | Top 2: VERB (9.8%) |
#   layer_2 | Pred: PRON | True: VERB ⚠️
#     Top 1: PRON (66.1%) | Top 2: VERB (21.1%) |
#   layer_3 | Pred: PRON | True: VERB ⚠️
#     Top 1: PRON (48.3%) | Top 2: ADV (27.9%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  wife who is now in *[HE]* aven. She
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PROPN
#     Top 1: PRON (62.3%) | Top 2: PROPN (18.3%) |
#   layer_1 | Pred: PROPN | True: PROPN
#     Top 1: PROPN (75.6%) | Top 2: PRON (14.7%) |
#   layer_2 | Pred: PROPN | True: PROPN ⚠️
#     Top 1: PROPN (54.6%) | Top 2: NOUN (23.5%) |
#   layer_3 | Pred: NOUN | True: PROPN
#     Top 1: NOUN (80.3%) | Top 2: PROPN (14.7%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  filled it with water and *[HE]* ated it up on
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: VERB
#     Top 1: PRON (93.3%) | Top 2: ADV (6.0%) |
#   layer_1 | Pred: PRON | True: VERB
#     Top 1: PRON (95.0%) | Top 2: ADV (4.5%) |
#   layer_2 | Pred: PRON | True: VERB
#     Top 1: PRON (82.9%) | Top 2: ADV (16.0%) |
#   layer_3 | Pred: PRON | True: VERB ⚠️
#     Top 1: PRON (74.2%) | Top 2: ADV (22.3%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  them instead. Lily was *[HE]* sitant at first
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (94.3%) | Top 2: ADV (3.9%) |
#   layer_1 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (65.8%) | Top 2: ADV (26.4%) |
#   layer_2 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (73.3%) | Top 2: ADV (24.0%) |
#   layer_3 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (62.7%) | Top 2: ADV (24.9%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  prize just because of his *[HE]* ight and hat.
# ------------------------------------------------------------
#   layer_0 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (62.0%) | Top 2: PRON (31.7%) |
#   layer_1 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (78.7%) | Top 2: PRON (16.4%) |
#   layer_2 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (79.1%) | Top 2: PRON (17.8%) |
#   layer_3 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (94.3%) | Top 2: PRON (3.4%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  all day long, and *[HE]*  learned that sometimes,
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: ADV (0.2%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.3%) | Top 2: ADV (0.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: ADV (2.1%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.1%) | Top 2: ADV (26.6%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  dreaming about all the fun *[HE]*  would have swinging on
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (81.8%) | Top 2: NOUN (18.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.5%) | Top 2: NOUN (26.3%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  the dog. Lily was *[HE]* sitant at first
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (92.8%) | Top 2: PROPN (3.1%) |
#   layer_1 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (54.5%) | Top 2: ADV (26.0%) |
#   layer_2 | Pred: PRON | True: ADJ
#     Top 1: PRON (89.5%) | Top 2: ADV (7.1%) |
#   layer_3 | Pred: PRON | True: ADJ
#     Top 1: PRON (79.2%) | Top 2: ADV (10.3%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  Without a moment's *[HE]* sitation, the
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: NOUN ⚠️
#     Top 1: PRON (69.0%) | Top 2: NOUN (29.9%) |
#   layer_1 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (69.1%) | Top 2: PRON (23.4%) |
#   layer_2 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (52.8%) | Top 2: PRON (44.4%) |
#   layer_3 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (95.6%) | Top 2: ADV (2.2%) |
# ------------------------------------------------------------
# ✅ Found 9 interesting cases for ' he'.

# %%
all_general_acc
# Out:
# [98.07286145802617, 98.04616206135283, 97.79710052522097, 97.63291916060285]

# %%
# IDEA DE GRAFICA: 

Causal vs Unmasking

ejex x layers 
eje y accuracy
4 lineas: net word gral accurayc and ambiguous
same apra unmasking


# TABLAS:
LAyesr vs modelo accuracys


# COMAPRACION 2

Palabras ambiguas . Calcular Accuracy promedio esa palabra en todas sus frases y compara mabas en causal y unmasking

# %%
def plot_probing_results(num_layers, general_accuracies, ambiguous_accuracies):
    layers = list(range(num_layers))
    plt.figure(figsize=(10, 6))
    plt.plot(layers, general_accuracies, marker='o', linestyle='-', linewidth=2, 
             color='blue', label='General POS Accuracy')
    plt.plot(layers, ambiguous_accuracies, marker='s', linestyle='--', linewidth=2, 
             color='orange', label='Ambiguous Words POS Accuracy')
    
    plt.title('Probing Analysis: Layer-by-Layer POS Information', fontsize=14)
    plt.xlabel('Transformer Layer', fontsize=12)
    plt.ylabel('Accuracy (%)', fontsize=12)
    plt.xticks(layers)
    plt.ylim(96.5, 98.5)
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend(fontsize=11, loc='lower right')
    plt.tight_layout()
    plt.show()


plot_probing_results(num_layers, all_general_acc, all_ambiguous_acc)
