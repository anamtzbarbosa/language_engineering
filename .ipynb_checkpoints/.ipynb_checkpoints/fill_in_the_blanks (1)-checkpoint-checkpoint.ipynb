# %%
import math
import torch
import random
import numpy as np
from torch import nn, optim

from datetime import datetime
from dataclasses import dataclass, asdict
from tokenizer import TinyStoriesTokenizer
from self_attention import MultiHeadSelfAttention

# %% [markdown]
# ## Transformer block
# To obtain a complete transformer block, we add a __position-wise feed-forward layer__ after the self-attention computation. The vectors are first projected to be 4 times wider, a non-linear ``relu'' function is applied, and the vectors are projected down to their original size.
#
# Before and after the self-attention computation, we add a __layer norm__ which normalizes each vector to have mean 0 and variance 1. This contributes to "numerical stability" in the forward pass, i.e. that the numbers within the vectors stay within the bounds representable by a computer.
#
# We also add __residual connections__ to each layer. In general, this means that we compute $x+f(x)$ rather than just $f(x)$ (the "$x+$" is sometimes called the "identity shortcut"). The gradient of $x+f(x)$ is $1+f'(x)$, which is close to 1 if $f'(x)$ is tiny. Without the identity shortcut, the overall gradient in the backward pass could be come extremely small, in particular in a deep network where many layers are stacked. The residual connection thus acts as a prevention for the "vanishing gradient" problem.

# %%
class PositionwiseFFN(nn.Module):
    """
    The position-wise FFN that follows after the self-attention computation.
    Vectors are projected to 4x the dimensionality and then projected down
    again after relu application.
    """

    def __init__(self, vector_dim, dropout_prob) :
        super().__init__()
        self.fc1 = nn.Linear(vector_dim, 4*vector_dim, bias=True)
        self.fc2 = nn.Linear(4*vector_dim, vector_dim, bias=True)
        self.dropout = nn.Dropout(dropout_prob)

    def forward(self, x):
        return self.fc2(self.dropout(torch.relu(self.fc1(x))))

class Block(nn.Module):
    """
    Transformer encoder block.

    This version differs from the original version in  [Vaswani et al. NeurIPS 2017],
    and applies the LayerNorm before the self-attention, and before the FFN, as this
    has proved to be beneficial (see [Nguyen and Salazar 2019]).
    """

    def __init__(self, vector_dim, n_heads, block_size, dropout_prob):
        super().__init__()
        att_dim = vector_dim // n_heads
        self.attn = MultiHeadSelfAttention(vector_dim, n_heads, block_size, is_causal=False) #MODIFY IMPO
        self.ffn = PositionwiseFFN(vector_dim, dropout_prob)
        self.dropout = nn.Dropout(dropout_prob)
        self.ln1 = nn.LayerNorm(vector_dim)
        self.ln2 = nn.LayerNorm(vector_dim)

    def forward(self, x):
        x1 = self.ln1(x) # pre layer norm
        x2 = x + self.dropout(self.attn(x1)) # attention + residual
        x3 = self.ln2(x2)
        x4 = x2 + self.dropout(self.ffn(x3)) # ffn + residual
        return x4

# %% [markdown]
# ## Fill in the blanks

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000 + 1  # This number should agree with the tokenizer
    mask_token_id: int = 5000  # new token forn unmasking
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 4
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1


class TinyStoriesLM(nn.Module):

    def __init__(self, config):
        super(TinyStoriesLM, self).__init__()
        self.config = config
        self.embed =  nn.Embedding(config.vocab_size, config.vector_dim)
        self.positional = nn.Parameter(torch.randn(1, config.block_size, config.vector_dim)) # learns during trianing, beginning random
        modules = [Block(config.vector_dim,\
                         config.number_of_attention_heads,\
                         config.block_size,\
                         config.dropout_prob) for _ in range(config.number_of_transformer_blocks)]
        self.transformers = nn.ModuleList(modules)
        self.final = nn.Linear(config.vector_dim, config.vocab_size)

    def forward(self, x):
        # x size (B, S)
        # each element is a token-word -> transf it to vector
        B, S = x.shape

        # Embedding (B, S, vector_dim)
        token_embeddings = self.embed(x) # each num.token is now a 256 len vector

        # Position Embedding - size ( 1, blocksize, vector_dim) -> S increasing as model generates more words
        pos_embeddings = self.positional[:, :S, :] # (1, S, vector_dim)

        x = token_embeddings + pos_embeddings # (B, S, vector_dim)

        # TRANSFORMERS BLOCK
        for block in self.transformers:
            x = block(x)
        # output - same len but with more context

        # Project to 5_001 words. For each pos - how probable for next word to be ... from 0-4999
        logits = self.final(x) # (B, S, vector_dim) to (B, S, vocab_size)

        # YOUR CODE HERE

        return logits

    @classmethod
    def load(cls, checkpoint_path, device='cpu'):
        """
        Loads a model from a checkpoint file.
        Automatically reconstructs the config and model architecture.
        """
        checkpoint = torch.load(checkpoint_path, map_location=device)
        config = Config(**checkpoint['config'])
        model = cls(config)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(device)

        print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']}, iteration {checkpoint['iteration']})")
        return model

# %% [markdown]
# ### Dataset
# In order to save disk space, we have already tokenized the Tiny Stories dataset for you (this allows every group to share the same file rather than construct theit own, several-GB file). The pretokenized dataset resides in a binary file, and the "TinyStoriesDataset" class below reads from this file.
#
# The "ResumableRandomSampler" class allows us to resume training after a pause, without repeating any previously processed datapoints from the training set.

# %%
from torch.utils.data import Sampler, SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from tokenizer import TinyStoriesTokenizer

class MaskedTinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size, vocab_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size
        self.mask_token_id = vocab_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):

        """
        For each input sentence, randomly select 15% of the tokens.
        We call these “selected tokens”. Of the selected tokens, and replace 80% with “[MASK]”, 10% with a random word, and leave 10% unchanged.
        Train the model to predict the original identity of all selected tokens.
        Note that your loss function should only be calculated over the selected tokens
        """
        # Pull a chunk of length block_size 
        chunk = self.data[idx : idx + self.block_size]
        chunk = torch.from_numpy(chunk.astype(np.int64))
        original = chunk.clone()     # original
        masked_input = chunk.clone() # modified

        # randomly select 15%
        probs = torch.full(original.shape, 0.15)
        selected_idx = torch.bernoulli(probs).bool()

        # 15% si what we want to predict
        # From 15%:

        for idx in selected_idx.nonzero(as_tuple=True)[0]: # give me the idx of the rows where ture in selected_idx
          r = random.random()
          if r < 0.80:
              masked_input[idx] = self.mask_token_id # 80% time we replace with mask [MASK]
          elif r < 0.90:
              masked_input[idx] = random.randint(0, self.mask_token_id-1)  # 10% replace with random word, exlcuidng mask
          # else: 10% remains the same


        return masked_input, original, selected_idx


# This class facilitates re-starting training without repeating any past training examples
class ResumableRandomSampler(Sampler):
    def __init__(self, data_source, start_index=0, seed=42):
        self.data_source = data_source
        self.start_index = start_index
        self.seed = seed
        self.generator = torch.Generator()
        self.generator.manual_seed(self.seed)

        # 1. Generate the full shuffled list of indices once
        self.indices = torch.randperm(len(self.data_source), generator=self.generator).tolist()

    def __iter__(self):
        # 2. Slice the indices to only include those from start_index onwards
        return iter(self.indices[self.start_index:])

    def __len__(self):
        return len(self.indices) - self.start_index

# %%
import os

# ======================= Training ======================= #

# Remove the checkpoint file if you want to train from scratch
checkpoint_path = 'last_checkpoint_none.pt'
RESUME_TRAINING = os.path.exists(checkpoint_path)

seed = 42
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print( "Running on", device )

tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')
# IMPO Add [MASK] to tokens
mask_token = "[MASK]"
if mask_token not in tokenizer.vocab:
    tokenizer.vocab.append(mask_token)
    tokenizer.vocab_size += 1
mask_id = len(tokenizer.vocab) - 1 

if RESUME_TRAINING:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']+1}, iteration {checkpoint['iteration']})")
    config = Config(**checkpoint['config'])
    lm = TinyStoriesLM(config)
    # Sanity check
    if tokenizer.vocab_size != lm.config.vocab_size:
        print("WARNING: The tokenizer's and the model's vocab_size are different!")
    lm.load_state_dict(checkpoint['model_state_dict'])
    lm.to(device)
else :
    config = Config()
    config.vocab_size = tokenizer.vocab_size  # 5001
    config.mask_token_id = tokenizer.vocab_size - 1  # 5000
    print('len tokenizer: ', len(tokenizer.vocab))
    lm = TinyStoriesLM(config).to(device)

lm_optimizer = torch.optim.AdamW(lm.parameters(), lr=lm.config.learning_rate, weight_decay=config.weight_decay)

if RESUME_TRAINING:
    lm_optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

training_dataset = MaskedTinyStoriesDataset('/datasets/dd2417/train.bin', config.block_size, config.mask_token_id)

# Development set
dev_dataset = MaskedTinyStoriesDataset('/datasets/dd2417/dev.bin', config.block_size, config.mask_token_id)
# Create indices that jump by the block size. This ensures we only see each
# chunk of text once when computing validation loss.
dev_indices = list(range(0, len(dev_dataset), config.block_size))
dev_subset = torch.utils.data.Subset(dev_dataset, dev_indices)
dev_loader = DataLoader(dev_subset, config.batch_size, pin_memory=True)

print( "There are", len(training_dataset), "datapoints and", tokenizer.vocab_size, "token classes in the dataset" )

criterion = nn.CrossEntropyLoss()

lm.train()
running_loss = 0
print( datetime.now().strftime("%X"), "Training starts" )
# Can we pick up where we left off?
start_epoch = checkpoint['epoch'] if RESUME_TRAINING else 0
start_iter = checkpoint['iteration'] if RESUME_TRAINING else 0

# CHANGE
for epoch in range(start_epoch, config.no_of_epochs) :
    iteration = start_iter if epoch == start_epoch else 0
    # Random sampling of datapoints. Note that we use a new seed for each epoch
    # -- this will guarantee that we can resume the training anywhere without
    # repeating any datapoints within an epoch.
    sampler = ResumableRandomSampler(training_dataset,
                                     start_index=iteration * config.batch_size,
                                     seed=seed+epoch)
    training_loader = DataLoader(training_dataset,
                                 batch_size=config.batch_size,
                                 sampler=sampler,
                                 num_workers=4)
    for masked_input, original, selected in training_loader:
        masked_input, original, selected = masked_input.to(device), original.to(device), selected.to(device)
        lm_optimizer.zero_grad()

        logits = lm(masked_input) 
        # masked input (15% - 80-10-10)-> what model sees | original -> what to predict | selected -> boolean, where calculate loss (random 15%)
        loss = criterion(logits[selected],  original[selected] )
        loss.backward() # gradients
        lm_optimizer.step() # update weights


        running_loss += loss.detach().item()
        iteration += 1
        if iteration%100 == 0:
            # Compute validation loss every 100 iterations
            # CHANGE
            lm.eval()
            with torch.no_grad():
                total_loss = 0
                for vx, vy, v_selected in dev_loader:
                  vx, vy, v_selected = vx.to(device), vy.to(device), v_selected.to(device)
                  logits = lm(vx)
                  val_loss = criterion(logits[v_selected], vy[v_selected])
                  total_loss += val_loss.item()
                print(f'{datetime.now().strftime("%X")} Epoch {epoch+1}, iteration {iteration}: loss={running_loss/100:.4f}, dev loss={total_loss/len(dev_loader):.4f}')
            lm.train()
            running_loss = 0
        if iteration%10000 == 0:
            checkpoint = {
                'model_state_dict': lm.state_dict(),
                'optimizer_state_dict': lm_optimizer.state_dict(),
                'epoch': epoch,
                'iteration': iteration,
                'config': config.__dict__, # Useful so you know the architecture later
            }

            # Overwrites the same file every time to save space
            torch.save(checkpoint, checkpoint_path)
            print(f"Checkpoint saved to {checkpoint_path}")

            # CHANGE how to show progress
            lm.eval()
            with torch.no_grad():
              sample_input, sample_original, sample_selected = next(iter(dev_loader))
              sample_input = sample_input.to(device)
              sample_original = sample_original.to(device)
              sample_selected = sample_selected.to(device)
              
              logits = lm(sample_input)
              predictions = logits.argmax(dim=-1)  # token max porbability
              
              # Get the indx for selected -> jsut print the first 5 tokens first example
              selected_positions = sample_selected[0].nonzero(as_tuple=True)[0][:5]
              print("-" * 30)
              for pos in selected_positions:
                  predicted = tokenizer.vocab[predictions[0][pos].item()]
                  original  = tokenizer.vocab[sample_original[0][pos].item()]
                  masked    = sample_input[0][pos].item()
                  print(f"original: {original:15} | prediction: {predicted:15} | actual [MASK]: {masked == config.mask_token_id}")
              print("-" * 30)
            lm.train()
# Out:
# Running on cuda
# len tokenizer:  5001
# There are 18507842 datapoints and 5001 token classes in the dataset
# 21:53:26 Training starts
# 21:53:38 Epoch 1, iteration 100: loss=6.1340, dev loss=5.7768
# 21:53:48 Epoch 1, iteration 200: loss=5.7725, dev loss=5.6634
# 21:53:57 Epoch 1, iteration 300: loss=5.6387, dev loss=5.5958
# 21:54:07 Epoch 1, iteration 400: loss=5.5915, dev loss=5.5498
# 21:54:14 Epoch 1, iteration 500: loss=5.5628, dev loss=5.5410
# 21:54:17 Epoch 1, iteration 600: loss=5.5108, dev loss=5.5015
# 21:54:20 Epoch 1, iteration 700: loss=5.5248, dev loss=5.4669
# 21:54:23 Epoch 1, iteration 800: loss=5.4975, dev loss=5.4527
# 21:54:28 Epoch 1, iteration 900: loss=5.4752, dev loss=5.4462
# 21:54:39 Epoch 1, iteration 1000: loss=5.4732, dev loss=5.4239
# 21:54:48 Epoch 1, iteration 1100: loss=5.4812, dev loss=5.4178
# 21:54:58 Epoch 1, iteration 1200: loss=5.4509, dev loss=5.4147
# 21:55:08 Epoch 1, iteration 1300: loss=5.4279, dev loss=5.4125
# 21:55:17 Epoch 1, iteration 1400: loss=5.3932, dev loss=5.4291
# 21:55:26 Epoch 1, iteration 1500: loss=5.4183, dev loss=5.3848
# 21:55:36 Epoch 1, iteration 1600: loss=5.4131, dev loss=5.3808
# 21:55:45 Epoch 1, iteration 1700: loss=5.3876, dev loss=5.3598
# 21:55:55 Epoch 1, iteration 1800: loss=5.3966, dev loss=5.3760
# 21:56:04 Epoch 1, iteration 1900: loss=5.4010, dev loss=5.4184
# 21:56:14 Epoch 1, iteration 2000: loss=5.3802, dev loss=5.3591
# 21:56:24 Epoch 1, iteration 2100: loss=5.3695, dev loss=5.3565
# 21:56:34 Epoch 1, iteration 2200: loss=5.3940, dev loss=5.3744
# 21:56:43 Epoch 1, iteration 2300: loss=5.3900, dev loss=5.3470
# 21:56:53 Epoch 1, iteration 2400: loss=5.3803, dev loss=5.3679
# 21:57:02 Epoch 1, iteration 2500: loss=5.3496, dev loss=5.3415
# 21:57:12 Epoch 1, iteration 2600: loss=5.3672, dev loss=5.3651
# 21:57:21 Epoch 1, iteration 2700: loss=5.3701, dev loss=5.3589
# 21:57:31 Epoch 1, iteration 2800: loss=5.3518, dev loss=5.3274
# 21:57:41 Epoch 1, iteration 2900: loss=5.3509, dev loss=5.3258
# 21:57:50 Epoch 1, iteration 3000: loss=5.3290, dev loss=5.3254
# 21:58:00 Epoch 1, iteration 3100: loss=5.3487, dev loss=5.3331
# 21:58:09 Epoch 1, iteration 3200: loss=5.3447, dev loss=5.3748
# 21:58:19 Epoch 1, iteration 3300: loss=5.3396, dev loss=5.3255
# 21:58:28 Epoch 1, iteration 3400: loss=5.3346, dev loss=5.3104
# 21:58:38 Epoch 1, iteration 3500: loss=5.3428, dev loss=5.3398
# 21:58:47 Epoch 1, iteration 3600: loss=5.3401, dev loss=5.3405
# 21:58:57 Epoch 1, iteration 3700: loss=5.3189, dev loss=5.3281
# 21:59:07 Epoch 1, iteration 3800: loss=5.3438, dev loss=5.3077
# 21:59:16 Epoch 1, iteration 3900: loss=5.3386, dev loss=5.3027
# 21:59:26 Epoch 1, iteration 4000: loss=5.3297, dev loss=5.3164
# 21:59:35 Epoch 1, iteration 4100: loss=5.3186, dev loss=5.2918
# 21:59:45 Epoch 1, iteration 4200: loss=5.3050, dev loss=5.3203
# 21:59:55 Epoch 1, iteration 4300: loss=5.3165, dev loss=5.2933
# 22:00:04 Epoch 1, iteration 4400: loss=5.3064, dev loss=5.2684
# 22:00:14 Epoch 1, iteration 4500: loss=5.2999, dev loss=5.3126
# 22:00:24 Epoch 1, iteration 4600: loss=5.3049, dev loss=5.2912
# 22:00:33 Epoch 1, iteration 4700: loss=5.3055, dev loss=5.2542
# 22:00:43 Epoch 1, iteration 4800: loss=5.2923, dev loss=5.2909
# 22:00:53 Epoch 1, iteration 4900: loss=5.2960, dev loss=5.2790
# 22:01:02 Epoch 1, iteration 5000: loss=5.3094, dev loss=5.2705
# 22:01:12 Epoch 1, iteration 5100: loss=5.2841, dev loss=5.2633
# 22:01:21 Epoch 1, iteration 5200: loss=5.2566, dev loss=5.2776
# 22:01:30 Epoch 1, iteration 5300: loss=5.2670, dev loss=5.2328
# 22:01:40 Epoch 1, iteration 5400: loss=5.2390, dev loss=5.2276
# 22:01:50 Epoch 1, iteration 5500: loss=5.2417, dev loss=5.2448
# 22:01:59 Epoch 1, iteration 5600: loss=5.2476, dev loss=5.2535
# 22:02:09 Epoch 1, iteration 5700: loss=5.2271, dev loss=5.2214
# 22:02:18 Epoch 1, iteration 5800: loss=5.2220, dev loss=5.2394
# 22:02:25 Epoch 1, iteration 5900: loss=5.2257, dev loss=5.1864
# 22:02:28 Epoch 1, iteration 6000: loss=5.2290, dev loss=5.2074
# 22:02:31 Epoch 1, iteration 6100: loss=5.2169, dev loss=5.1735
# 22:02:35 Epoch 1, iteration 6200: loss=5.2113, dev loss=5.2123
# 22:02:39 Epoch 1, iteration 6300: loss=5.1989, dev loss=5.1681
# 22:02:49 Epoch 1, iteration 6400: loss=5.1544, dev loss=5.1563
# 22:03:00 Epoch 1, iteration 6500: loss=5.1531, dev loss=5.1450
# 22:03:09 Epoch 1, iteration 6600: loss=5.1475, dev loss=5.1427
# 22:03:18 Epoch 1, iteration 6700: loss=5.1350, dev loss=5.0814
# 22:03:28 Epoch 1, iteration 6800: loss=5.1162, dev loss=5.1085
# 22:03:38 Epoch 1, iteration 6900: loss=5.1072, dev loss=5.1015
# 22:03:48 Epoch 1, iteration 7000: loss=5.0894, dev loss=5.0116
# 22:03:57 Epoch 1, iteration 7100: loss=5.0362, dev loss=4.9914
# 22:04:07 Epoch 1, iteration 7200: loss=5.0089, dev loss=4.9308
# 22:04:17 Epoch 1, iteration 7300: loss=4.9134, dev loss=4.8550
# 22:04:26 Epoch 1, iteration 7400: loss=4.8427, dev loss=4.7844
# 22:04:36 Epoch 1, iteration 7500: loss=4.7477, dev loss=4.6564
# 22:04:45 Epoch 1, iteration 7600: loss=4.6452, dev loss=4.5561
# 22:04:54 Epoch 1, iteration 7700: loss=4.5334, dev loss=4.4426
# 22:05:04 Epoch 1, iteration 7800: loss=4.4631, dev loss=4.3565
# 22:05:14 Epoch 1, iteration 7900: loss=4.3241, dev loss=4.2296
# 22:05:24 Epoch 1, iteration 8000: loss=4.2570, dev loss=4.1258
# 22:05:33 Epoch 1, iteration 8100: loss=4.1484, dev loss=4.1173
# 22:05:43 Epoch 1, iteration 8200: loss=4.0962, dev loss=3.9930
# 22:05:53 Epoch 1, iteration 8300: loss=4.0195, dev loss=3.9058
# 22:06:02 Epoch 1, iteration 8400: loss=3.9417, dev loss=3.8398
# 22:06:12 Epoch 1, iteration 8500: loss=3.8824, dev loss=3.7778
# 22:06:21 Epoch 1, iteration 8600: loss=3.8412, dev loss=3.7116
# 22:06:31 Epoch 1, iteration 8700: loss=3.7829, dev loss=3.6484
# 22:06:41 Epoch 1, iteration 8800: loss=3.7170, dev loss=3.6296
# 22:06:50 Epoch 1, iteration 8900: loss=3.6711, dev loss=3.5665
# 22:06:59 Epoch 1, iteration 9000: loss=3.6132, dev loss=3.5408
# 22:07:09 Epoch 1, iteration 9100: loss=3.5709, dev loss=3.4851
# 22:07:19 Epoch 1, iteration 9200: loss=3.5330, dev loss=3.4560
# 22:07:28 Epoch 1, iteration 9300: loss=3.4900, dev loss=3.4521
# 22:07:37 Epoch 1, iteration 9400: loss=3.4949, dev loss=3.3885
# 22:07:47 Epoch 1, iteration 9500: loss=3.4275, dev loss=3.3459
# 22:07:56 Epoch 1, iteration 9600: loss=3.3940, dev loss=3.3262
# 22:08:05 Epoch 1, iteration 9700: loss=3.3770, dev loss=3.2822
# 22:08:15 Epoch 1, iteration 9800: loss=3.3365, dev loss=3.2414
# 22:08:24 Epoch 1, iteration 9900: loss=3.3149, dev loss=3.2123
# 22:08:34 Epoch 1, iteration 10000: loss=3.2785, dev loss=3.1956
# Checkpoint saved to last_checkpoint_none.pt
# ------------------------------
# original:  little         | prediction:  little         | actual [MASK]: False
# original:  boy            | prediction:  boy            | actual [MASK]: True
# original: .               | prediction:  loved          | actual [MASK]: True
# original:  fish           | prediction:  water          | actual [MASK]: True
# original: !               | prediction:  and            | actual [MASK]: True
# ------------------------------
# 22:08:44 Epoch 1, iteration 10100: loss=3.2548, dev loss=3.1523
# 22:08:54 Epoch 1, iteration 10200: loss=3.2320, dev loss=3.1550
# 22:09:03 Epoch 1, iteration 10300: loss=3.1841, dev loss=3.0868
# 22:09:12 Epoch 1, iteration 10400: loss=3.1933, dev loss=3.0804
# 22:09:22 Epoch 1, iteration 10500: loss=3.1493, dev loss=3.0462
# 22:09:32 Epoch 1, iteration 10600: loss=3.0978, dev loss=3.0237
# 22:09:42 Epoch 1, iteration 10700: loss=3.1272, dev loss=2.9883
# 22:09:51 Epoch 1, iteration 10800: loss=3.0727, dev loss=2.9891
# 22:10:01 Epoch 1, iteration 10900: loss=3.0442, dev loss=2.9718
# 22:10:10 Epoch 1, iteration 11000: loss=3.0263, dev loss=2.9490
# 22:10:20 Epoch 1, iteration 11100: loss=3.0136, dev loss=2.9250
# 22:10:29 Epoch 1, iteration 11200: loss=3.0001, dev loss=2.8928
# 22:10:36 Epoch 1, iteration 11300: loss=3.0052, dev loss=2.9089
# 22:10:39 Epoch 1, iteration 11400: loss=2.9751, dev loss=2.8858
# 22:10:42 Epoch 1, iteration 11500: loss=2.9571, dev loss=2.8552
# 22:10:45 Epoch 1, iteration 11600: loss=2.9668, dev loss=2.8533
# 22:10:50 Epoch 1, iteration 11700: loss=2.9159, dev loss=2.8027
# 22:11:00 Epoch 1, iteration 11800: loss=2.8941, dev loss=2.7993
# 22:11:10 Epoch 1, iteration 11900: loss=2.8861, dev loss=2.7564
# 22:11:19 Epoch 1, iteration 12000: loss=2.8713, dev loss=2.7430
# 22:11:29 Epoch 1, iteration 12100: loss=2.8239, dev loss=2.7385
# 22:11:39 Epoch 1, iteration 12200: loss=2.8287, dev loss=2.7292
# 22:11:48 Epoch 1, iteration 12300: loss=2.7993, dev loss=2.7073
# 22:11:58 Epoch 1, iteration 12400: loss=2.7887, dev loss=2.6821
# 22:12:07 Epoch 1, iteration 12500: loss=2.7697, dev loss=2.6942
# 22:12:16 Epoch 1, iteration 12600: loss=2.7555, dev loss=2.6485
# 22:12:26 Epoch 1, iteration 12700: loss=2.7331, dev loss=2.6505
# 22:12:35 Epoch 1, iteration 12800: loss=2.7302, dev loss=2.6297
# 22:12:45 Epoch 1, iteration 12900: loss=2.6886, dev loss=2.6111
# 22:12:55 Epoch 1, iteration 13000: loss=2.7011, dev loss=2.5928
# 22:13:04 Epoch 1, iteration 13100: loss=2.6853, dev loss=2.6247
# 22:13:14 Epoch 1, iteration 13200: loss=2.6886, dev loss=2.5739
# 22:13:23 Epoch 1, iteration 13300: loss=2.6596, dev loss=2.5617
# 22:13:33 Epoch 1, iteration 13400: loss=2.6139, dev loss=2.5475
# 22:13:42 Epoch 1, iteration 13500: loss=2.6107, dev loss=2.5380
# 22:13:52 Epoch 1, iteration 13600: loss=2.5973, dev loss=2.5006
# 22:14:01 Epoch 1, iteration 13700: loss=2.5952, dev loss=2.5215
# 22:14:11 Epoch 1, iteration 13800: loss=2.5953, dev loss=2.4897
# 22:14:20 Epoch 1, iteration 13900: loss=2.5786, dev loss=2.5155
# 22:14:29 Epoch 1, iteration 14000: loss=2.5637, dev loss=2.4723
# 22:14:39 Epoch 1, iteration 14100: loss=2.5571, dev loss=2.4549
# 22:14:48 Epoch 1, iteration 14200: loss=2.5203, dev loss=2.4714
# 22:14:58 Epoch 1, iteration 14300: loss=2.5178, dev loss=2.4316
# 22:15:07 Epoch 1, iteration 14400: loss=2.5288, dev loss=2.4257
# 22:15:17 Epoch 1, iteration 14500: loss=2.5009, dev loss=2.3972
# 22:15:27 Epoch 1, iteration 14600: loss=2.4608, dev loss=2.3764
# 22:15:36 Epoch 1, iteration 14700: loss=2.4850, dev loss=2.3778
# 22:15:46 Epoch 1, iteration 14800: loss=2.4880, dev loss=2.3661
# 22:15:55 Epoch 1, iteration 14900: loss=2.4606, dev loss=2.3566
# 22:16:05 Epoch 1, iteration 15000: loss=2.4321, dev loss=2.3697
# 22:16:14 Epoch 1, iteration 15100: loss=2.4144, dev loss=2.3574
# 22:16:24 Epoch 1, iteration 15200: loss=2.4538, dev loss=2.3368
# 22:16:34 Epoch 1, iteration 15300: loss=2.4237, dev loss=2.3144
# 22:16:43 Epoch 1, iteration 15400: loss=2.4046, dev loss=2.3115
# 22:16:53 Epoch 1, iteration 15500: loss=2.3967, dev loss=2.3218
# 22:17:02 Epoch 1, iteration 15600: loss=2.4034, dev loss=2.2761
# 22:17:10 Epoch 1, iteration 15700: loss=2.3805, dev loss=2.2802
# 22:17:19 Epoch 1, iteration 15800: loss=2.3710, dev loss=2.2873
# 22:17:28 Epoch 1, iteration 15900: loss=2.3560, dev loss=2.2529
# 22:17:38 Epoch 1, iteration 16000: loss=2.3424, dev loss=2.2335
# 22:17:48 Epoch 1, iteration 16100: loss=2.3337, dev loss=2.2215
# 22:17:57 Epoch 1, iteration 16200: loss=2.3212, dev loss=2.2452
# 22:18:06 Epoch 1, iteration 16300: loss=2.2968, dev loss=2.2308
# 22:18:16 Epoch 1, iteration 16400: loss=2.2841, dev loss=2.2005
# 22:18:26 Epoch 1, iteration 16500: loss=2.3146, dev loss=2.2034
# 22:18:36 Epoch 1, iteration 16600: loss=2.3095, dev loss=2.1862
# 22:18:44 Epoch 1, iteration 16700: loss=2.3042, dev loss=2.1521
# 22:18:50 Epoch 1, iteration 16800: loss=2.2764, dev loss=2.1432
# 22:18:53 Epoch 1, iteration 16900: loss=2.2680, dev loss=2.1606
# 22:18:56 Epoch 1, iteration 17000: loss=2.2458, dev loss=2.1699
# 22:18:59 Epoch 1, iteration 17100: loss=2.2495, dev loss=2.1406
# 22:19:04 Epoch 1, iteration 17200: loss=2.2247, dev loss=2.1389
# 22:19:15 Epoch 1, iteration 17300: loss=2.2275, dev loss=2.1363
# 22:19:25 Epoch 1, iteration 17400: loss=2.2148, dev loss=2.1283
# 22:19:34 Epoch 1, iteration 17500: loss=2.2128, dev loss=2.1103
# 22:19:44 Epoch 1, iteration 17600: loss=2.1760, dev loss=2.1085
# 22:19:53 Epoch 1, iteration 17700: loss=2.1990, dev loss=2.0539
# 22:20:02 Epoch 1, iteration 17800: loss=2.1615, dev loss=2.0915
# 22:20:11 Epoch 1, iteration 17900: loss=2.1870, dev loss=2.0593
# 22:20:21 Epoch 1, iteration 18000: loss=2.1709, dev loss=2.0548
# 22:20:30 Epoch 1, iteration 18100: loss=2.1661, dev loss=2.0601
# 22:20:40 Epoch 1, iteration 18200: loss=2.1576, dev loss=2.0558
# 22:20:50 Epoch 1, iteration 18300: loss=2.1180, dev loss=2.0735
# 22:20:59 Epoch 1, iteration 18400: loss=2.1221, dev loss=2.0140
# 22:21:09 Epoch 1, iteration 18500: loss=2.1266, dev loss=2.0199
# 22:21:18 Epoch 1, iteration 18600: loss=2.1093, dev loss=2.0135
# 22:21:28 Epoch 1, iteration 18700: loss=2.1054, dev loss=2.0219
# 22:21:37 Epoch 1, iteration 18800: loss=2.1293, dev loss=1.9894
# 22:21:47 Epoch 1, iteration 18900: loss=2.1100, dev loss=1.9907
# 22:21:57 Epoch 1, iteration 19000: loss=2.1012, dev loss=2.0204
# 22:22:07 Epoch 1, iteration 19100: loss=2.0746, dev loss=1.9651
# 22:22:17 Epoch 1, iteration 19200: loss=2.0865, dev loss=1.9518
# 22:22:26 Epoch 1, iteration 19300: loss=2.0834, dev loss=1.9791
# 22:22:36 Epoch 1, iteration 19400: loss=2.0708, dev loss=1.9508
# 22:22:45 Epoch 1, iteration 19500: loss=2.0692, dev loss=1.9754
# 22:22:55 Epoch 1, iteration 19600: loss=2.0370, dev loss=1.9830
# 22:23:04 Epoch 1, iteration 19700: loss=2.0477, dev loss=1.9618
# 22:23:14 Epoch 1, iteration 19800: loss=2.0275, dev loss=1.9560
# 22:23:24 Epoch 1, iteration 19900: loss=2.0481, dev loss=1.9239
# 22:23:33 Epoch 1, iteration 20000: loss=2.0196, dev loss=1.9562
# Checkpoint saved to last_checkpoint_none.pt
# ------------------------------
# original: ,               | prediction: ,               | actual [MASK]: True
# original:  boy            | prediction:  boy            | actual [MASK]: True
# original: .               | prediction: .               | actual [MASK]: True
# original:  to             | prediction:  to             | actual [MASK]: False
# original:  so             | prediction:  so             | actual [MASK]: True
# ------------------------------
# 22:23:43 Epoch 1, iteration 20100: loss=2.0257, dev loss=1.9286
# 22:23:53 Epoch 1, iteration 20200: loss=2.0114, dev loss=1.9355
# 22:24:02 Epoch 1, iteration 20300: loss=2.0103, dev loss=1.9176
# 22:24:11 Epoch 1, iteration 20400: loss=1.9897, dev loss=1.8828
# 22:24:21 Epoch 1, iteration 20500: loss=2.0200, dev loss=1.9010
# 22:24:30 Epoch 1, iteration 20600: loss=1.9872, dev loss=1.9138
# 22:24:39 Epoch 1, iteration 20700: loss=1.9891, dev loss=1.8701
# 22:24:49 Epoch 1, iteration 20800: loss=1.9634, dev loss=1.8625
# 22:24:59 Epoch 1, iteration 20900: loss=1.9791, dev loss=1.8884
# 22:25:08 Epoch 1, iteration 21000: loss=1.9872, dev loss=1.8789
# 22:25:17 Epoch 1, iteration 21100: loss=1.9662, dev loss=1.8540
# 22:25:27 Epoch 1, iteration 21200: loss=1.9779, dev loss=1.8721
# 22:25:36 Epoch 1, iteration 21300: loss=1.9500, dev loss=1.8467
# 22:25:46 Epoch 1, iteration 21400: loss=1.9421, dev loss=1.8717
# 22:25:56 Epoch 1, iteration 21500: loss=1.9555, dev loss=1.8740
# 22:26:05 Epoch 1, iteration 21600: loss=1.9230, dev loss=1.8204
# 22:26:15 Epoch 1, iteration 21700: loss=1.9200, dev loss=1.8404
# 22:26:25 Epoch 1, iteration 21800: loss=1.9224, dev loss=1.8331
# 22:26:34 Epoch 1, iteration 21900: loss=1.9373, dev loss=1.8295
# 22:26:44 Epoch 1, iteration 22000: loss=1.9316, dev loss=1.8129
# 22:26:53 Epoch 1, iteration 22100: loss=1.9235, dev loss=1.8291
# 22:27:00 Epoch 1, iteration 22200: loss=1.9189, dev loss=1.8379
# 22:27:03 Epoch 1, iteration 22300: loss=1.9147, dev loss=1.7852
# 22:27:07 Epoch 1, iteration 22400: loss=1.9361, dev loss=1.8222
# 22:27:10 Epoch 1, iteration 22500: loss=1.9064, dev loss=1.7894
# 22:27:14 Epoch 1, iteration 22600: loss=1.8982, dev loss=1.8021
# 22:27:25 Epoch 1, iteration 22700: loss=1.9036, dev loss=1.7840
# 22:27:35 Epoch 1, iteration 22800: loss=1.8899, dev loss=1.7800
# 22:27:44 Epoch 1, iteration 22900: loss=1.9007, dev loss=1.7644
# 22:27:54 Epoch 1, iteration 23000: loss=1.8887, dev loss=1.7569
# 22:28:03 Epoch 1, iteration 23100: loss=1.8761, dev loss=1.7935
# 22:28:13 Epoch 1, iteration 23200: loss=1.8640, dev loss=1.7855
# 22:28:22 Epoch 1, iteration 23300: loss=1.8419, dev loss=1.7663
# 22:28:32 Epoch 1, iteration 23400: loss=1.8316, dev loss=1.7682
# 22:28:42 Epoch 1, iteration 23500: loss=1.8499, dev loss=1.7685
# 22:28:52 Epoch 1, iteration 23600: loss=1.8589, dev loss=1.7824
# 22:29:02 Epoch 1, iteration 23700: loss=1.8567, dev loss=1.7556
# 22:29:11 Epoch 1, iteration 23800: loss=1.8539, dev loss=1.7450
# 22:29:20 Epoch 1, iteration 23900: loss=1.8590, dev loss=1.7459
# 22:29:30 Epoch 1, iteration 24000: loss=1.8296, dev loss=1.7680
# 22:29:39 Epoch 1, iteration 24100: loss=1.8587, dev loss=1.7286
# 22:29:49 Epoch 1, iteration 24200: loss=1.8261, dev loss=1.7202
# 22:29:58 Epoch 1, iteration 24300: loss=1.8454, dev loss=1.7411
# 22:30:08 Epoch 1, iteration 24400: loss=1.8381, dev loss=1.7280
# 22:30:18 Epoch 1, iteration 24500: loss=1.7959, dev loss=1.7190
# 22:30:27 Epoch 1, iteration 24600: loss=1.8053, dev loss=1.7107
# 22:30:37 Epoch 1, iteration 24700: loss=1.8178, dev loss=1.7026
# 22:30:46 Epoch 1, iteration 24800: loss=1.8003, dev loss=1.6875
# 22:30:55 Epoch 1, iteration 24900: loss=1.8282, dev loss=1.6955
# 22:31:04 Epoch 1, iteration 25000: loss=1.7754, dev loss=1.6901
# 22:31:14 Epoch 1, iteration 25100: loss=1.7903, dev loss=1.6764
# 22:31:23 Epoch 1, iteration 25200: loss=1.7957, dev loss=1.7043
# 22:31:32 Epoch 1, iteration 25300: loss=1.7738, dev loss=1.6994
# 22:31:42 Epoch 1, iteration 25400: loss=1.7849, dev loss=1.6804
# 22:31:50 Epoch 1, iteration 25500: loss=1.7860, dev loss=1.7073
# 22:32:00 Epoch 1, iteration 25600: loss=1.7763, dev loss=1.6757
# 22:32:10 Epoch 1, iteration 25700: loss=1.7875, dev loss=1.6634
# 22:32:19 Epoch 1, iteration 25800: loss=1.7799, dev loss=1.6841
# 22:32:29 Epoch 1, iteration 25900: loss=1.7651, dev loss=1.7001
# 22:32:37 Epoch 1, iteration 26000: loss=1.7578, dev loss=1.6744
# 22:32:47 Epoch 1, iteration 26100: loss=1.7507, dev loss=1.6717
# 22:32:57 Epoch 1, iteration 26200: loss=1.7609, dev loss=1.6429
# 22:33:06 Epoch 1, iteration 26300: loss=1.7564, dev loss=1.6678
# 22:33:16 Epoch 1, iteration 26400: loss=1.7482, dev loss=1.6624
# 22:33:25 Epoch 1, iteration 26500: loss=1.7418, dev loss=1.6600
# 22:33:34 Epoch 1, iteration 26600: loss=1.7415, dev loss=1.6175
# 22:33:44 Epoch 1, iteration 26700: loss=1.7642, dev loss=1.6392
# 22:33:54 Epoch 1, iteration 26800: loss=1.7535, dev loss=1.6359
# 22:34:04 Epoch 1, iteration 26900: loss=1.7145, dev loss=1.6429
# 22:34:13 Epoch 1, iteration 27000: loss=1.7421, dev loss=1.6091
# 22:34:23 Epoch 1, iteration 27100: loss=1.7379, dev loss=1.6392
# 22:34:33 Epoch 1, iteration 27200: loss=1.7345, dev loss=1.6380
# 22:34:42 Epoch 1, iteration 27300: loss=1.7212, dev loss=1.6294
# 22:34:52 Epoch 1, iteration 27400: loss=1.7354, dev loss=1.6185
# 22:35:01 Epoch 1, iteration 27500: loss=1.7373, dev loss=1.6334
# 22:35:09 Epoch 1, iteration 27600: loss=1.7395, dev loss=1.6111
# 22:35:14 Epoch 1, iteration 27700: loss=1.7099, dev loss=1.6163
# 22:35:17 Epoch 1, iteration 27800: loss=1.7008, dev loss=1.6322
# 22:35:21 Epoch 1, iteration 27900: loss=1.7138, dev loss=1.6053
# 22:35:24 Epoch 1, iteration 28000: loss=1.7372, dev loss=1.5947
# 22:35:32 Epoch 1, iteration 28100: loss=1.7299, dev loss=1.5902
# 22:35:42 Epoch 1, iteration 28200: loss=1.7139, dev loss=1.6290
# 22:35:52 Epoch 1, iteration 28300: loss=1.7215, dev loss=1.5811
# 22:36:02 Epoch 1, iteration 28400: loss=1.7156, dev loss=1.5851
# 22:36:11 Epoch 1, iteration 28500: loss=1.7071, dev loss=1.5698
# 22:36:21 Epoch 1, iteration 28600: loss=1.6915, dev loss=1.5822
# 22:36:30 Epoch 1, iteration 28700: loss=1.7153, dev loss=1.5970
# 22:36:40 Epoch 1, iteration 28800: loss=1.7030, dev loss=1.5541
# 22:36:50 Epoch 1, iteration 28900: loss=1.7156, dev loss=1.5946
# 22:36:59 Epoch 1, iteration 29000: loss=1.6870, dev loss=1.5908
# 22:37:09 Epoch 1, iteration 29100: loss=1.6649, dev loss=1.5390
# 22:37:19 Epoch 1, iteration 29200: loss=1.6795, dev loss=1.5877
# 22:37:27 Epoch 1, iteration 29300: loss=1.6514, dev loss=1.5432
# 22:37:37 Epoch 1, iteration 29400: loss=1.6626, dev loss=1.5586
# 22:37:46 Epoch 1, iteration 29500: loss=1.6630, dev loss=1.5674
# 22:37:56 Epoch 1, iteration 29600: loss=1.6794, dev loss=1.5473
# 22:38:05 Epoch 1, iteration 29700: loss=1.6788, dev loss=1.5734
# 22:38:15 Epoch 1, iteration 29800: loss=1.6549, dev loss=1.5767
# 22:38:25 Epoch 1, iteration 29900: loss=1.6446, dev loss=1.5813
# 22:38:33 Epoch 1, iteration 30000: loss=1.6514, dev loss=1.5540
# Checkpoint saved to last_checkpoint_none.pt
# ------------------------------
# original: Once            | prediction: Once            | actual [MASK]: True
# original:  grandpa        | prediction:  friends        | actual [MASK]: True
# original:  to             | prediction:  to             | actual [MASK]: False
# original:  lake           | prediction:  lake           | actual [MASK]: False
# original:  so             | prediction:  so             | actual [MASK]: False
# ------------------------------
# 22:38:43 Epoch 1, iteration 30100: loss=1.6656, dev loss=1.5419
# 22:38:53 Epoch 1, iteration 30200: loss=1.6548, dev loss=1.5472
# 22:39:02 Epoch 1, iteration 30300: loss=1.6658, dev loss=1.5205
# 22:39:12 Epoch 1, iteration 30400: loss=1.6694, dev loss=1.5313
# 22:39:22 Epoch 1, iteration 30500: loss=1.6623, dev loss=1.5367
# 22:39:31 Epoch 1, iteration 30600: loss=1.6765, dev loss=1.5340
# 22:39:41 Epoch 1, iteration 30700: loss=1.6372, dev loss=1.5433
# 22:39:51 Epoch 1, iteration 30800: loss=1.6522, dev loss=1.5488
# 22:40:01 Epoch 1, iteration 30900: loss=1.6337, dev loss=1.5331
# 22:40:11 Epoch 1, iteration 31000: loss=1.6458, dev loss=1.4999
# 22:40:21 Epoch 1, iteration 31100: loss=1.6469, dev loss=1.5401
# 22:40:30 Epoch 1, iteration 31200: loss=1.6460, dev loss=1.5300
# 22:40:40 Epoch 1, iteration 31300: loss=1.6352, dev loss=1.5105
# 22:40:49 Epoch 1, iteration 31400: loss=1.6241, dev loss=1.5342
# 22:40:58 Epoch 1, iteration 31500: loss=1.6243, dev loss=1.5142
# 22:41:07 Epoch 1, iteration 31600: loss=1.6548, dev loss=1.5202
# 22:41:17 Epoch 1, iteration 31700: loss=1.6459, dev loss=1.5281
# 22:41:27 Epoch 1, iteration 31800: loss=1.6231, dev loss=1.5043
# 22:41:37 Epoch 1, iteration 31900: loss=1.6187, dev loss=1.5113
# 22:41:46 Epoch 1, iteration 32000: loss=1.6036, dev loss=1.5305
# 22:41:56 Epoch 1, iteration 32100: loss=1.6054, dev loss=1.4910
# 22:42:05 Epoch 1, iteration 32200: loss=1.6344, dev loss=1.5056
# 22:42:15 Epoch 1, iteration 32300: loss=1.6241, dev loss=1.5022
# 22:42:25 Epoch 1, iteration 32400: loss=1.6310, dev loss=1.4858
# 22:42:34 Epoch 1, iteration 32500: loss=1.5973, dev loss=1.5096
# 22:42:44 Epoch 1, iteration 32600: loss=1.5865, dev loss=1.5230
# 22:42:53 Epoch 1, iteration 32700: loss=1.6007, dev loss=1.4965
# 22:43:03 Epoch 1, iteration 32800: loss=1.6081, dev loss=1.4830
# 22:43:12 Epoch 1, iteration 32900: loss=1.5808, dev loss=1.5079
# 22:43:20 Epoch 1, iteration 33000: loss=1.5960, dev loss=1.4946
# 22:43:25 Epoch 1, iteration 33100: loss=1.6153, dev loss=1.5021
# 22:43:28 Epoch 1, iteration 33200: loss=1.6043, dev loss=1.4736
# 22:43:32 Epoch 1, iteration 33300: loss=1.5801, dev loss=1.4844
# 22:43:35 Epoch 1, iteration 33400: loss=1.5892, dev loss=1.4966
# 22:43:43 Epoch 1, iteration 33500: loss=1.5935, dev loss=1.4451
# 22:43:53 Epoch 1, iteration 33600: loss=1.5655, dev loss=1.4823
# 22:44:03 Epoch 1, iteration 33700: loss=1.6029, dev loss=1.4826
# 22:44:12 Epoch 1, iteration 33800: loss=1.5971, dev loss=1.4970
# 22:44:21 Epoch 1, iteration 33900: loss=1.6075, dev loss=1.4823
# 22:44:31 Epoch 1, iteration 34000: loss=1.5582, dev loss=1.4842
# 22:44:41 Epoch 1, iteration 34100: loss=1.5784, dev loss=1.4667
# 22:44:50 Epoch 1, iteration 34200: loss=1.5768, dev loss=1.4704
# 22:44:59 Epoch 1, iteration 34300: loss=1.5663, dev loss=1.4335
# 22:45:09 Epoch 1, iteration 34400: loss=1.5571, dev loss=1.4882
# 22:45:18 Epoch 1, iteration 34500: loss=1.5563, dev loss=1.4712
# 22:45:28 Epoch 1, iteration 34600: loss=1.5686, dev loss=1.4469
# 22:45:38 Epoch 1, iteration 34700: loss=1.5813, dev loss=1.4386
# 22:45:47 Epoch 1, iteration 34800: loss=1.5632, dev loss=1.4599
# 22:45:57 Epoch 1, iteration 34900: loss=1.5909, dev loss=1.4553
# 22:46:06 Epoch 1, iteration 35000: loss=1.5539, dev loss=1.4710
# 22:46:16 Epoch 1, iteration 35100: loss=1.5601, dev loss=1.4512
# 22:46:25 Epoch 1, iteration 35200: loss=1.5610, dev loss=1.4628
# 22:46:35 Epoch 1, iteration 35300: loss=1.5498, dev loss=1.4339
# 22:46:45 Epoch 1, iteration 35400: loss=1.5676, dev loss=1.4498
# 22:46:54 Epoch 1, iteration 35500: loss=1.5516, dev loss=1.4435
# 22:47:04 Epoch 1, iteration 35600: loss=1.5634, dev loss=1.4390
# 22:47:14 Epoch 1, iteration 35700: loss=1.5454, dev loss=1.4411
# 22:47:23 Epoch 1, iteration 35800: loss=1.5559, dev loss=1.4402
# 22:47:33 Epoch 1, iteration 35900: loss=1.5195, dev loss=1.4400
# 22:47:43 Epoch 1, iteration 36000: loss=1.5350, dev loss=1.4560
# 22:47:53 Epoch 1, iteration 36100: loss=1.5610, dev loss=1.4416
# 22:48:02 Epoch 1, iteration 36200: loss=1.5355, dev loss=1.4200
# 22:48:12 Epoch 1, iteration 36300: loss=1.5216, dev loss=1.4379
# 22:48:22 Epoch 1, iteration 36400: loss=1.5344, dev loss=1.4191
# 22:48:31 Epoch 1, iteration 36500: loss=1.5412, dev loss=1.4424
# 22:48:41 Epoch 1, iteration 36600: loss=1.5365, dev loss=1.4337
# 22:48:51 Epoch 1, iteration 36700: loss=1.5380, dev loss=1.4474
# 22:49:01 Epoch 1, iteration 36800: loss=1.5113, dev loss=1.4094
# 22:49:10 Epoch 1, iteration 36900: loss=1.5212, dev loss=1.3894
# 22:49:20 Epoch 1, iteration 37000: loss=1.5205, dev loss=1.4270
# 22:49:29 Epoch 1, iteration 37100: loss=1.5069, dev loss=1.4251
# 22:49:39 Epoch 1, iteration 37200: loss=1.5367, dev loss=1.4302
# 22:49:48 Epoch 1, iteration 37300: loss=1.5359, dev loss=1.4266
# 22:49:58 Epoch 1, iteration 37400: loss=1.5213, dev loss=1.4116
# 22:50:08 Epoch 1, iteration 37500: loss=1.4939, dev loss=1.3995
# 22:50:17 Epoch 1, iteration 37600: loss=1.5355, dev loss=1.4188
# 22:50:27 Epoch 1, iteration 37700: loss=1.5113, dev loss=1.3876
# 22:50:36 Epoch 1, iteration 37800: loss=1.4803, dev loss=1.4375
# 22:50:46 Epoch 1, iteration 37900: loss=1.5086, dev loss=1.3956
# 22:50:56 Epoch 1, iteration 38000: loss=1.5290, dev loss=1.4112
# 22:51:05 Epoch 1, iteration 38100: loss=1.5094, dev loss=1.4136
# 22:51:15 Epoch 1, iteration 38200: loss=1.5323, dev loss=1.4120
# 22:51:25 Epoch 1, iteration 38300: loss=1.5098, dev loss=1.4231
# 22:51:32 Epoch 1, iteration 38400: loss=1.5067, dev loss=1.4342
# 22:51:36 Epoch 1, iteration 38500: loss=1.5019, dev loss=1.3982
# 22:51:39 Epoch 1, iteration 38600: loss=1.5151, dev loss=1.3887
# 22:51:43 Epoch 1, iteration 38700: loss=1.4882, dev loss=1.3999
# 22:51:46 Epoch 1, iteration 38800: loss=1.5038, dev loss=1.4248
# 22:51:54 Epoch 1, iteration 38900: loss=1.5212, dev loss=1.3555
# 22:52:04 Epoch 1, iteration 39000: loss=1.5004, dev loss=1.4102
# 22:52:14 Epoch 1, iteration 39100: loss=1.4833, dev loss=1.3989
# 22:52:23 Epoch 1, iteration 39200: loss=1.5013, dev loss=1.4042
# 22:52:33 Epoch 1, iteration 39300: loss=1.5057, dev loss=1.3587
# 22:52:43 Epoch 1, iteration 39400: loss=1.4908, dev loss=1.3917
# 22:52:53 Epoch 1, iteration 39500: loss=1.5073, dev loss=1.3682
# 22:53:02 Epoch 1, iteration 39600: loss=1.4712, dev loss=1.3840
# 22:53:11 Epoch 1, iteration 39700: loss=1.4658, dev loss=1.3509
# 22:53:20 Epoch 1, iteration 39800: loss=1.5165, dev loss=1.3980
# 22:53:30 Epoch 1, iteration 39900: loss=1.4728, dev loss=1.3991
# 22:53:39 Epoch 1, iteration 40000: loss=1.4724, dev loss=1.3839
# Checkpoint saved to last_checkpoint_none.pt
# ------------------------------
# original:  a              | prediction:  a              | actual [MASK]: False
# original:  Timmy          | prediction:  Timmy          | actual [MASK]: True
# original:  water          | prediction:  line           | actual [MASK]: True
# original:  a              | prediction:  a              | actual [MASK]: True
# original:  pulled         | prediction:  pulled         | actual [MASK]: True
# ------------------------------
# 22:53:49 Epoch 1, iteration 40100: loss=1.4792, dev loss=1.4185
# 22:53:59 Epoch 1, iteration 40200: loss=1.4938, dev loss=1.3832
# 22:54:08 Epoch 1, iteration 40300: loss=1.4780, dev loss=1.3783
# 22:54:18 Epoch 1, iteration 40400: loss=1.4772, dev loss=1.3616
# 22:54:28 Epoch 1, iteration 40500: loss=1.4767, dev loss=1.3428
# 22:54:37 Epoch 1, iteration 40600: loss=1.4767, dev loss=1.3618
# 22:54:47 Epoch 1, iteration 40700: loss=1.4837, dev loss=1.3752
# 22:54:56 Epoch 1, iteration 40800: loss=1.4790, dev loss=1.3569
# 22:55:06 Epoch 1, iteration 40900: loss=1.4876, dev loss=1.3694
# 22:55:15 Epoch 1, iteration 41000: loss=1.4716, dev loss=1.3674
# 22:55:25 Epoch 1, iteration 41100: loss=1.4620, dev loss=1.3738
# 22:55:34 Epoch 1, iteration 41200: loss=1.4677, dev loss=1.3893
# 22:55:44 Epoch 1, iteration 41300: loss=1.4787, dev loss=1.3751
# 22:55:54 Epoch 1, iteration 41400: loss=1.4786, dev loss=1.3648
# 22:56:04 Epoch 1, iteration 41500: loss=1.4804, dev loss=1.3724
# 22:56:13 Epoch 1, iteration 41600: loss=1.4738, dev loss=1.3729
# 22:56:22 Epoch 1, iteration 41700: loss=1.4572, dev loss=1.3590
# 22:56:32 Epoch 1, iteration 41800: loss=1.4677, dev loss=1.3704
# 22:56:42 Epoch 1, iteration 41900: loss=1.4614, dev loss=1.3856
# 22:56:52 Epoch 1, iteration 42000: loss=1.4445, dev loss=1.3466
# 22:57:01 Epoch 1, iteration 42100: loss=1.4604, dev loss=1.3933
# 22:57:10 Epoch 1, iteration 42200: loss=1.4378, dev loss=1.3339
# 22:57:20 Epoch 1, iteration 42300: loss=1.4493, dev loss=1.3631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 88
#      84 loss.backward() # gradients
#      85 lm_optimizer.step() # update weights
# ---> 88 running_loss += loss.detach().item()
#      89 iteration += 1
#      90 if iteration%100 == 0:
#      91     # Compute validation loss every 100 iterations
#      92     # CHANGE
#
# KeyboardInterrupt:

# %% [markdown]
# ### Use the model to generate stories
# Try varying the prompt, max tokens, temperature, and top-k sampling to study the effects.

# %%
### MODIFY ###

def predict_masked(model, tokenizer, prompt="The cat sat in the chair"):
    device = next(model.parameters()).device
    mask_token_id = tokenizer.vocab_size - 1  
    
    _, token_ids = tokenizer.tokenize(prompt)
    token_ids = torch.tensor(token_ids, dtype=torch.long, device=device)
    
    # manual amsk
    masked_input = token_ids.clone()
    positions_to_mask = [1, 2] 
    for pos in positions_to_mask:
        masked_input[pos] = mask_token_id
    
    # forward pass
    with torch.no_grad():
        logits = model(masked_input.unsqueeze(0))  
        predictions = logits.argmax(dim=-1).squeeze(0) 
    
  
    print("-" * 40)
    print(f"Prompt: {prompt}")
    print("-" * 40)
    for pos in positions_to_mask:
            original_word  = tokenizer.vocab[token_ids[pos].item()]
            predicted_word = tokenizer.vocab[predictions[pos].item()]
            print('original vector: ', original_word)
            print('predicted word:', predicted_word)
            print(masked_input)
            print(masked_input[pos:])
            print(f" Position {pos}: original='{original_word}' | predicted='{predicted_word}'")
    print("-" * 40)

checkpoint_path = "last_checkpoint_none.pt"
tokenizer_path = "/content/tokenizer.json"
tokenizer_path = "/datasets/dd2417/tokenizer.json"

tokenizer = TinyStoriesTokenizer.load(tokenizer_path)
# Add [MASK] to tokens
mask_token = "[MASK]"
if mask_token not in tokenizer.vocab:
    tokenizer.vocab.append(mask_token)
    tokenizer.vocab_size += 1
mask_id = len(tokenizer.vocab) - 1  # new token for unmasking


model = TinyStoriesLM.load(checkpoint_path, device='cuda')
print(f"Tokenizer vocab_size: {tokenizer.vocab_size}")
print(f"Model vocab_size: {model.config.vocab_size}")

predict_masked(model, tokenizer)
# Out:
# Model loaded from last_checkpoint_none.pt (Epoch 0, iteration 40000)
# Tokenizer vocab_size: 5001
# Model vocab_size: 5001
# ----------------------------------------
# Prompt: The cat sat in the chair
# ----------------------------------------
# original vector:   cat
# predicted word:  chair
# tensor([1772, 5000, 5000,  135,   79, 1491], device='cuda:0')
# tensor([5000, 5000,  135,   79, 1491], device='cuda:0')
#  Position 1: original=' cat' | predicted=' chair'
# original vector:   sat
# predicted word:  is
# tensor([1772, 5000, 5000,  135,   79, 1491], device='cuda:0')
# tensor([5000,  135,   79, 1491], device='cuda:0')
#  Position 2: original=' sat' | predicted=' is'
# ----------------------------------------

# %%
print(mask_id)
