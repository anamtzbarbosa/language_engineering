# %% [markdown]
# ## SET is_causal = False in Settings

# %%
import torch
import torch.nn as nn
from Settings import TinyStoriesLM
from datetime import datetime
import random
import matplotlib.pyplot as plt
import os
from tokenizer import TinyStoriesTokenizer
from torch.utils.data import Dataset, DataLoader
from dataclasses import dataclass, asdict
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

print("cell ran")
# Out:
# cell ran

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000  # This number should agree with the tokenizer
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 1
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1


class TinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        # Pull a chunk of length block_size + 1 (data and target)
        chunk = self.data[idx : idx + self.block_size + 1]

        # Convert to torch tensors
        x = torch.from_numpy(chunk[:-1].astype(np.int64)) # Input
        y = torch.from_numpy(chunk[1:].astype(np.int64))  # Target (shifted by 1)

        return x, y 


class ProbeDataset(Dataset):
    def __init__(self, data, tensor_tags, index_range, limit=512, ignore_index = -100):
        self.data = data
        self.limit = limit
        self.index_range = list(index_range)
        self.tensor_tags = tensor_tags
        self.ignore_index = ignore_index
        #self.pos_to_id = pos_to_id

    def __len__(self):
        return len(self.index_range)

    def __getitem__(self, idx):
        idx_true = self.index_range[idx]
    
        # when we built tensors, we bactch (0, 512, 1024, 1536...)
        # To get the real position
        dataset_index = idx_true * self.limit

        # Extract binary file
        item = self.data[dataset_index]
        input_ids = item[0][:self.limit] 
        
        # from tensor tags
        labels = self.tensor_tags[idx_true][:self.limit].clone()
        labels[labels < 3] = self.ignore_index
        
        return {
            'input_ids': input_ids,
            'labels': labels
        }

print("probedataset ready")
# Out:
# probedataset ready

# %%
# We load the aligned data
tensores_tags_dataset = torch.load('tags_probes_5k_first_subtoken.pt')
POS_TAGS_VOCAB = [
    'PAD', 'SUBWORD', 'X', 'ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 
    'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 
    'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB'
]
tag2id = {tag: idx for idx, tag in enumerate(POS_TAGS_VOCAB)}
id2tag = {idx: tag for tag, idx in tag2id.items()}
ignore_index = -100
print(f"{len(tensores_tags_dataset)} tensors for Probing.")
# Out:
# 5000 tensors for Probing.

# %%
import json

with open("multipos_dict.json", "r") as f:
    multipos_dict = json.load(f)

print("cell ran")
# Out:
# cell ran

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
checkpoint_path = 'last_checkpoint_unmasking.pt'

model = TinyStoriesLM.load(checkpoint_path, device=device).to(device)
training_dataset = TinyStoriesDataset('/datasets/dd2417/train.bin', Config.block_size)
tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')

# Freeze model
for param in model.parameters():
    param.requires_grad = False

model.eval() 

activations = {}

def forward_hook(module, input, output):
    if isinstance(output, tuple):
        activations[module.name] = output[0].detach()
    else:
        activations[module.name] = output.detach()

hooks = []
for i, block in enumerate(model.transformers):
    block.name = f"layer_{i}" 
    handle = block.register_forward_hook(forward_hook)
    hooks.append(handle)

num_tags = len(tag2id)
input_dim = model.config.vector_dim
limit = model.config.block_size
num_layers = len(model.transformers)

train_subset_tags = tensores_tags_dataset[:4500]
val_subset_tags = tensores_tags_dataset[4500:]

train_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(0, 4500), limit=limit)
train_loader = DataLoader(train_ds, batch_size=model.config.batch_size, shuffle=True)

val_ds = ProbeDataset(training_dataset, tensores_tags_dataset, index_range=range(4500, 5000), limit=limit)
val_loader = DataLoader(val_ds, batch_size=model.config.batch_size, shuffle=False)
# Out:
# Model loaded from last_checkpoint_unmasking.pt (Epoch 0, iteration 130000)

# %%
print(f"Subsets : training: {len(train_ds)} | validation: {len(val_ds)}")

output_dir = os.path.join("plts", "fill_in_the_blanks")
os.makedirs(output_dir, exist_ok=True)
target_words = [' so', ' playing', ' back', ' it', ' he']
evolution_tracking = {word: {} for word in target_words}

# Global accumulation 
all_general_acc = []
all_ambiguous_acc = []
all_general_pres = []
all_ambiguous_pres = []
all_general_rec = []
all_ambiguous_rec = []
all_general_f1 = []
all_ambiguous_f1 = []

# loop through each layer representation
for layer_to_probe in range(num_layers):
    layer_name = f"layer_{layer_to_probe}"
    print(f"\nTraining probe of: {layer_name}")

    # Reset linear probing for current layer
    probe = nn.Linear(input_dim, num_tags).to(device)
    optimizer = torch.optim.Adam(probe.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=ignore_index)

    # Epochs
    for epoch in range(3):
        probe.train()
        for batch in train_loader:
            activations.clear()
            ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            with torch.no_grad():
                model(ids) 

            optimizer.zero_grad()
            logits = probe(activations[layer_name])
   
            loss = criterion(logits.view(-1, num_tags), labels.view(-1))
            loss.backward()
            optimizer.step()

        # Validation phase
        probe.eval()
        
        all_preds_general = []
        all_labels_general = []
        all_preds_ambiguous = []
        all_labels_ambiguous = []
        
        with torch.no_grad():
            for v_batch in val_loader:
                v_ids = v_batch['input_ids'].to(device)
                v_labels = v_batch['labels'].to(device)
                
                model(v_ids)
                v_logits = probe(activations[layer_name])
                predictions = v_logits.argmax(dim=-1)

                v_probs = torch.softmax(v_logits, dim=-1)
                top_3_probs, top_3_idx = torch.topk(v_probs, k=3, dim=-1)  

                # Only not ignored elements
                mask = (v_labels != ignore_index)
                all_preds_general.extend(predictions[mask].cpu().tolist())
                all_labels_general.extend(v_labels[mask].cpu().tolist())

                for b in range(v_ids.size(0)):
                    ids_list = v_ids[b].tolist()
                    tokens = tokenizer.decode_to_tokens(ids_list)
                    
                    for t in range(len(tokens)):
                        label_real = v_labels[b, t].item()
                        if label_real == ignore_index:
                            continue 
                        
                        current_word = tokens[t] 
    
                        # Qualitative log (final epoch only)
                        if epoch == 2 and current_word in target_words:
                            inicio_contexto = max(0, t - 5)
                            fin_contexto = min(len(ids_list), t + 5)
                            texto_antes = tokenizer.decode(ids_list[inicio_contexto: t])
                            frase_id = f"{texto_antes} *[{current_word.upper().strip()}]*"

                            if frase_id not in evolution_tracking[current_word]:
                                evolution_tracking[current_word][frase_id] = {}
                            
                            pred_label = predictions[b, t].item()
                            top_3_lista = top_3_idx[b, t].tolist()
                            top_3_tags = [id2tag[idx] for idx in top_3_lista]
                            top_3_probs_list = top_3_probs[b, t].tolist()
                            percentages = [p * 100 for p in top_3_probs_list]
                                
                            evolution_tracking[current_word][frase_id][layer_name] = {
                                "real_tag": id2tag[label_real],
                                "pred_tag": id2tag[pred_label],
                                "top_3_tags": top_3_tags,
                                "percentages": percentages
                            }
                                
                        # Collect ambiguous info
                        if current_word in multipos_dict:
                            pred_label = predictions[b, t].item()
                            all_preds_ambiguous.append(pred_label)
                            all_labels_ambiguous.append(label_real)

        # Filter to strip subwordsl tags (0, 1, 2)
        valid_indices = [i for i, lbl in enumerate(all_labels_general) if lbl >= 3]
        all_labels_general = [all_labels_general[i] for i in valid_indices]
        all_preds_general = [all_preds_general[i] for i in valid_indices]
        unique_valid_labels = sorted(list(set(all_labels_general + all_preds_general)))

        # General evaluations
        epoch_accuracy = accuracy_score(all_labels_general, all_preds_general) * 100
        gen_prec, gen_rec, gen_f1, _ = precision_recall_fscore_support(
            all_labels_general, all_preds_general, labels=unique_valid_labels, average='macro', zero_division=0
        )
        epoch_precision = gen_prec * 100
        epoch_recall = gen_rec * 100
        epoch_f1 = gen_f1 * 100
        
        # Ambiguous subset evaluations (also ignore 0,1,2)
        amb_valid_labels = sorted(list(set([l for l in all_labels_ambiguous + all_preds_ambiguous if l >= 3])))
        if len(all_labels_ambiguous) > 0 and len(amb_valid_labels) > 0:
            epoch_ambiguity_accuracy = accuracy_score(all_labels_ambiguous, all_preds_ambiguous) * 100
            amb_prec, amb_rec, amb_f1, _ = precision_recall_fscore_support(
                all_labels_ambiguous, all_preds_ambiguous, labels = amb_valid_labels, average='macro', zero_division=0
            )
            epoch_amb_precision = amb_prec * 100
            epoch_amb_recall = amb_rec * 100
            epoch_amb_f1 = amb_f1 * 100
        else:
            epoch_ambiguity_accuracy, epoch_amb_precision, epoch_amb_recall, epoch_amb_f1 = 0.0, 0.0, 0.0, 0.0
       
        print(f" Epoch {epoch + 1} [General]   accuracy: {epoch_accuracy:.2f}% | precision: {epoch_precision:.2f}% | recall: {epoch_recall:.2f}% | F1: {epoch_f1:.2f}%")
        print(f" Epoch {epoch + 1} [Ambiguous] accuracy: {epoch_ambiguity_accuracy:.2f}% | precision: {epoch_amb_precision:.2f}% | recall: {epoch_amb_recall:.2f}% | F1: {epoch_amb_f1:.2f}%")
        
        # confusion data to numpy arrays
        if epoch == 2:
            tag_names = [id2tag[idx] for idx in unique_valid_labels]
            cm = confusion_matrix(all_labels_general, all_preds_general, labels=unique_valid_labels, normalize='true')
            matrix_data = {
                "matrix": cm,
                "tag_names": tag_names,
                "tag_ids": unique_valid_labels
            }
            
            matrix_path = os.path.join(output_dir, f'matrix_data_{layer_name}.npy')
            np.save(matrix_path, matrix_data, allow_pickle=True)
            print(f" -- Saved matrix array data to: {matrix_path}--")

    # Log for line plot 
    all_general_acc.append(epoch_accuracy)
    all_ambiguous_acc.append(epoch_ambiguity_accuracy)
    all_general_pres.append(epoch_precision)
    all_ambiguous_pres.append(epoch_amb_precision)
    all_general_rec.append(epoch_recall)
    all_ambiguous_rec.append(epoch_amb_recall)
    all_general_f1.append(epoch_f1)
    all_ambiguous_f1.append(epoch_amb_f1)
    
    print(f"="*70) 

# Disconnect hooks
for handle in hooks:
    handle.remove()

# metrics to json
experiment_results = {
    "metadata": {
        "num_layers": num_layers,
        "target_words": target_words
    },
    "general_metrics": {
        "layers": [f"layer_{i}" for i in range(num_layers)],
        "accuracy": all_general_acc,
        "precision": all_general_pres,
        "recall": all_general_rec,
        "f1_score": all_general_f1
    },
    "ambiguous_metrics": {
        "accuracy": all_ambiguous_acc,
        "precision": all_ambiguous_pres,
        "recall": all_ambiguous_rec,
        "f1_score": all_ambiguous_f1
    },
    "evolution_tracking": evolution_tracking
}

json_path = os.path.join(output_dir, "probing_results.json")
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(experiment_results, f, ensure_ascii=False, indent=4)

print("cell ran")
# Out:
# Subsets : training: 4500 | validation: 500
#
# Training probe of: layer_0

# %%
"""metrics = {
    "accuracy": {
        "general": all_general_acc,
        "ambiguous": all_ambiguous_acc
    },
    "f1_score": {
        "general": all_general_f1,
        "ambiguous": all_ambiguous_f1
    },
    "recall": {
        "general": all_general_rec,
        "ambiguous": all_ambiguous_rec
    },
    "precision": {
        "general": all_general_pres,
        "ambiguous": all_ambiguous_pres
    }
}

with open("metrics_fill_in_the_blanks.json", "w") as f:
    json.dump(metrics, f, indent=4)"""
# Out:
# 'metrics = {\n    "accuracy": {\n        "general": all_general_acc,\n        "ambiguous": all_ambiguous_acc\n    },\n    "f1_score": {\n        "general": all_general_f1,\n        "ambiguous": all_ambiguous_f1\n    },\n    "recall": {\n        "general": all_general_rec,\n        "ambiguous": all_ambiguous_rec\n    },\n    "precision": {\n        "general": all_general_pres,\n        "ambiguous": all_ambiguous_pres\n    }\n}\n\nwith open("metrics_fill_in_the_blanks.json", "w") as f:\n    json.dump(metrics, f, indent=4)'

# %%
fixed_rand_phrases = {}

for word, contexts in evolution_tracking.items():
    phrase_list = list(contexts.keys())
    phrase_list = sorted(phrase_list) # base order
    random.seed(103)
    num_elements = min(5, len(phrase_list)) # if any element has less than 5
    selected_phrases = random.sample(phrase_list, num_elements)
    fixed_rand_phrases[word] = selected_phrases

for word, phrases in fixed_rand_phrases.items():
    print("-"*50)
    print(f"Ambiguous Word: {repr(word)}")
    for phrase_id in phrases: # each dif phrase from that ambiguous word
       layers = evolution_tracking[word][phrase_id]
       print("-"*50)
       print(f"Sentence ... {phrase_id}") 
       for layer_name in sorted(layers.keys()):
           info = layers[layer_name]
           print(f"{layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']}")
           print(f" Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | Top 3: {info['top_3_tags'][2]} ({info['percentages'][2]:.1f}%)")
            
    print("")
# Out:
# --------------------------------------------------
# Ambiguous Word: ' so'
# --------------------------------------------------
# Sentence ...  to play. They had *[SO]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (94.5%) | Top 2: SCONJ (3.6%) | Top 3: DET (1.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (94.2%) | Top 2: ADJ (2.1%) | Top 3: DET (1.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (93.3%) | Top 2: ADJ (4.9%) | Top 3: DET (0.7%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (93.2%) | Top 2: ADJ (4.8%) | Top 3: VERB (1.0%)
# --------------------------------------------------
# Sentence ...  not like the noise, *[SO]*
# layer_0 | Pred: ADV | True: CCONJ
#  Top 1: ADV (67.7%) | Top 2: SCONJ (27.6%) | Top 3: CCONJ (3.9%)
# layer_1 | Pred: ADV | True: CCONJ
#  Top 1: ADV (53.5%) | Top 2: SCONJ (36.9%) | Top 3: CCONJ (8.8%)
# layer_2 | Pred: ADV | True: CCONJ
#  Top 1: ADV (61.9%) | Top 2: SCONJ (25.1%) | Top 3: CCONJ (12.3%)
# layer_3 | Pred: ADV | True: CCONJ
#  Top 1: ADV (67.7%) | Top 2: SCONJ (24.9%) | Top 3: CCONJ (7.0%)
# --------------------------------------------------
# Sentence ... ed. The bird was *[SO]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (98.8%) | Top 2: ADJ (0.9%) | Top 3: SCONJ (0.3%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.6%) | Top 2: ADJ (0.3%) | Top 3: SCONJ (0.1%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (98.4%) | Top 2: ADJ (1.3%) | Top 3: VERB (0.2%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.5%) | Top 2: ADJ (0.4%) | Top 3: VERB (0.1%)
# --------------------------------------------------
# Sentence ...  to share. Max got *[SO]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.6%) | Top 2: ADJ (0.1%) | Top 3: DET (0.1%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.8%) | Top 2: PART (0.1%) | Top 3: CCONJ (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (99.9%) | Top 2: DET (0.0%) | Top 3: ADJ (0.0%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.9%) | Top 2: ADJ (0.0%) | Top 3: DET (0.0%)
# --------------------------------------------------
# Sentence ...  to help the bird, *[SO]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (85.5%) | Top 2: SCONJ (13.6%) | Top 3: CCONJ (0.7%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (90.2%) | Top 2: SCONJ (7.7%) | Top 3: CCONJ (2.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (80.3%) | Top 2: SCONJ (17.2%) | Top 3: CCONJ (2.2%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (95.1%) | Top 2: SCONJ (3.4%) | Top 3: CCONJ (1.3%)
#
# --------------------------------------------------
# Ambiguous Word: ' playing'
# --------------------------------------------------
# Sentence ...  with her friends. While *[PLAYING]*
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (84.9%) | Top 2: NOUN (14.7%) | Top 3: PROPN (0.2%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (54.5%) | Top 2: NOUN (44.5%) | Top 3: PROPN (0.8%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (67.8%) | Top 2: NOUN (31.9%) | Top 3: ADJ (0.1%)
# layer_3 | Pred: NOUN | True: VERB
#  Top 1: NOUN (88.2%) | Top 2: VERB (11.4%) | Top 3: PROPN (0.2%)
# --------------------------------------------------
# Sentence ...  had a lot of fun *[PLAYING]*
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (81.5%) | Top 2: NOUN (17.8%) | Top 3: PUNCT (0.3%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (92.1%) | Top 2: NOUN (7.4%) | Top 3: ADV (0.2%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (92.0%) | Top 2: NOUN (7.9%) | Top 3: ADP (0.0%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (85.7%) | Top 2: NOUN (14.2%) | Top 3: ADP (0.0%)
# --------------------------------------------------
# Sentence ...  Sue was adventurous and loved *[PLAYING]*
# layer_0 | Pred: VERB | True: NOUN
#  Top 1: VERB (99.8%) | Top 2: NOUN (0.2%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: VERB | True: NOUN
#  Top 1: VERB (99.9%) | Top 2: NOUN (0.1%) | Top 3: PROPN (0.0%)
# layer_2 | Pred: VERB | True: NOUN
#  Top 1: VERB (99.9%) | Top 2: NOUN (0.1%) | Top 3: ADJ (0.0%)
# layer_3 | Pred: VERB | True: NOUN
#  Top 1: VERB (99.7%) | Top 2: NOUN (0.3%) | Top 3: PRON (0.1%)
# --------------------------------------------------
# Sentence ...  and had so much fun *[PLAYING]*
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (63.5%) | Top 2: NOUN (32.9%) | Top 3: ADP (1.5%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (52.0%) | Top 2: NOUN (41.5%) | Top 3: ADP (2.4%)
# layer_2 | Pred: NOUN | True: VERB
#  Top 1: NOUN (56.2%) | Top 2: VERB (41.3%) | Top 3: ADP (1.1%)
# layer_3 | Pred: NOUN | True: VERB
#  Top 1: NOUN (80.5%) | Top 2: VERB (16.5%) | Top 3: ADP (1.9%)
# --------------------------------------------------
# Sentence ...  the park. Timmy was *[PLAYING]*
# layer_0 | Pred: VERB | True: VERB
#  Top 1: VERB (99.6%) | Top 2: NOUN (0.2%) | Top 3: ADV (0.1%)
# layer_1 | Pred: VERB | True: VERB
#  Top 1: VERB (98.7%) | Top 2: NOUN (0.5%) | Top 3: ADV (0.4%)
# layer_2 | Pred: VERB | True: VERB
#  Top 1: VERB (96.9%) | Top 2: NOUN (1.6%) | Top 3: ADV (0.7%)
# layer_3 | Pred: VERB | True: VERB
#  Top 1: VERB (96.0%) | Top 2: NOUN (2.2%) | Top 3: PRON (0.6%)
#
# --------------------------------------------------
# Ambiguous Word: ' back'
# --------------------------------------------------
# Sentence ...  you should give the watch *[BACK]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (79.3%) | Top 2: PRON (14.8%) | Top 3: NOUN (2.9%)
# layer_1 | Pred: ADP | True: ADV
#  Top 1: ADP (46.8%) | Top 2: ADV (44.3%) | Top 3: NOUN (4.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (66.4%) | Top 2: ADP (29.4%) | Top 3: PRON (1.9%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (96.1%) | Top 2: ADP (2.5%) | Top 3: ADJ (0.5%)
# --------------------------------------------------
# Sentence ...  park. We will come *[BACK]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (97.9%) | Top 2: ADP (1.7%) | Top 3: ADJ (0.2%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (92.0%) | Top 2: ADP (5.6%) | Top 3: ADJ (1.9%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (83.9%) | Top 2: ADP (14.6%) | Top 3: ADJ (1.2%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (90.6%) | Top 2: ADP (8.0%) | Top 3: ADJ (0.9%)
# --------------------------------------------------
# Sentence ...  yucky!" Timmy climbed *[BACK]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.4%) | Top 2: ADP (0.4%) | Top 3: VERB (0.1%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (98.9%) | Top 2: ADP (0.8%) | Top 3: VERB (0.2%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (95.9%) | Top 2: ADP (3.0%) | Top 3: VERB (0.7%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (95.5%) | Top 2: ADP (2.0%) | Top 3: PROPN (0.8%)
# --------------------------------------------------
# Sentence ...  while, the boat sailed *[BACK]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (99.9%) | Top 2: ADP (0.1%) | Top 3: VERB (0.0%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.8%) | Top 2: ADP (0.2%) | Top 3: VERB (0.0%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (99.7%) | Top 2: ADP (0.2%) | Top 3: ADJ (0.1%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (99.6%) | Top 2: ADP (0.2%) | Top 3: ADJ (0.2%)
# --------------------------------------------------
# Sentence ... " Timmy smiled and went *[BACK]*
# layer_0 | Pred: ADV | True: ADV
#  Top 1: ADV (98.1%) | Top 2: ADP (1.6%) | Top 3: VERB (0.2%)
# layer_1 | Pred: ADV | True: ADV
#  Top 1: ADV (99.1%) | Top 2: VERB (0.5%) | Top 3: ADP (0.3%)
# layer_2 | Pred: ADV | True: ADV
#  Top 1: ADV (94.7%) | Top 2: ADJ (3.3%) | Top 3: VERB (1.8%)
# layer_3 | Pred: ADV | True: ADV
#  Top 1: ADV (91.3%) | Top 2: ADJ (5.8%) | Top 3: VERB (2.8%)
#
# --------------------------------------------------
# Ambiguous Word: ' it'
# --------------------------------------------------
# Sentence ...  to twist the stick until *[IT]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: ADV (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: PUNCT (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: AUX (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ...  ground, but luckily *[IT]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: CCONJ (0.0%)
# --------------------------------------------------
# Sentence ...  already made a hole in *[IT]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) | Top 3: PUNCT (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) | Top 3: VERB (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ... s when she touches *[IT]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.2%) | Top 2: VERB (0.4%) | Top 3: ADV (0.2%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: DET (0.0%) | Top 3: VERB (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: PROPN (0.1%) | Top 3: ADV (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# --------------------------------------------------
# Sentence ...  be measured, but *[IT]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: ADV (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: ADV (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: DET (0.0%) | Top 3: ADV (0.0%)
#
# --------------------------------------------------
# Ambiguous Word: ' he'
# --------------------------------------------------
# Sentence ... . He asked Sue if *[HE]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: ADV (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: ADV (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ...  say sorry to Sammy but *[HE]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: AUX (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: ADV (0.0%) | Top 3: SCONJ (0.0%)
# --------------------------------------------------
# Sentence ... . He told Billy that *[HE]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: PROPN (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: PART (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: DET (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) | Top 3: PROPN (0.0%)
# --------------------------------------------------
# Sentence ... , little frog," *[HE]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.7%) | Top 2: PROPN (0.2%) | Top 3: NOUN (0.1%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: PROPN (0.1%) | Top 3: NOUN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: PROPN (0.1%) | Top 3: NOUN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (99.7%) | Top 2: PROPN (0.2%) | Top 3: ADV (0.0%)
# --------------------------------------------------
# Sentence ... . She admired how good *[HE]*
# layer_0 | Pred: PRON | True: PRON
#  Top 1: PRON (99.9%) | Top 2: NOUN (0.1%) | Top 3: ADV (0.0%)
# layer_1 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) | Top 3: PROPN (0.0%)
# layer_2 | Pred: PRON | True: PRON
#  Top 1: PRON (99.8%) | Top 2: NOUN (0.2%) | Top 3: PROPN (0.0%)
# layer_3 | Pred: PRON | True: PRON
#  Top 1: PRON (98.8%) | Top 2: NOUN (1.1%) | Top 3: PROPN (0.1%)

# %%
for word, contexts in evolution_tracking.items():
    print("=" * 80)
    print(f"SEARCHING HIGH-UNCERTAINTY CASES FOR: {repr(word)}")
    print("=" * 80)
    
    match_count = 0
    
    for phrase_id, layers in contexts.items():
        # Verificamos si en AL MENOS una capa el Top 2 superó el 20%
        has_high_uncertainty = any(layers[layer]['percentages'][1] > 20.0 for layer in layers)
        
        if has_high_uncertainty:
            match_count += 1
            print(f"\n[Case #{match_count}] Sentence: {phrase_id}")
            print("-" * 60)
            
            # Mostramos cómo evolucionó la duda capa por capa en esta frase
            for layer_name in sorted(layers.keys()):
                info = layers[layer_name]
                
                # Alerta visual si esta capa específica es la que causó la duda
                alert = "⚠️" if info['percentages'][1] > 20.0 else "   "
                
                print(f"  {layer_name} | Pred: {info['pred_tag']} | True: {info['real_tag']} {alert}")
                print(f"    Top 1: {info['top_3_tags'][0]} ({info['percentages'][0]:.1f}%) | "
                      f"Top 2: {info['top_3_tags'][1]} ({info['percentages'][1]:.1f}%) | ")
            print("-" * 60)
            
    if match_count == 0:
        print(f"No rare cases found for {repr(word)} with Top 2 > 10% in this run.\n")
    else:
        print(f"✅ Found {match_count} interesting cases for {repr(word)}.\n")
# Out:
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' so'
# ================================================================================
#
# [Case #1] Sentence:  for it to breathe, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (57.4%) | Top 2: ADV (41.3%) |
#   layer_1 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (77.5%) | Top 2: ADV (18.7%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (66.7%) | Top 2: ADV (31.6%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (74.4%) | Top 2: ADV (23.6%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  Lily couldn't reach it, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (88.5%) | Top 2: SCONJ (7.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.8%) | Top 2: CCONJ (34.0%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (37.9%) | Top 2: ADV (33.8%) |
#   layer_3 | Pred: CCONJ | True: ADV ⚠️
#     Top 1: CCONJ (48.4%) | Top 2: SCONJ (40.9%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence: . "Ah, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.3%) | Top 2: SCONJ (39.2%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (76.7%) | Top 2: ADV (21.0%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (85.7%) | Top 2: ADV (7.1%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (64.0%) | Top 2: ADV (15.3%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  wanted to include everyone, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.1%) | Top 2: SCONJ (34.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (89.0%) | Top 2: SCONJ (7.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (95.2%) | Top 2: SCONJ (4.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.2%) | Top 2: SCONJ (1.8%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  extra careful with his water *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.5%) | Top 2: ADV (12.2%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.9%) | Top 2: ADV (25.6%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.0%) | Top 2: SCONJ (25.8%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.5%) | Top 2: SCONJ (32.4%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  was excited to help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.9%) | Top 2: SCONJ (33.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.9%) | Top 2: SCONJ (17.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (83.8%) | Top 2: SCONJ (15.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.9%) | Top 2: SCONJ (1.8%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  Let me restore your leg *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (66.7%) | Top 2: ADV (31.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.6%) | Top 2: ADV (16.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.5%) | Top 2: ADV (12.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.7%) | Top 2: ADV (12.6%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  eat in their home, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.5%) | Top 2: SCONJ (40.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.0%) | Top 2: SCONJ (11.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (87.2%) | Top 2: SCONJ (11.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.7%) | Top 2: SCONJ (6.9%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  should take care of it *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (54.0%) | Top 2: ADV (44.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (63.0%) | Top 2: ADV (35.8%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (72.4%) | Top 2: ADV (26.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (92.3%) | Top 2: ADV (6.5%) |
# ------------------------------------------------------------
#
# [Case #10] Sentence: ided them evenly, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (75.6%) | Top 2: ADV (22.6%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (58.0%) | Top 2: ADV (38.8%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (94.6%) | Top 2: ADV (5.3%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (95.1%) | Top 2: ADV (4.6%) |
# ------------------------------------------------------------
#
# [Case #11] Sentence:  play with the toys, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.3%) | Top 2: SCONJ (32.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (79.5%) | Top 2: SCONJ (19.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.2%) | Top 2: SCONJ (8.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.8%) | Top 2: SCONJ (2.1%) |
# ------------------------------------------------------------
#
# [Case #12] Sentence:  let me comb your hair *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (76.7%) | Top 2: ADV (22.4%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.9%) | Top 2: ADV (8.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.5%) | Top 2: ADV (3.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.2%) | Top 2: ADV (7.7%) |
# ------------------------------------------------------------
#
# [Case #13] Sentence: . Lily got thirsty, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (87.1%) | Top 2: SCONJ (9.3%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (46.2%) | Top 2: ADV (45.4%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (47.8%) | Top 2: ADV (46.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.0%) | Top 2: SCONJ (21.2%) |
# ------------------------------------------------------------
#
# [Case #14] Sentence:  be careful with her juice *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.8%) | Top 2: ADV (14.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.1%) | Top 2: ADV (10.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (60.9%) | Top 2: SCONJ (38.9%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (64.1%) | Top 2: SCONJ (34.5%) |
# ------------------------------------------------------------
#
# [Case #15] Sentence:  wanted to help Tom, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.9%) | Top 2: SCONJ (23.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (86.5%) | Top 2: SCONJ (11.3%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (86.9%) | Top 2: SCONJ (10.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.9%) | Top 2: SCONJ (1.2%) |
# ------------------------------------------------------------
#
# [Case #16] Sentence:  her house to Tom's house *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.0%) | Top 2: ADV (8.6%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.8%) | Top 2: ADV (7.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (81.6%) | Top 2: ADV (18.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.1%) | Top 2: ADV (26.4%) |
# ------------------------------------------------------------
#
# [Case #17] Sentence:  to protect his family, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.2%) | Top 2: SCONJ (47.0%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (67.2%) | Top 2: ADV (28.6%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (60.6%) | Top 2: ADV (33.2%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (44.5%) | Top 2: ADV (41.0%) |
# ------------------------------------------------------------
#
# [Case #18] Sentence: . The duck was scared *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (65.1%) | Top 2: ADV (33.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (63.2%) | Top 2: ADV (35.5%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (49.6%) | Top 2: SCONJ (49.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (50.4%) | Top 2: ADV (48.4%) |
# ------------------------------------------------------------
#
# [Case #19] Sentence:  said, "Please move *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.1%) | Top 2: SCONJ (30.1%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (69.7%) | Top 2: SCONJ (28.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (57.1%) | Top 2: ADV (40.9%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (80.2%) | Top 2: SCONJ (16.8%) |
# ------------------------------------------------------------
#
# [Case #20] Sentence:  said. "It is *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.2%) | Top 2: ADJ (0.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (95.4%) | Top 2: DET (1.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (70.1%) | Top 2: DET (11.8%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (61.8%) | Top 2: DET (26.8%) |
# ------------------------------------------------------------
#
# [Case #21] Sentence:  in the warm ocean, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.6%) | Top 2: SCONJ (40.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.3%) | Top 2: SCONJ (21.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.6%) | Top 2: SCONJ (8.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.7%) | Top 2: SCONJ (8.0%) |
# ------------------------------------------------------------
#
# [Case #22] Sentence:  started to feel sleepy, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (70.7%) | Top 2: SCONJ (27.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.1%) | Top 2: SCONJ (16.4%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (94.5%) | Top 2: SCONJ (5.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.7%) | Top 2: SCONJ (2.1%) |
# ------------------------------------------------------------
#
# [Case #23] Sentence:  see where it went, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (89.5%) | Top 2: SCONJ (7.6%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.0%) | Top 2: SCONJ (27.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (75.6%) | Top 2: SCONJ (12.3%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (83.1%) | Top 2: SCONJ (11.1%) |
# ------------------------------------------------------------
#
# [Case #24] Sentence:  was scaring the baby *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.2%) | Top 2: SCONJ (9.8%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (60.9%) | Top 2: SCONJ (38.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (80.3%) | Top 2: ADV (17.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (76.4%) | Top 2: ADV (19.8%) |
# ------------------------------------------------------------
#
# [Case #25] Sentence:  the things in the refrigerator *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (71.5%) | Top 2: SCONJ (27.1%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (85.8%) | Top 2: SCONJ (13.8%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (75.9%) | Top 2: SCONJ (23.8%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.6%) | Top 2: SCONJ (11.9%) |
# ------------------------------------------------------------
#
# [Case #26] Sentence:  had to be careful, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.8%) | Top 2: SCONJ (21.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.8%) | Top 2: SCONJ (5.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (90.5%) | Top 2: SCONJ (8.5%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (93.7%) | Top 2: SCONJ (5.6%) |
# ------------------------------------------------------------
#
# [Case #27] Sentence:  parents with his address *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (56.8%) | Top 2: ADV (42.6%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.1%) | Top 2: SCONJ (10.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (60.8%) | Top 2: ADV (38.5%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.5%) | Top 2: SCONJ (29.7%) |
# ------------------------------------------------------------
#
# [Case #28] Sentence:  more about the crane, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (85.3%) | Top 2: SCONJ (12.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (88.9%) | Top 2: SCONJ (9.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.1%) | Top 2: SCONJ (22.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (83.4%) | Top 2: SCONJ (15.4%) |
# ------------------------------------------------------------
#
# [Case #29] Sentence:  to go to work, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (53.4%) | Top 2: SCONJ (45.4%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.8%) | Top 2: SCONJ (7.4%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (8.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.0%) | Top 2: SCONJ (3.8%) |
# ------------------------------------------------------------
#
# [Case #30] Sentence:  in a safe place, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (84.5%) | Top 2: SCONJ (14.7%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.6%) | Top 2: SCONJ (10.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.4%) | Top 2: SCONJ (22.3%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (50.4%) | Top 2: SCONJ (45.7%) |
# ------------------------------------------------------------
#
# [Case #31] Sentence:  you back to your house *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (73.0%) | Top 2: ADV (24.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.4%) | Top 2: ADV (10.6%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.3%) | Top 2: ADV (9.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (93.0%) | Top 2: ADV (6.4%) |
# ------------------------------------------------------------
#
# [Case #32] Sentence:  help Tim feel better, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: CCONJ ⚠️
#     Top 1: SCONJ (49.2%) | Top 2: ADV (48.2%) |
#   layer_1 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (57.7%) | Top 2: SCONJ (38.2%) |
#   layer_2 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (57.2%) | Top 2: SCONJ (41.8%) |
#   layer_3 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (57.9%) | Top 2: SCONJ (39.4%) |
# ------------------------------------------------------------
#
# [Case #33] Sentence:  "I will release you *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (65.5%) | Top 2: ADV (31.2%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (98.0%) | Top 2: ADV (1.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (92.3%) | Top 2: ADV (6.8%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (82.8%) | Top 2: ADV (14.1%) |
# ------------------------------------------------------------
#
# [Case #34] Sentence:  was careful when she danced *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.5%) | Top 2: SCONJ (23.4%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (57.1%) | Top 2: SCONJ (42.9%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (62.4%) | Top 2: SCONJ (37.5%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.9%) | Top 2: SCONJ (32.9%) |
# ------------------------------------------------------------
#
# [Case #35] Sentence:  was a cold day, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (80.9%) | Top 2: SCONJ (18.1%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.4%) | Top 2: SCONJ (24.9%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (70.8%) | Top 2: SCONJ (28.6%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (92.2%) | Top 2: SCONJ (6.9%) |
# ------------------------------------------------------------
#
# [Case #36] Sentence:  truck, Timmy. It's *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.3%) | Top 2: ADJ (0.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (98.4%) | Top 2: PRON (0.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (92.0%) | Top 2: PRON (3.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.0%) | Top 2: AUX (24.4%) |
# ------------------------------------------------------------
#
# [Case #37] Sentence:  feel a bit chilly *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (56.5%) | Top 2: SCONJ (42.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (89.1%) | Top 2: SCONJ (10.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.1%) | Top 2: SCONJ (28.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.1%) | Top 2: SCONJ (28.7%) |
# ------------------------------------------------------------
#
# [Case #38] Sentence:  to tie your hair back *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.2%) | Top 2: SCONJ (32.1%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (78.6%) | Top 2: ADV (21.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.5%) | Top 2: ADV (8.3%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (69.4%) | Top 2: ADV (29.2%) |
# ------------------------------------------------------------
#
# [Case #39] Sentence:  to be tidy and organized *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (90.7%) | Top 2: SCONJ (8.8%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (93.2%) | Top 2: SCONJ (6.3%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (71.2%) | Top 2: SCONJ (28.1%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (87.2%) | Top 2: SCONJ (8.5%) |
# ------------------------------------------------------------
#
# [Case #40] Sentence:  and tied him up outside *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.9%) | Top 2: SCONJ (9.6%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.4%) | Top 2: SCONJ (10.4%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (79.0%) | Top 2: SCONJ (20.5%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (67.5%) | Top 2: SCONJ (31.8%) |
# ------------------------------------------------------------
#
# [Case #41] Sentence:  "You need to bathe *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (65.8%) | Top 2: ADV (33.4%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.6%) | Top 2: ADV (3.0%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.0%) | Top 2: ADV (10.8%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (74.1%) | Top 2: ADV (23.4%) |
# ------------------------------------------------------------
#
# [Case #42] Sentence:  to gather more strawberries, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.6%) | Top 2: SCONJ (25.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (84.0%) | Top 2: SCONJ (12.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (93.9%) | Top 2: SCONJ (4.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (96.2%) | Top 2: SCONJ (2.5%) |
# ------------------------------------------------------------
#
# [Case #43] Sentence:  know, but it's locked *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (66.1%) | Top 2: SCONJ (33.8%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (72.8%) | Top 2: ADV (27.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (78.9%) | Top 2: SCONJ (21.0%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (86.3%) | Top 2: SCONJ (13.6%) |
# ------------------------------------------------------------
#
# [Case #44] Sentence:  listen to her mom, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (76.1%) | Top 2: SCONJ (21.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.9%) | Top 2: SCONJ (6.9%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (78.4%) | Top 2: SCONJ (19.8%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (89.6%) | Top 2: SCONJ (8.8%) |
# ------------------------------------------------------------
#
# [Case #45] Sentence:  books back on the bookcase *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (85.1%) | Top 2: SCONJ (14.6%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (59.2%) | Top 2: SCONJ (40.6%) |
#   layer_2 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.8%) | Top 2: SCONJ (11.1%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.6%) | Top 2: SCONJ (10.3%) |
# ------------------------------------------------------------
#
# [Case #46] Sentence:  in the sky. And *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.7%) | Top 2: SCONJ (28.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (92.7%) | Top 2: SCONJ (6.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: SCONJ (5.9%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.7%) | Top 2: SCONJ (3.0%) |
# ------------------------------------------------------------
#
# [Case #47] Sentence:  and were very quiet, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.5%) | Top 2: SCONJ (9.4%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.3%) | Top 2: SCONJ (17.2%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.2%) | Top 2: SCONJ (30.3%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.5%) | Top 2: SCONJ (19.0%) |
# ------------------------------------------------------------
#
# [Case #48] Sentence:  glass to the kitchen, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (52.2%) | Top 2: ADV (46.4%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (87.4%) | Top 2: ADV (10.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.0%) | Top 2: ADV (11.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (79.8%) | Top 2: CCONJ (11.7%) |
# ------------------------------------------------------------
#
# [Case #49] Sentence: illed it had given him *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (94.7%) | Top 2: SCONJ (4.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (73.6%) | Top 2: ADP (17.9%) |
#   layer_2 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (40.0%) | Top 2: SCONJ (38.7%) |
#   layer_3 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (62.4%) | Top 2: SCONJ (20.0%) |
# ------------------------------------------------------------
#
# [Case #50] Sentence:  happy to see them, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.1%) | Top 2: SCONJ (21.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (79.1%) | Top 2: SCONJ (18.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (82.7%) | Top 2: SCONJ (16.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.6%) | Top 2: SCONJ (1.6%) |
# ------------------------------------------------------------
#
# [Case #51] Sentence:  The lady looked cold, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.0%) | Top 2: SCONJ (25.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (81.2%) | Top 2: SCONJ (15.7%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.4%) | Top 2: SCONJ (40.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (83.8%) | Top 2: SCONJ (14.5%) |
# ------------------------------------------------------------
#
# [Case #52] Sentence:  his room clean and tidy *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (84.7%) | Top 2: ADV (15.2%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (97.5%) | Top 2: ADV (2.5%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.1%) | Top 2: ADV (10.8%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (59.6%) | Top 2: ADV (39.7%) |
# ------------------------------------------------------------
#
# [Case #53] Sentence:  to help the boy, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.1%) | Top 2: SCONJ (22.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: SCONJ (7.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (86.6%) | Top 2: SCONJ (12.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (86.4%) | Top 2: SCONJ (12.9%) |
# ------------------------------------------------------------
#
# [Case #54] Sentence:  wanted to catch the bee *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (79.9%) | Top 2: SCONJ (19.8%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (68.3%) | Top 2: ADV (31.4%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (77.3%) | Top 2: ADV (22.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (74.3%) | Top 2: ADV (24.9%) |
# ------------------------------------------------------------
#
# [Case #55] Sentence:  her mom for help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (85.0%) | Top 2: SCONJ (13.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (76.2%) | Top 2: SCONJ (14.1%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (54.9%) | Top 2: ADV (37.6%) |
#   layer_3 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (55.4%) | Top 2: CCONJ (25.7%) |
# ------------------------------------------------------------
#
# [Case #56] Sentence:  town was very modern, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (74.4%) | Top 2: SCONJ (24.3%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (75.3%) | Top 2: SCONJ (23.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (63.1%) | Top 2: SCONJ (36.2%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (89.0%) | Top 2: SCONJ (10.1%) |
# ------------------------------------------------------------
#
# [Case #57] Sentence:  But his mom insisted, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (60.5%) | Top 2: SCONJ (38.1%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.4%) | Top 2: SCONJ (41.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (79.7%) | Top 2: SCONJ (18.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (76.8%) | Top 2: SCONJ (19.5%) |
# ------------------------------------------------------------
#
# [Case #58] Sentence:  It started to rain, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (55.6%) | Top 2: ADV (43.7%) |
#   layer_1 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (55.7%) | Top 2: ADV (43.5%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (68.3%) | Top 2: ADV (31.2%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.7%) | Top 2: SCONJ (29.4%) |
# ------------------------------------------------------------
#
# [Case #59] Sentence:  that Timmy needed support, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (71.9%) | Top 2: SCONJ (26.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.9%) | Top 2: SCONJ (21.9%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.4%) | Top 2: SCONJ (20.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (93.9%) | Top 2: SCONJ (4.7%) |
# ------------------------------------------------------------
#
# [Case #60] Sentence:  decided to practice every day *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (91.4%) | Top 2: SCONJ (8.5%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (86.1%) | Top 2: SCONJ (13.7%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (76.4%) | Top 2: SCONJ (23.4%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (82.9%) | Top 2: SCONJ (16.6%) |
# ------------------------------------------------------------
#
# [Case #61] Sentence: . I was hungry, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (83.4%) | Top 2: SCONJ (8.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (75.5%) | Top 2: CCONJ (14.4%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (67.4%) | Top 2: SCONJ (22.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (80.1%) | Top 2: SCONJ (11.0%) |
# ------------------------------------------------------------
#
# [Case #62] Sentence:  to supply it with power *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (66.3%) | Top 2: ADV (32.6%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (93.9%) | Top 2: ADV (5.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.4%) | Top 2: ADV (3.2%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (89.8%) | Top 2: ADV (8.1%) |
# ------------------------------------------------------------
#
# [Case #63] Sentence:  Let's put it in there *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.5%) | Top 2: SCONJ (14.5%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.8%) | Top 2: SCONJ (21.9%) |
#   layer_2 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (84.6%) | Top 2: ADV (15.3%) |
#   layer_3 | Pred: SCONJ | True: ADV
#     Top 1: SCONJ (94.3%) | Top 2: ADV (5.4%) |
# ------------------------------------------------------------
#
# [Case #64] Sentence: ometimes bugs are terrible, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (78.9%) | Top 2: SCONJ (17.3%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (49.5%) | Top 2: SCONJ (44.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (43.4%) | Top 2: SCONJ (38.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (42.3%) | Top 2: ADV (41.5%) |
# ------------------------------------------------------------
#
# [Case #65] Sentence:  Ann asked for help, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (50.3%) | Top 2: ADV (44.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (89.4%) | Top 2: SCONJ (6.2%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (84.1%) | Top 2: SCONJ (13.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (80.7%) | Top 2: SCONJ (17.8%) |
# ------------------------------------------------------------
#
# [Case #66] Sentence: Mommy, the comet is *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (97.6%) | Top 2: SCONJ (1.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (97.4%) | Top 2: SCONJ (1.1%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (60.0%) | Top 2: ADJ (32.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (63.9%) | Top 2: ADJ (28.7%) |
# ------------------------------------------------------------
#
# [Case #67] Sentence: . He was thirsty, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (95.1%) | Top 2: SCONJ (3.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (85.7%) | Top 2: SCONJ (13.3%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (77.9%) | Top 2: SCONJ (20.7%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (8.2%) |
# ------------------------------------------------------------
#
# [Case #68] Sentence:  take care of special things *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (78.2%) | Top 2: ADV (21.0%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (86.3%) | Top 2: ADV (13.5%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (91.8%) | Top 2: ADV (8.0%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (90.8%) | Top 2: ADV (8.7%) |
# ------------------------------------------------------------
#
# [Case #69] Sentence:  correctly, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (82.8%) | Top 2: SCONJ (13.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (82.1%) | Top 2: SCONJ (14.5%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.0%) | Top 2: SCONJ (34.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (57.6%) | Top 2: SCONJ (39.6%) |
# ------------------------------------------------------------
#
# [Case #70] Sentence:  dishwasher in action, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.5%) | Top 2: SCONJ (26.1%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (92.2%) | Top 2: SCONJ (7.5%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (82.9%) | Top 2: SCONJ (16.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.2%) | Top 2: SCONJ (9.5%) |
# ------------------------------------------------------------
#
# [Case #71] Sentence:  Tim loved to draw, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (94.2%) | Top 2: SCONJ (5.4%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (61.4%) | Top 2: SCONJ (36.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.3%) | Top 2: SCONJ (28.6%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (64.2%) | Top 2: SCONJ (31.7%) |
# ------------------------------------------------------------
#
# [Case #72] Sentence:  was behind the door, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (90.8%) | Top 2: SCONJ (7.0%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.9%) | Top 2: SCONJ (28.2%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.5%) | Top 2: SCONJ (45.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.7%) | Top 2: SCONJ (27.2%) |
# ------------------------------------------------------------
#
# [Case #73] Sentence:  crying. Daisy was curious *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.4%) | Top 2: SCONJ (47.3%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.6%) | Top 2: SCONJ (32.7%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (69.4%) | Top 2: ADV (30.5%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.4%) | Top 2: SCONJ (34.2%) |
# ------------------------------------------------------------
#
# [Case #74] Sentence: . Let's rush back home *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (61.4%) | Top 2: SCONJ (38.0%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.4%) | Top 2: ADV (14.3%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (72.2%) | Top 2: SCONJ (27.6%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (69.6%) | Top 2: SCONJ (29.8%) |
# ------------------------------------------------------------
#
# [Case #75] Sentence:  to her and scared her *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (86.5%) | Top 2: SCONJ (12.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (91.0%) | Top 2: SCONJ (8.4%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (53.7%) | Top 2: ADV (45.1%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (70.0%) | Top 2: SCONJ (29.5%) |
# ------------------------------------------------------------
#
# [Case #76] Sentence:  to help her grandma, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.5%) | Top 2: SCONJ (26.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.3%) | Top 2: SCONJ (8.8%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (89.6%) | Top 2: SCONJ (10.0%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (95.9%) | Top 2: SCONJ (3.3%) |
# ------------------------------------------------------------
#
# [Case #77] Sentence:  to play more quietly, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (84.6%) | Top 2: SCONJ (10.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (73.9%) | Top 2: CCONJ (14.9%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.9%) | Top 2: SCONJ (20.2%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (74.9%) | Top 2: SCONJ (17.4%) |
# ------------------------------------------------------------
#
# [Case #78] Sentence:  wanted to buy something, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (68.8%) | Top 2: SCONJ (26.2%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (88.8%) | Top 2: SCONJ (8.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (88.2%) | Top 2: SCONJ (10.8%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (90.4%) | Top 2: SCONJ (9.0%) |
# ------------------------------------------------------------
#
# [Case #79] Sentence: umbs on the path *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (64.5%) | Top 2: SCONJ (34.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (71.1%) | Top 2: ADV (28.2%) |
#   layer_2 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (79.7%) | Top 2: ADV (19.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (85.6%) | Top 2: ADV (13.0%) |
# ------------------------------------------------------------
#
# [Case #80] Sentence: , it's not safe, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (54.2%) | Top 2: SCONJ (43.2%) |
#   layer_1 | Pred: SCONJ | True: CCONJ
#     Top 1: SCONJ (73.9%) | Top 2: ADV (18.1%) |
#   layer_2 | Pred: SCONJ | True: CCONJ
#     Top 1: SCONJ (85.6%) | Top 2: ADV (11.0%) |
#   layer_3 | Pred: ADV | True: CCONJ ⚠️
#     Top 1: ADV (45.1%) | Top 2: SCONJ (43.4%) |
# ------------------------------------------------------------
#
# [Case #81] Sentence:  at this eraser! It's *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.1%) | Top 2: DET (30.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (87.8%) | Top 2: DET (4.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (54.5%) | Top 2: DET (31.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (70.9%) | Top 2: DET (18.8%) |
# ------------------------------------------------------------
#
# [Case #82] Sentence:  to see what it was *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (93.4%) | Top 2: SCONJ (6.0%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (94.8%) | Top 2: SCONJ (4.1%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (86.4%) | Top 2: SCONJ (8.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.8%) | Top 2: SCONJ (32.2%) |
# ------------------------------------------------------------
#
# [Case #83] Sentence:  it looked like fun, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.6%) | Top 2: SCONJ (30.5%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (88.7%) | Top 2: SCONJ (10.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (85.9%) | Top 2: SCONJ (13.1%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (97.5%) | Top 2: SCONJ (1.6%) |
# ------------------------------------------------------------
#
# [Case #84] Sentence:  pass it out to everyone *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (96.6%) | Top 2: ADV (3.3%) |
#   layer_1 | Pred: SCONJ | True: SCONJ
#     Top 1: SCONJ (97.9%) | Top 2: ADV (2.1%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (77.2%) | Top 2: ADV (22.7%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (72.7%) | Top 2: ADV (27.0%) |
# ------------------------------------------------------------
#
# [Case #85] Sentence:  oven could be hot, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (75.8%) | Top 2: SCONJ (23.4%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (51.1%) | Top 2: SCONJ (47.8%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.9%) | Top 2: SCONJ (46.3%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (66.7%) | Top 2: SCONJ (32.5%) |
# ------------------------------------------------------------
#
# [Case #86] Sentence:  It was cold outside, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (91.3%) | Top 2: SCONJ (7.9%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.6%) | Top 2: SCONJ (29.1%) |
#   layer_2 | Pred: SCONJ | True: ADV ⚠️
#     Top 1: SCONJ (77.8%) | Top 2: ADV (20.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (48.8%) | Top 2: SCONJ (47.9%) |
# ------------------------------------------------------------
#
# [Case #87] Sentence:  to help the little fish *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (82.9%) | Top 2: SCONJ (15.9%) |
#   layer_1 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (70.7%) | Top 2: SCONJ (28.0%) |
#   layer_2 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (75.2%) | Top 2: SCONJ (21.0%) |
#   layer_3 | Pred: ADV | True: SCONJ
#     Top 1: ADV (88.2%) | Top 2: SCONJ (8.4%) |
# ------------------------------------------------------------
#
# [Case #88] Sentence: . She had never seen *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (92.8%) | Top 2: SCONJ (5.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (98.7%) | Top 2: ADP (0.6%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.0%) | Top 2: SCONJ (29.0%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.0%) | Top 2: ADP (21.4%) |
# ------------------------------------------------------------
#
# [Case #89] Sentence:  be an artist, *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (68.2%) | Top 2: SCONJ (29.9%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (47.5%) | Top 2: ADV (47.3%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (62.5%) | Top 2: ADV (31.2%) |
#   layer_3 | Pred: ADV | True: SCONJ ⚠️
#     Top 1: ADV (47.7%) | Top 2: SCONJ (29.8%) |
# ------------------------------------------------------------
#
# [Case #90] Sentence:  pen in a safe place *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (77.4%) | Top 2: ADV (21.7%) |
#   layer_1 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (61.2%) | Top 2: ADV (37.9%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (70.1%) | Top 2: ADV (29.5%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (68.5%) | Top 2: ADV (29.6%) |
# ------------------------------------------------------------
#
# [Case #91] Sentence:  "I'm eating this leaf *[SO]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: SCONJ
#     Top 1: ADV (86.6%) | Top 2: SCONJ (11.2%) |
#   layer_1 | Pred: ADV | True: SCONJ
#     Top 1: ADV (76.0%) | Top 2: SCONJ (19.7%) |
#   layer_2 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (56.9%) | Top 2: ADV (38.4%) |
#   layer_3 | Pred: SCONJ | True: SCONJ ⚠️
#     Top 1: SCONJ (48.8%) | Top 2: ADV (40.1%) |
# ------------------------------------------------------------
#
# [Case #92] Sentence:  play with the pattern, *[SO]*
# ------------------------------------------------------------
# ...
#     Top 1: ADV (83.5%) | Top 2: ADJ (7.8%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.2%) | Top 2: ADP (7.6%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (86.0%) | Top 2: ADP (7.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.3%) | Top 2: ADJ (20.1%) |
# ------------------------------------------------------------
#
# [Case #84] Sentence:  nicely to give the notebook *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (92.0%) | Top 2: ADP (3.2%) |
#   layer_1 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (58.6%) | Top 2: ADP (40.6%) |
#   layer_2 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (66.5%) | Top 2: ADV (31.8%) |
#   layer_3 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (65.9%) | Top 2: ADV (32.9%) |
# ------------------------------------------------------------
#
# [Case #85] Sentence:  was and gave the notebook *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (65.5%) | Top 2: NOUN (23.7%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (80.2%) | Top 2: ADP (17.7%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (56.0%) | Top 2: ADP (41.5%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (69.7%) | Top 2: ADP (28.4%) |
# ------------------------------------------------------------
#
# [Case #86] Sentence:  she was excited to go *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (59.0%) | Top 2: VERB (33.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (94.9%) | Top 2: VERB (4.7%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (99.1%) | Top 2: VERB (0.6%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (98.7%) | Top 2: VERB (0.9%) |
# ------------------------------------------------------------
#
# [Case #87] Sentence:  the crane's *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (45.8%) | Top 2: NOUN (33.2%) |
#   layer_1 | Pred: NOUN | True: ADV ⚠️
#     Top 1: NOUN (30.8%) | Top 2: ADV (27.1%) |
#   layer_2 | Pred: NOUN | True: ADV ⚠️
#     Top 1: NOUN (46.3%) | Top 2: ADJ (22.3%) |
#   layer_3 | Pred: NOUN | True: ADV
#     Top 1: NOUN (60.1%) | Top 2: ADV (17.1%) |
# ------------------------------------------------------------
#
# [Case #88] Sentence:  not fair! Give me *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (49.6%) | Top 2: ADV (41.9%) |
#   layer_1 | Pred: ADP | True: ADV ⚠️
#     Top 1: ADP (71.7%) | Top 2: ADV (24.8%) |
#   layer_2 | Pred: ADP | True: ADV
#     Top 1: ADP (88.1%) | Top 2: ADV (10.7%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (50.9%) | Top 2: ADP (47.8%) |
# ------------------------------------------------------------
#
# [Case #89] Sentence:  wrong and gave the hammer *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (73.6%) | Top 2: ADJ (22.9%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (93.9%) | Top 2: ADJ (3.0%) |
#   layer_2 | Pred: ADV | True: ADV
#     Top 1: ADV (97.8%) | Top 2: ADJ (1.4%) |
#   layer_3 | Pred: ADV | True: ADV
#     Top 1: ADV (98.1%) | Top 2: ADJ (1.6%) |
# ------------------------------------------------------------
#
# [Case #90] Sentence:  leash. When they came *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (98.6%) | Top 2: ADP (0.6%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (96.0%) | Top 2: ADP (2.3%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.5%) | Top 2: ADP (23.9%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (52.2%) | Top 2: ADP (45.1%) |
# ------------------------------------------------------------
#
# [Case #91] Sentence:  don't know how to go *[BACK]*
# ------------------------------------------------------------
#   layer_0 | Pred: ADV | True: ADV
#     Top 1: ADV (99.4%) | Top 2: ADP (0.3%) |
#   layer_1 | Pred: ADV | True: ADV
#     Top 1: ADV (90.7%) | Top 2: ADP (8.1%) |
#   layer_2 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (74.5%) | Top 2: ADP (24.9%) |
#   layer_3 | Pred: ADV | True: ADV ⚠️
#     Top 1: ADV (72.8%) | Top 2: ADP (26.6%) |
# ------------------------------------------------------------
# ✅ Found 91 interesting cases for ' back'.
#
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' it'
# ================================================================================
#
# [Case #1] Sentence: . He loved to play *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: ADV (0.6%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: ADV (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (94.3%) | Top 2: ADV (5.1%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (75.4%) | Top 2: ADV (22.1%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  for the bird and gave *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.0%) | Top 2: DET (24.6%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: DET (0.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: DET (0.1%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (99.9%) | Top 2: DET (0.1%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  only once. Use *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.4%) | Top 2: DET (27.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (91.8%) | Top 2: DET (7.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (96.4%) | Top 2: AUX (1.8%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (98.6%) | Top 2: AUX (0.9%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  they both realized how important *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.6%) | Top 2: NOUN (0.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (94.1%) | Top 2: NOUN (5.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: NOUN (2.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (72.4%) | Top 2: NOUN (27.3%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  little bird's voice and played *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (89.1%) | Top 2: DET (9.2%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.9%) | Top 2: DET (25.4%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (88.7%) | Top 2: DET (8.4%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (84.5%) | Top 2: DET (7.1%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  top. He would spin *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (78.2%) | Top 2: DET (16.5%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (61.4%) | Top 2: DET (36.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.7%) | Top 2: DET (1.3%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (98.6%) | Top 2: ADV (0.7%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  she wanted to go down *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.5%) | Top 2: ADV (0.3%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (87.4%) | Top 2: ADV (9.6%) |
#   layer_2 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (67.7%) | Top 2: ADV (31.7%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.0%) | Top 2: ADV (26.3%) |
# ------------------------------------------------------------
#
# [Case #8] Sentence:  but he could not make *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: DET (1.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (97.4%) | Top 2: DET (0.9%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.0%) | Top 2: VERB (1.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (70.6%) | Top 2: VERB (21.4%) |
# ------------------------------------------------------------
#
# [Case #9] Sentence:  toy. "I had *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (98.0%) | Top 2: VERB (1.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (96.4%) | Top 2: VERB (2.2%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (94.3%) | Top 2: VERB (3.5%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (63.4%) | Top 2: VERB (29.0%) |
# ------------------------------------------------------------
#
# [Case #10] Sentence:  You need to pay for *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (97.3%) | Top 2: NOUN (2.5%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (73.3%) | Top 2: NOUN (26.7%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (99.2%) | Top 2: NOUN (0.7%) |
#   layer_3 | Pred: PRON | True: PRON
#     Top 1: PRON (94.6%) | Top 2: NOUN (5.2%) |
# ------------------------------------------------------------
#
# [Case #11] Sentence:  ball. He can bounce *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (96.3%) | Top 2: ADV (3.1%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (94.2%) | Top 2: ADV (5.1%) |
#   layer_2 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (79.2%) | Top 2: ADV (20.2%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (62.6%) | Top 2: ADV (34.0%) |
# ------------------------------------------------------------
#
# [Case #12] Sentence:  throw it, and catch *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (95.3%) | Top 2: NOUN (4.4%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (88.3%) | Top 2: NOUN (11.3%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (97.9%) | Top 2: NOUN (1.5%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (75.5%) | Top 2: NOUN (23.5%) |
# ------------------------------------------------------------
#
# [Case #13] Sentence: , but he cannot catch *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (96.5%) | Top 2: NOUN (2.7%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (91.0%) | Top 2: NOUN (7.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (93.7%) | Top 2: ADV (3.7%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (54.3%) | Top 2: ADV (30.9%) |
# ------------------------------------------------------------
#
# [Case #14] Sentence:  She wanted to slide down *[IT]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (97.4%) | Top 2: ADV (0.5%) |
#   layer_1 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (48.8%) | Top 2: ADV (28.4%) |
#   layer_2 | Pred: ADV | True: PRON ⚠️
#     Top 1: ADV (63.0%) | Top 2: PRON (32.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (47.2%) | Top 2: ADV (46.3%) |
# ------------------------------------------------------------
# ✅ Found 14 interesting cases for ' it'.
#
# ================================================================================
# SEARCHING HIGH-UNCERTAINTY CASES FOR: ' he'
# ================================================================================
#
# [Case #1] Sentence:  wife who is now in *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PROPN ⚠️
#     Top 1: PRON (62.2%) | Top 2: PROPN (21.8%) |
#   layer_1 | Pred: PROPN | True: PROPN ⚠️
#     Top 1: PROPN (67.0%) | Top 2: PRON (21.4%) |
#   layer_2 | Pred: PROPN | True: PROPN
#     Top 1: PROPN (67.5%) | Top 2: PRON (19.4%) |
#   layer_3 | Pred: NOUN | True: PROPN
#     Top 1: NOUN (74.5%) | Top 2: PROPN (18.8%) |
# ------------------------------------------------------------
#
# [Case #2] Sentence:  them instead. Lily was *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (94.9%) | Top 2: ADV (4.0%) |
#   layer_1 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (63.7%) | Top 2: ADV (29.6%) |
#   layer_2 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (70.5%) | Top 2: ADV (26.4%) |
#   layer_3 | Pred: PRON | True: ADJ
#     Top 1: PRON (72.0%) | Top 2: ADV (17.8%) |
# ------------------------------------------------------------
#
# [Case #3] Sentence:  prize just because of his *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (52.8%) | Top 2: PRON (39.4%) |
#   layer_1 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (76.8%) | Top 2: PRON (17.8%) |
#   layer_2 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (72.0%) | Top 2: PRON (23.1%) |
#   layer_3 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (93.1%) | Top 2: PRON (4.7%) |
# ------------------------------------------------------------
#
# [Case #4] Sentence:  all day long, and *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (99.8%) | Top 2: ADV (0.2%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (99.2%) | Top 2: ADV (0.8%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (98.2%) | Top 2: ADV (1.7%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (69.6%) | Top 2: ADV (30.1%) |
# ------------------------------------------------------------
#
# [Case #5] Sentence:  dreaming about all the fun *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: PRON
#     Top 1: PRON (100.0%) | Top 2: PROPN (0.0%) |
#   layer_1 | Pred: PRON | True: PRON
#     Top 1: PRON (100.0%) | Top 2: NOUN (0.0%) |
#   layer_2 | Pred: PRON | True: PRON
#     Top 1: PRON (83.0%) | Top 2: NOUN (17.0%) |
#   layer_3 | Pred: PRON | True: PRON ⚠️
#     Top 1: PRON (77.9%) | Top 2: NOUN (22.0%) |
# ------------------------------------------------------------
#
# [Case #6] Sentence:  the dog. Lily was *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: ADJ
#     Top 1: PRON (94.5%) | Top 2: ADV (2.5%) |
#   layer_1 | Pred: PRON | True: ADJ ⚠️
#     Top 1: PRON (54.8%) | Top 2: ADV (27.4%) |
#   layer_2 | Pred: PRON | True: ADJ
#     Top 1: PRON (85.1%) | Top 2: ADV (9.1%) |
#   layer_3 | Pred: PRON | True: ADJ
#     Top 1: PRON (87.2%) | Top 2: ADV (5.6%) |
# ------------------------------------------------------------
#
# [Case #7] Sentence:  Without a moment's *[HE]*
# ------------------------------------------------------------
#   layer_0 | Pred: PRON | True: NOUN ⚠️
#     Top 1: PRON (74.7%) | Top 2: NOUN (24.2%) |
#   layer_1 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (48.9%) | Top 2: PRON (41.6%) |
#   layer_2 | Pred: NOUN | True: NOUN ⚠️
#     Top 1: NOUN (61.9%) | Top 2: PRON (33.0%) |
#   layer_3 | Pred: NOUN | True: NOUN
#     Top 1: NOUN (91.9%) | Top 2: PRON (5.7%) |
# ------------------------------------------------------------
# ✅ Found 7 interesting cases for ' he'.

# %%
# IDEA DE GRAFICA: 

Causal vs Unmasking

ejex x layers 
eje y accuracy
4 lineas: net word gral accurayc and ambiguous
same apra unmasking


# TABLAS:
LAyesr vs modelo accuracys


# COMAPRACION 2

Palabras ambiguas . Calcular Accuracy promedio esa palabra en todas sus frases y compara mabas en causal y unmasking
# Out:
#   Cell In[84], line 3
#     Causal vs Unmasking
#            ^
# SyntaxError: invalid syntax

# %%
def plot_probing_results(num_layers, general_accuracies, ambiguous_accuracies):
    layers = list(range(num_layers))
    plt.figure(figsize=(10, 6))
    plt.plot(layers, general_accuracies, marker='o', linestyle='-', linewidth=2, 
             color='blue', label='General POS Accuracy')
    plt.plot(layers, ambiguous_accuracies, marker='s', linestyle='--', linewidth=2, 
             color='orange', label='Ambiguous Words POS Accuracy')
    
    plt.title('Probing Analysis: Layer-by-Layer POS Information', fontsize=14)
    plt.xlabel('Transformer Layer', fontsize=12)
    plt.ylabel('Accuracy (%)', fontsize=12)
    plt.xticks(layers)
    plt.ylim(96.5, 98.5)
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend(fontsize=11, loc='lower right')
    plt.tight_layout()
    plt.show()


plot_probing_results(num_layers, all_general_acc, all_ambiguous_acc)
